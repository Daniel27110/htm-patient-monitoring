# %% [markdown]
# # Desarollo Modelo HTM Proyecto de Grado

# %% [markdown]
# ## 1. Importar Librerías y Archivos

# %% [markdown]
# ### 1.1. Importar Librerías

# %%
# Misc
import os
import csv
import time
import math
import random
import datetime
import itertools
import numpy as np
import pandas as pd
from scipy import stats
from functools import partial
from multiprocessing import Pool

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Mathplot
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.colors as mcolors
from matplotlib.animation import FuncAnimation
from matplotlib.colors import LinearSegmentedColormap

# %%
# Sklearn
from sklearn.metrics import f1_score
from sklearn.metrics import fbeta_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# HTM
from htm.bindings.sdr import SDR, Metrics
from htm.encoders.date import DateEncoder
from htm.algorithms.anomaly import Anomaly
from htm.bindings.algorithms import SpatialPooler
from htm.bindings.algorithms import TemporalMemory
from htm.encoders.rdse import RDSE, RDSE_Parameters
from htm.algorithms.anomaly_likelihood import AnomalyLikelihood
from htm.encoders.scalar_encoder import ScalarEncoder, ScalarEncoderParameters
# Out:
# /app/.venv/lib/python3.13/site-packages/htm/__init__.py:24: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)

# %% [markdown]
# ### 1.2. Importar Datos de Pacientes

# %%
studied_patients = []
studied_patients_ages = []
studied_patients_conditions = []

patient_dir = 'patient_data'

# Load patient data with the file name patient_<age>_<condition>.txt
for file_name in os.listdir(patient_dir):
        
        # Read each file
        file_path = os.path.join(patient_dir, file_name)
        data = pd.read_csv(file_path, sep='\t', skiprows=13, encoding='latin1')
        
        # Extract age and condition from the file name
        file_name_parts = file_name.split('_')
        age = int(file_name_parts[1])
        condition = file_name_parts[2].split('.')[0] 
        
        # Add the data to the lists
        studied_patients.append(data)
        studied_patients_ages.append(age)
        studied_patients_conditions.append(condition)

# %% [markdown]
# ## 2. Limpieza y Preparación de Datos

# %% [markdown]
# ### 2.1. Parametros de los signos vitales a utilizar

# %%
# List of all vital signs collected by the monitor
all_vital_signs = ['FC', 'SpO2', 'IP', 'Resp', 'ARTs', 'ARTm', 'ARTd', 'T1', 'PI', '1s', '1m', '1d', 'T1']

# List of vitial signs of interest for this project
vital_signs = ['FC', 'SpO2', 'Resp', 'ARTs', 'ARTd']

# %%
id_paciente = 2

# %% [markdown]
# ### 2.2. Ajustar etiqueta de tiempo y manejar valores nulos

# %%
def prepare_patient_data(patient):
    
    # Convert 'Timestamp' column to datetime
    patient['Time'] = pd.to_datetime(patient['Time'], format="%Y/%m/%d %H:%M:%S")
    
    # Convert available columns to numeric, setting errors='coerce' to handle '---'
    for col in all_vital_signs:
        if col in patient.columns:
            
            # Format all readings into numbers
            patient[col] = pd.to_numeric(patient[col], errors='coerce')
            
            # Replace [-1, 0, 1] values with NaN ([-1, 0, 1] are known error readings)
            patient[col] = patient[col].replace([-1, 0, 1], np.nan)

    # Drop any empty columns
    patient.dropna(how='all', axis=1, inplace=True)

    # Sort by timestamp in ascending order
    patient.sort_values(by='Time', inplace=True)

    # Set 'Timestamp' as the index for plotting
    patient.set_index('Time', inplace=True)
    
    # Drop any empty rows
    patient.dropna(axis = 0, how = 'all', inplace = True)
    
    # print the total time range of the patient data
    print(f"Patient data range: {patient.index.min()} to {patient.index.max()}")
    # get the total number of minutes in the patient data
    total_minutes = (patient.index.max() - patient.index.min()).total_seconds() / 60
    print(f"Total minutes of data: {total_minutes:.2f} minutes")

# %%
# find out of the vital signs which ones are available in the patient data, and make that the studied vital signs
def get_studied_vital_signs(patient):
    available_vital_signs = []
    
    for col in vital_signs:
        if col in patient.columns:
            available_vital_signs.append(col)
    
    # If no vital signs are available, return an empty list
    if not available_vital_signs:
        return []
    
    # Return the available vital signs
    return available_vital_signs

# %% [markdown]
# ### 2.3. Visualizar el los signos vitales de un paciente despues de la preparación

# %%
def visualize_patient_data(patient, patient_id):
    
    patient = patient.sort_index()  # Sort by index (timestamps)
    
    # Plot available variables
    plt.figure(figsize=(14, 6))
    for col in studied_vital_signs:
        if col in patient.columns:
            plt.plot(patient.index, patient[col], label=col, linewidth=1)
    
    # Customize the plot
    plt.title(f'Signos Vitales {patient_id}')
    plt.xlabel('Tiempo (HH:MM:SS)')
    plt.ylabel('Mediciones de Signos Vitales')
    plt.xticks(rotation=45)
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    plt.grid(True)
    
    # Move legend outside the plot
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.8))  # Adjusts to be outside
    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Leaves space for legend
    plt.show()

# %% [markdown]
# ### 2.4. Aplicar la función de limpieza a todos los pacientes

# %%
# Apply the preparation and visulize the vital signs for each patient
for patient_id, patient in enumerate(studied_patients):
    
    # Clean and prepare the data
    prepare_patient_data(patient)
    
    studied_vital_signs = get_studied_vital_signs(patient)
    print(f"Studied vital signs: {studied_vital_signs}")
    
    # Visualize the data
    visualize_patient_data(patient, f'Paciente {id_paciente}')
# Out:
# Patient data range: 2025-03-16 17:15:00 to 2025-03-17 09:54:00
# Total minutes of data: 999.00 minutes
# Studied vital signs: ['FC', 'SpO2', 'ARTs', 'ARTd']

# %% [markdown]
# ## 3. Calcular anomalias de cada paciente

# %% [markdown]
# ### 3.1 Calcular anomalias a partir de los valores normales

# %%
# Define normal ranges for vital signs based on age ranges
normal_ranges = {
    
    "ARTs": {
        "0-1 años": (60, 90),
        "2-2 años": (78, 112),  
        "3-8 años": (85, 114),  
        "9-12 años": (95, 135),  
        "13-18 años": (100, 120)
    },    
    "ARTd": {
        "0-1 años": (30, 62),  
        "2-2 años": (48, 78),  
        "3-8 años": (52, 85),  
        "9-12 años": (58, 88),  
        "13-18 años": (60, 80)
    },    
    "FC": {
        "0-1 años": (100, 160), 
        "1-3 años": (95, 150), 
        "4-5 años": (80, 140), 
        "6-12 años": (70, 120), 
        "13-18 años": (60, 100)
    },    
    "Resp": {
        "0-1 años": (30, 60), 
        "1-3 años": (24, 40), 
        "4-5 años": (22, 34), 
        "6-12 años": (18, 30), 
        "13-18 años": (12, 16)
    },    
    "SpO2": {
        "0-1 años": (88, 100), # SpO2 is the same for all ages
        "1-3 años": (88, 100),
        "4-5 años": (88, 100),
        "6-12 años": (88, 100),
        "13-18 años": (88, 100)
    },
}

# %%
# Function to map age to age range string for each vital sign
def get_age_range(age, col):
    if col in ["ARTs", "ARTd"]:
        if age <= 1:
            return "0-1 años"
        elif age == 2:
            return "2-2 años"
        elif 3 <= age <= 8:
            return "3-8 años"
        elif 9 <= age <= 12:
            return "9-12 años"
        else:
            return "13-18 años"
    elif col == "FC":
        if age <= 1:
            return "0-1 años"
        elif 1 < age <= 3:
            return "1-3 años"
        elif 4 <= age <= 5:
            return "4-5 años"
        elif 6 <= age <= 12:
            return "6-12 años"
        else:
            return "13-18 años"
    elif col == "Resp":
        if age <= 1:
            return "0-1 años"
        elif 1 < age <= 3:
            return "1-3 años"
        elif 4 <= age <= 5:
            return "4-5 años"
        elif 6 <= age <= 12:
            return "6-12 años"
        else:
            return "13-18 años"
    elif col == "SpO2":
        # SpO2 uses the same range for all ages
        return "0-1 años"
    else:
        return None

# Function to count anomalies, using the patient's age
def count_anomalies(row):
    
    anomalies = 0
    age = studied_patients_ages[0]  # Use the correct index for the patient
    for col in studied_vital_signs:
        age_range = get_age_range(age, col)
        if age_range and age_range in normal_ranges[col]:
            min_val, max_val = normal_ranges[col][age_range]
            if row[col] < min_val or row[col] > max_val:
                anomalies += 1
    return anomalies

# %%
# Function to analize and plot numeber of anomalies
def analyze_and_plot_patient(patient_data, patient_id):
    
    # Apply function to count anomalies
    patient_data['Anomalies'] = patient_data.apply(count_anomalies, axis=1)
    
    # Define dynamic color mapping based on number of columns
    max_anomalies = len(normal_ranges)  # Maximum possible anomalies
    colors = ['white', '#ffff94', 'yellow', 'orange', 'red']  # White to Light Yellow to Orange
    cmap = mcolors.LinearSegmentedColormap.from_list("custom_gradient", colors, N=max_anomalies + 1)
    norm = mcolors.Normalize(vmin=0, vmax=max_anomalies)
    color_values = patient_data['Anomalies'].apply(lambda x: cmap(norm(x)))
    
    # Create the plot
    plt.figure(figsize=(14, 6))
    
    # Plot all vital signs dynamically
    for col in studied_vital_signs:
        plt.plot(patient_data.index, patient_data[col], label=col, linewidth=1)
    
    # Customize the plot
    plt.title(f'Signos Vitales Paciente {patient_id}')
    plt.xlabel('Tiempo')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.grid(True)
    
    # Color bar setup
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    plt.colorbar(sm, ax=plt.gca(), orientation='horizontal', pad=0.2, ticks=range(max_anomalies + 1), label='Número de signos vitales fuera del rango normal')    
      
    # Apply background coloring
    for i in range(len(patient_data.index) - 1):
        plt.axvspan(patient_data.index[i], patient_data.index[i + 1], color=color_values.iloc[i], alpha=0.25)
    
    # Format x-axis
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.8))  # Adjusts to be outside
    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Leaves space for legend
    plt.show()

# %%
# Apply the preparation and visulize the vital signs
for patient_id, patient in enumerate(studied_patients):
    
    
    analyze_and_plot_patient(patient, f'Paciente {id_paciente}')

# %%
# Add a column for the number of anomalies at each time step
for patient_id, patient in enumerate(studied_patients):
    
    # Apply function to count anomalies
    patient['Anomalies'] = patient.apply(count_anomalies, axis=1)
    
    print(f"Paciente {patient_id} tiene {patient['Anomalies'].sum()} anomalías en total.")
# Out:
# Paciente 0 tiene 733 anomalías en total.

# %%
# Calculate the most common number of anomalies
paciente0 = studied_patients[0]
most_common_anomalies = paciente0['Anomalies'].mode()[0]

# Initialize variables
anomaly_periods = []
interval_duration = pd.Timedelta(minutes=2)
# Set the start time as the first time in the 'Time' column
start_time = paciente0.index.min()
end_time = start_time + interval_duration

# Initialize a variable to track consecutive anomaly intervals
consecutive_anomalies = 0

while start_time < paciente0.index.max():
    # Filter the data within the current interval
    interval_data = paciente0[(paciente0.index >= start_time) & (paciente0.index < end_time)]
    
    # If there is data in this interval, process it
    if not interval_data.empty:
        # Find the highest anomaly level within the interval
        max_anomaly_level = interval_data['Anomalies'].max()
        
        # Append the interval details with the anomaly level
        anomaly_periods.append((start_time, end_time, max_anomaly_level))
        
        # Check if this interval has an anomaly level higher than the most common level
        if max_anomaly_level > most_common_anomalies:
            consecutive_anomalies += 1
        else:
            consecutive_anomalies = 0  # Reset if no anomaly
    else:
        consecutive_anomalies = 0  # Reset if there's no data in this interval
    
    # Move to the next interval
    start_time = end_time
    end_time = start_time + interval_duration

# Create a DataFrame to store the time frames, anomaly levels, and anomaly status
anomaly_df = pd.DataFrame(anomaly_periods, columns=['Start Time', 'End Time', 'Anomaly Level'])

# Set the 'Anomaly' column to True only if the anomaly level persists for more than 1 timeframe
anomaly_df['Anomaly'] = False
for i in range(1, len(anomaly_df)):
    if anomaly_df.loc[i, 'Anomaly Level'] > most_common_anomalies and anomaly_df.loc[i - 1, 'Anomaly Level'] > most_common_anomalies:
        anomaly_df.loc[i, 'Anomaly'] = True
        anomaly_df.loc[i - 1, 'Anomaly'] = True

# Display the updated DataFrame
anomaly_df
# Out:
#              Start Time            End Time  Anomaly Level  Anomaly
# 0   2025-03-16 17:15:00 2025-03-16 17:17:00              0    False
# 1   2025-03-16 17:17:00 2025-03-16 17:19:00              0    False
# 2   2025-03-16 17:19:00 2025-03-16 17:21:00              0    False
# 3   2025-03-16 17:21:00 2025-03-16 17:23:00              2     True
# 4   2025-03-16 17:23:00 2025-03-16 17:25:00              2     True
# 5   2025-03-16 17:25:00 2025-03-16 17:27:00              0    False
# 6   2025-03-16 17:27:00 2025-03-16 17:29:00              0    False
# 7   2025-03-16 17:29:00 2025-03-16 17:31:00              0    False
# 8   2025-03-16 17:31:00 2025-03-16 17:33:00              1     True
# 9   2025-03-16 17:33:00 2025-03-16 17:35:00              1     True
# 10  2025-03-16 17:35:00 2025-03-16 17:37:00              1     True
# 11  2025-03-16 17:37:00 2025-03-16 17:39:00              2     True
# 12  2025-03-16 17:39:00 2025-03-16 17:41:00              2     True
# 13  2025-03-16 17:41:00 2025-03-16 17:43:00              2     True
# 14  2025-03-16 17:43:00 2025-03-16 17:45:00              2     True
# 15  2025-03-16 17:45:00 2025-03-16 17:47:00              3     True
# 16  2025-03-16 17:47:00 2025-03-16 17:49:00              1     True
# 17  2025-03-16 17:49:00 2025-03-16 17:51:00              2     True
# 18  2025-03-16 17:51:00 2025-03-16 17:53:00              1     True
# 19  2025-03-16 17:53:00 2025-03-16 17:55:00              1     True
# 20  2025-03-16 17:55:00 2025-03-16 17:57:00              0    False
# 21  2025-03-16 17:57:00 2025-03-16 17:59:00              1    False
# 22  2025-03-16 17:59:00 2025-03-16 18:01:00              0    False
# 23  2025-03-16 18:01:00 2025-03-16 18:03:00              0    False
# 24  2025-03-16 18:03:00 2025-03-16 18:05:00              0    False
# 25  2025-03-16 18:05:00 2025-03-16 18:07:00              0    False
# 26  2025-03-16 18:07:00 2025-03-16 18:09:00              0    False
# 27  2025-03-16 18:09:00 2025-03-16 18:11:00              0    False
# 28  2025-03-16 18:11:00 2025-03-16 18:13:00              0    False
# 29  2025-03-16 18:13:00 2025-03-16 18:15:00              0    False
# 30  2025-03-16 18:15:00 2025-03-16 18:17:00              0    False
# 31  2025-03-16 18:17:00 2025-03-16 18:19:00              1    False
# 32  2025-03-16 18:19:00 2025-03-16 18:21:00              0    False
# 33  2025-03-16 18:21:00 2025-03-16 18:23:00              0    False
# 34  2025-03-16 18:23:00 2025-03-16 18:25:00              0    False
# 35  2025-03-16 18:25:00 2025-03-16 18:27:00              0    False
# 36  2025-03-16 18:27:00 2025-03-16 18:29:00              0    False
# 37  2025-03-16 18:29:00 2025-03-16 18:31:00              0    False
# 38  2025-03-16 18:31:00 2025-03-16 18:33:00              0    False
# 39  2025-03-16 18:33:00 2025-03-16 18:35:00              2    False
# 40  2025-03-16 18:35:00 2025-03-16 18:37:00              0    False
# 41  2025-03-16 18:37:00 2025-03-16 18:39:00              0    False
# 42  2025-03-16 18:39:00 2025-03-16 18:41:00              2    False
# 43  2025-03-16 18:41:00 2025-03-16 18:43:00              0    False
# 44  2025-03-16 18:43:00 2025-03-16 18:45:00              0    False
# 45  2025-03-16 18:45:00 2025-03-16 18:47:00              0    False
# 46  2025-03-16 18:47:00 2025-03-16 18:49:00              0    False
# 47  2025-03-16 18:49:00 2025-03-16 18:51:00              0    False
# 48  2025-03-16 18:51:00 2025-03-16 18:53:00              0    False
# 49  2025-03-16 18:53:00 2025-03-16 18:55:00              0    False
# 50  2025-03-16 18:55:00 2025-03-16 18:57:00              0    False
# 51  2025-03-16 18:57:00 2025-03-16 18:59:00              0    False
# 52  2025-03-16 18:59:00 2025-03-16 19:01:00              0    False
# 53  2025-03-16 19:01:00 2025-03-16 19:03:00              0    False
# 54  2025-03-16 19:03:00 2025-03-16 19:05:00              0    False
# 55  2025-03-16 19:05:00 2025-03-16 19:07:00              0    False
# 56  2025-03-16 19:07:00 2025-03-16 19:09:00              0    False
# 57  2025-03-16 19:09:00 2025-03-16 19:11:00              0    False
# 58  2025-03-16 19:11:00 2025-03-16 19:13:00              0    False
# 59  2025-03-16 19:13:00 2025-03-16 19:15:00              0    False
# 60  2025-03-16 19:15:00 2025-03-16 19:17:00              0    False
# 61  2025-03-16 19:17:00 2025-03-16 19:19:00              0    False
# 62  2025-03-16 19:19:00 2025-03-16 19:21:00              1    False
# 63  2025-03-16 19:21:00 2025-03-16 19:23:00              0    False
# 64  2025-03-16 19:23:00 2025-03-16 19:25:00              0    False
# 65  2025-03-16 19:25:00 2025-03-16 19:27:00              0    False
# 66  2025-03-16 19:27:00 2025-03-16 19:29:00              0    False
# 67  2025-03-16 19:29:00 2025-03-16 19:31:00              0    False
# 68  2025-03-16 19:31:00 2025-03-16 19:33:00              0    False
# 69  2025-03-16 19:33:00 2025-03-16 19:35:00              0    False
# 70  2025-03-16 19:35:00 2025-03-16 19:37:00              0    False
# 71  2025-03-16 19:37:00 2025-03-16 19:39:00              0    False
# 72  2025-03-16 19:39:00 2025-03-16 19:41:00              0    False
# 73  2025-03-16 19:41:00 2025-03-16 19:43:00              0    False
# 74  2025-03-16 19:43:00 2025-03-16 19:45:00              1     True
# 75  2025-03-16 19:45:00 2025-03-16 19:47:00              1     True
# 76  2025-03-16 19:47:00 2025-03-16 19:49:00              0    False
# 77  2025-03-16 19:49:00 2025-03-16 19:51:00              0    False
# 78  2025-03-16 19:51:00 2025-03-16 19:53:00              2     True
# 79  2025-03-16 19:53:00 2025-03-16 19:55:00              1     True
# 80  2025-03-16 19:55:00 2025-03-16 19:57:00              1     True
# 81  2025-03-16 19:57:00 2025-03-16 19:59:00              0    False
# 82  2025-03-16 19:59:00 2025-03-16 20:01:00              0    False
# 83  2025-03-16 20:01:00 2025-03-16 20:03:00              0    False
# 84  2025-03-16 20:03:00 2025-03-16 20:05:00              0    False
# 85  2025-03-16 20:05:00 2025-03-16 20:07:00              0    False
# 86  2025-03-16 20:07:00 2025-03-16 20:09:00              0    False
# 87  2025-03-16 20:09:00 2025-03-16 20:11:00              1    False
# 88  2025-03-16 20:11:00 2025-03-16 20:13:00              0    False
# 89  2025-03-16 20:13:00 2025-03-16 20:15:00              1    False
# 90  2025-03-16 20:15:00 2025-03-16 20:17:00              0    False
# 91  2025-03-16 20:17:00 2025-03-16 20:19:00              0    False
# 92  2025-03-16 20:19:00 2025-03-16 20:21:00              0    False
# 93  2025-03-16 20:21:00 2025-03-16 20:23:00              1     True
# 94  2025-03-16 20:23:00 2025-03-16 20:25:00              1     True
# 95  2025-03-16 20:25:00 2025-03-16 20:27:00              2     True
# 96  2025-03-16 20:27:00 2025-03-16 20:29:00              2     True
# 97  2025-03-16 20:29:00 2025-03-16 20:31:00              2     True
# 98  2025-03-16 20:31:00 2025-03-16 20:33:00              1     True
# 99  2025-03-16 20:33:00 2025-03-16 20:35:00              1     True
# 100 2025-03-16 20:35:00 2025-03-16 20:37:00              1     True
# 101 2025-03-16 20:37:00 2025-03-16 20:39:00              2     True
# 102 2025-03-16 20:39:00 2025-03-16 20:41:00              1     True
# 103 2025-03-16 20:41:00 2025-03-16 20:43:00              1     True
# 104 2025-03-16 20:43:00 2025-03-16 20:45:00              2     True
# 105 2025-03-16 20:45:00 2025-03-16 20:47:00              1     True
# 106 2025-03-16 20:47:00 2025-03-16 20:49:00              1     True
# 107 2025-03-16 20:49:00 2025-03-16 20:51:00              1     True
# 108 2025-03-16 20:51:00 2025-03-16 20:53:00              1     True
# 109 2025-03-16 20:53:00 2025-03-16 20:55:00              2     True
# 110 2025-03-16 20:55:00 2025-03-16 20:57:00              1     True
# 111 2025-03-16 20:57:00 2025-03-16 20:59:00              1     True
# 112 2025-03-16 20:59:00 2025-03-16 21:01:00              1     True
# 113 2025-03-16 21:01:00 2025-03-16 21:03:00              2     True
# 114 2025-03-16 21:03:00 2025-03-16 21:05:00              1     True
# 115 2025-03-16 21:05:00 2025-03-16 21:07:00              2     True
# 116 2025-03-16 21:07:00 2025-03-16 21:09:00              2     True
# 117 2025-03-16 21:09:00 2025-03-16 21:11:00              1     True
# 118 2025-03-16 21:11:00 2025-03-16 21:13:00              1     True
# 119 2025-03-16 21:13:00 2025-03-16 21:15:00              2     True
# 120 2025-03-16 21:15:00 2025-03-16 21:17:00              1     True
# 121 2025-03-16 21:17:00 2025-03-16 21:19:00              2     True
# 122 2025-03-16 21:19:00 2025-03-16 21:21:00              2     True
# 123 2025-03-16 21:21:00 2025-03-16 21:23:00              2     True
# 124 2025-03-16 21:23:00 2025-03-16 21:25:00              1     True
# 125 2025-03-16 21:25:00 2025-03-16 21:27:00              1     True
# 126 2025-03-16 21:27:00 2025-03-16 21:29:00              1     True
# 127 2025-03-16 21:29:00 2025-03-16 21:31:00              2     True
# 128 2025-03-16 21:31:00 2025-03-16 21:33:00              2     True
# 129 2025-03-16 21:33:00 2025-03-16 21:35:00              2     True
# 130 2025-03-16 21:35:00 2025-03-16 21:37:00              2     True
# 131 2025-03-16 21:37:00 2025-03-16 21:39:00              2     True
# 132 2025-03-16 21:39:00 2025-03-16 21:41:00              2     True
# 133 2025-03-16 21:41:00 2025-03-16 21:43:00              1     True
# 134 2025-03-16 21:43:00 2025-03-16 21:45:00              1     True
# 135 2025-03-16 21:45:00 2025-03-16 21:47:00              2     True
# 136 2025-03-16 21:47:00 2025-03-16 21:49:00              2     True
# 137 2025-03-16 21:49:00 2025-03-16 21:51:00              2     True
# 138 2025-03-16 21:51:00 2025-03-16 21:53:00              2     True
# 139 2025-03-16 21:53:00 2025-03-16 21:55:00              1     True
# 140 2025-03-16 21:55:00 2025-03-16 21:57:00              2     True
# 141 2025-03-16 21:57:00 2025-03-16 21:59:00              2     True
# 142 2025-03-16 21:59:00 2025-03-16 22:01:00              2     True
# 143 2025-03-16 22:01:00 2025-03-16 22:03:00              2     True
# 144 2025-03-16 22:03:00 2025-03-16 22:05:00              2     True
# 145 2025-03-16 22:05:00 2025-03-16 22:07:00              2     True
# 146 2025-03-16 22:07:00 2025-03-16 22:09:00              2     True
# 147 2025-03-16 22:09:00 2025-03-16 22:11:00              2     True
# 148 2025-03-16 22:11:00 2025-03-16 22:13:00              2     True
# 149 2025-03-16 22:13:00 2025-03-16 22:15:00              1     True
# 150 2025-03-16 22:15:00 2025-03-16 22:17:00              1     True
# 151 2025-03-16 22:17:00 2025-03-16 22:19:00              2     True
# 152 2025-03-16 22:19:00 2025-03-16 22:21:00              1     True
# 153 2025-03-16 22:21:00 2025-03-16 22:23:00              2     True
# 154 2025-03-16 22:23:00 2025-03-16 22:25:00              2     True
# 155 2025-03-16 22:25:00 2025-03-16 22:27:00              2     True
# 156 2025-03-16 22:27:00 2025-03-16 22:29:00              2     True
# 157 2025-03-16 22:29:00 2025-03-16 22:31:00              1     True
# 158 2025-03-16 22:31:00 2025-03-16 22:33:00              1     True
# 159 2025-03-16 22:33:00 2025-03-16 22:35:00              1     True
# 160 2025-03-16 22:35:00 2025-03-16 22:37:00              1     True
# 161 2025-03-16 22:37:00 2025-03-16 22:39:00              2     True
# 162 2025-03-16 22:39:00 2025-03-16 22:41:00              1     True
# 163 2025-03-16 22:41:00 2025-03-16 22:43:00              1     True
# 164 2025-03-16 22:43:00 2025-03-16 22:45:00              1     True
# 165 2025-03-16 22:45:00 2025-03-16 22:47:00              1     True
# 166 2025-03-16 22:47:00 2025-03-16 22:49:00              1     True
# 167 2025-03-16 22:49:00 2025-03-16 22:51:00              1     True
# 168 2025-03-16 22:51:00 2025-03-16 22:53:00              2     True
# 169 2025-03-16 22:53:00 2025-03-16 22:55:00              2     True
# 170 2025-03-16 22:55:00 2025-03-16 22:57:00              1     True
# 171 2025-03-16 22:57:00 2025-03-16 22:59:00              1     True
# 172 2025-03-16 22:59:00 2025-03-16 23:01:00              2     True
# 173 2025-03-16 23:01:00 2025-03-16 23:03:00              2     True
# 174 2025-03-16 23:03:00 2025-03-16 23:05:00              2     True
# 175 2025-03-16 23:05:00 2025-03-16 23:07:00              2     True
# 176 2025-03-16 23:07:00 2025-03-16 23:09:00              2     True
# 177 2025-03-16 23:09:00 2025-03-16 23:11:00              2     True
# 178 2025-03-16 23:11:00 2025-03-16 23:13:00              2     True
# 179 2025-03-16 23:13:00 2025-03-16 23:15:00              2     True
# 180 2025-03-16 23:15:00 2025-03-16 23:17:00              2     True
# 181 2025-03-16 23:17:00 2025-03-16 23:19:00              2     True
# 182 2025-03-16 23:19:00 2025-03-16 23:21:00              1     True
# 183 2025-03-16 23:21:00 2025-03-16 23:23:00              2     True
# 184 2025-03-16 23:23:00 2025-03-16 23:25:00              2     True
# 185 2025-03-16 23:25:00 2025-03-16 23:27:00              2     True
# 186 2025-03-16 23:27:00 2025-03-16 23:29:00              2     True
# 187 2025-03-16 23:29:00 2025-03-16 23:31:00              2     True
# 188 2025-03-16 23:31:00 2025-03-16 23:33:00              2     True
# 189 2025-03-16 23:33:00 2025-03-16 23:35:00              1     True
# 190 2025-03-16 23:35:00 2025-03-16 23:37:00              1     True
# 191 2025-03-16 23:37:00 2025-03-16 23:39:00              1     True
# 192 2025-03-16 23:39:00 2025-03-16 23:41:00              1     True
# 193 2025-03-16 23:41:00 2025-03-16 23:43:00              1     True
# 194 2025-03-16 23:43:00 2025-03-16 23:45:00              2     True
# 195 2025-03-16 23:45:00 2025-03-16 23:47:00              2     True
# 196 2025-03-16 23:47:00 2025-03-16 23:49:00              2     True
# 197 2025-03-16 23:49:00 2025-03-16 23:51:00              2     True
# 198 2025-03-16 23:51:00 2025-03-16 23:53:00              2     True
# 199 2025-03-16 23:53:00 2025-03-16 23:55:00              2     True
# 200 2025-03-16 23:55:00 2025-03-16 23:57:00              2     True
# 201 2025-03-16 23:57:00 2025-03-16 23:59:00              1     True
# 202 2025-03-16 23:59:00 2025-03-17 00:01:00              2     True
# 203 2025-03-17 00:01:00 2025-03-17 00:03:00              2     True
# 204 2025-03-17 00:03:00 2025-03-17 00:05:00              2     True
# 205 2025-03-17 00:05:00 2025-03-17 00:07:00              2     True
# 206 2025-03-17 00:07:00 2025-03-17 00:09:00              2     True
# 207 2025-03-17 00:09:00 2025-03-17 00:11:00              2     True
# 208 2025-03-17 00:11:00 2025-03-17 00:13:00              2     True
# 209 2025-03-17 00:13:00 2025-03-17 00:15:00              2     True
# 210 2025-03-17 00:15:00 2025-03-17 00:17:00              1     True
# 211 2025-03-17 00:17:00 2025-03-17 00:19:00              2     True
# 212 2025-03-17 00:19:00 2025-03-17 00:21:00              2     True
# 213 2025-03-17 00:21:00 2025-03-17 00:23:00              2     True
# 214 2025-03-17 00:23:00 2025-03-17 00:25:00              2     True
# 215 2025-03-17 00:25:00 2025-03-17 00:27:00              2     True
# 216 2025-03-17 00:27:00 2025-03-17 00:29:00              0    False
# 217 2025-03-17 00:29:00 2025-03-17 00:31:00              2     True
# 218 2025-03-17 00:31:00 2025-03-17 00:33:00              2     True
# 219 2025-03-17 00:33:00 2025-03-17 00:35:00              3     True
# 220 2025-03-17 00:35:00 2025-03-17 00:37:00              3     True
# 221 2025-03-17 00:37:00 2025-03-17 00:39:00              2     True
# 222 2025-03-17 00:39:00 2025-03-17 00:41:00              2     True
# 223 2025-03-17 00:41:00 2025-03-17 00:43:00              2     True
# 224 2025-03-17 00:43:00 2025-03-17 00:45:00              2     True
# 225 2025-03-17 00:45:00 2025-03-17 00:47:00              1     True
# 226 2025-03-17 00:47:00 2025-03-17 00:49:00              2     True
# 227 2025-03-17 00:49:00 2025-03-17 00:51:00              2     True
# 228 2025-03-17 00:51:00 2025-03-17 00:53:00              3     True
# 229 2025-03-17 00:53:00 2025-03-17 00:55:00              3     True
# 230 2025-03-17 00:55:00 2025-03-17 00:57:00              2     True
# 231 2025-03-17 00:57:00 2025-03-17 00:59:00              2     True
# 232 2025-03-17 00:59:00 2025-03-17 01:01:00              2     True
# 233 2025-03-17 01:01:00 2025-03-17 01:03:00              2     True
# 234 2025-03-17 01:03:00 2025-03-17 01:05:00              2     True
# 235 2025-03-17 01:05:00 2025-03-17 01:07:00              2     True
# 236 2025-03-17 01:07:00 2025-03-17 01:09:00              2     True
# 237 2025-03-17 01:09:00 2025-03-17 01:11:00              2     True
# 238 2025-03-17 01:11:00 2025-03-17 01:13:00              3     True
# 239 2025-03-17 01:13:00 2025-03-17 01:15:00              2     True
# 240 2025-03-17 01:15:00 2025-03-17 01:17:00              1     True
# 241 2025-03-17 01:17:00 2025-03-17 01:19:00              1     True
# 242 2025-03-17 01:19:00 2025-03-17 01:21:00              0    False
# 243 2025-03-17 01:21:00 2025-03-17 01:23:00              0    False
# 244 2025-03-17 01:23:00 2025-03-17 01:25:00              1     True
# 245 2025-03-17 01:25:00 2025-03-17 01:27:00              1     True
# 246 2025-03-17 01:27:00 2025-03-17 01:29:00              1     True
# 247 2025-03-17 01:29:00 2025-03-17 01:31:00              2     True
# 248 2025-03-17 01:31:00 2025-03-17 01:33:00              1     True
# 249 2025-03-17 01:33:00 2025-03-17 01:35:00              1     True
# 250 2025-03-17 01:35:00 2025-03-17 01:37:00              1     True
# 251 2025-03-17 01:37:00 2025-03-17 01:39:00              1     True
# 252 2025-03-17 01:39:00 2025-03-17 01:41:00              1     True
# 253 2025-03-17 01:41:00 2025-03-17 01:43:00              1     True
# 254 2025-03-17 01:43:00 2025-03-17 01:45:00              2     True
# 255 2025-03-17 01:45:00 2025-03-17 01:47:00              2     True
# 256 2025-03-17 01:47:00 2025-03-17 01:49:00              1     True
# 257 2025-03-17 01:49:00 2025-03-17 01:51:00              1     True
# 258 2025-03-17 01:51:00 2025-03-17 01:53:00              1     True
# 259 2025-03-17 01:53:00 2025-03-17 01:55:00              1     True
# 260 2025-03-17 01:55:00 2025-03-17 01:57:00              1     True
# 261 2025-03-17 01:57:00 2025-03-17 01:59:00              2     True
# 262 2025-03-17 01:59:00 2025-03-17 02:01:00              2     True
# 263 2025-03-17 02:01:00 2025-03-17 02:03:00              2     True
# 264 2025-03-17 02:03:00 2025-03-17 02:05:00              1     True
# 265 2025-03-17 02:05:00 2025-03-17 02:07:00              3     True
# 266 2025-03-17 02:07:00 2025-03-17 02:09:00              0    False
# 267 2025-03-17 02:09:00 2025-03-17 02:11:00              1    False
# 268 2025-03-17 02:11:00 2025-03-17 02:13:00              0    False
# 269 2025-03-17 02:13:00 2025-03-17 02:15:00              0    False
# 270 2025-03-17 02:15:00 2025-03-17 02:17:00              0    False
# 271 2025-03-17 02:17:00 2025-03-17 02:19:00              0    False
# 272 2025-03-17 02:19:00 2025-03-17 02:21:00              3     True
# 273 2025-03-17 02:21:00 2025-03-17 02:23:00              1     True
# 274 2025-03-17 02:23:00 2025-03-17 02:25:00              3     True
# 275 2025-03-17 02:25:00 2025-03-17 02:27:00              0    False
# 276 2025-03-17 02:27:00 2025-03-17 02:29:00              0    False
# 277 2025-03-17 02:29:00 2025-03-17 02:31:00              3    False
# 278 2025-03-17 02:31:00 2025-03-17 02:33:00              0    False
# 279 2025-03-17 02:33:00 2025-03-17 02:35:00              0    False
# 280 2025-03-17 02:35:00 2025-03-17 02:37:00              1     True
# 281 2025-03-17 02:37:00 2025-03-17 02:39:00              1     True
# 282 2025-03-17 02:39:00 2025-03-17 02:41:00              1     True
# 283 2025-03-17 02:41:00 2025-03-17 02:43:00              1     True
# 284 2025-03-17 02:43:00 2025-03-17 02:45:00              0    False
# 285 2025-03-17 02:45:00 2025-03-17 02:47:00              0    False
# 286 2025-03-17 02:47:00 2025-03-17 02:49:00              2     True
# 287 2025-03-17 02:49:00 2025-03-17 02:51:00              2     True
# 288 2025-03-17 02:51:00 2025-03-17 02:53:00              0    False
# 289 2025-03-17 02:53:00 2025-03-17 02:55:00              2    False
# 290 2025-03-17 02:55:00 2025-03-17 02:57:00              0    False
# 291 2025-03-17 02:57:00 2025-03-17 02:59:00              2     True
# 292 2025-03-17 02:59:00 2025-03-17 03:01:00              2     True
# 293 2025-03-17 03:01:00 2025-03-17 03:03:00              4     True
# 294 2025-03-17 03:03:00 2025-03-17 03:05:00              1     True
# 295 2025-03-17 03:05:00 2025-03-17 03:07:00              1     True
# 296 2025-03-17 03:07:00 2025-03-17 03:09:00              3     True
# 297 2025-03-17 03:09:00 2025-03-17 03:11:00              0    False
# 298 2025-03-17 03:11:00 2025-03-17 03:13:00              2     True
# 299 2025-03-17 03:13:00 2025-03-17 03:15:00              2     True
# 300 2025-03-17 03:15:00 2025-03-17 03:17:00              3     True
# 301 2025-03-17 03:17:00 2025-03-17 03:19:00              3     True
# 302 2025-03-17 03:19:00 2025-03-17 03:21:00              3     True
# 303 2025-03-17 03:21:00 2025-03-17 03:23:00              3     True
# 304 2025-03-17 03:23:00 2025-03-17 03:25:00              3     True
# 305 2025-03-17 03:25:00 2025-03-17 03:27:00              2     True
# 306 2025-03-17 03:27:00 2025-03-17 03:29:00              2     True
# 307 2025-03-17 03:29:00 2025-03-17 03:31:00              2     True
# 308 2025-03-17 03:31:00 2025-03-17 03:33:00              3     True
# 309 2025-03-17 03:33:00 2025-03-17 03:35:00              1     True
# 310 2025-03-17 03:35:00 2025-03-17 03:37:00              3     True
# 311 2025-03-17 03:37:00 2025-03-17 03:39:00              2     True
# 312 2025-03-17 03:39:00 2025-03-17 03:41:00              1     True
# 313 2025-03-17 03:41:00 2025-03-17 03:43:00              1     True
# 314 2025-03-17 03:43:00 2025-03-17 03:45:00              1     True
# 315 2025-03-17 03:45:00 2025-03-17 03:47:00              0    False
# 316 2025-03-17 03:47:00 2025-03-17 03:49:00              1    False
# 317 2025-03-17 03:49:00 2025-03-17 03:51:00              0    False
# 318 2025-03-17 03:51:00 2025-03-17 03:53:00              1     True
# 319 2025-03-17 03:53:00 2025-03-17 03:55:00              2     True
# 320 2025-03-17 03:55:00 2025-03-17 03:57:00              0    False
# 321 2025-03-17 03:57:00 2025-03-17 03:59:00              1    False
# 322 2025-03-17 03:59:00 2025-03-17 04:01:00              0    False
# 323 2025-03-17 04:01:00 2025-03-17 04:03:00              1    False
# 324 2025-03-17 04:03:00 2025-03-17 04:05:00              0    False
# 325 2025-03-17 04:05:00 2025-03-17 04:07:00              2     True
# 326 2025-03-17 04:07:00 2025-03-17 04:09:00              1     True
# 327 2025-03-17 04:09:00 2025-03-17 04:11:00              1     True
# 328 2025-03-17 04:11:00 2025-03-17 04:13:00              1     True
# 329 2025-03-17 04:13:00 2025-03-17 04:15:00              0    False
# 330 2025-03-17 04:15:00 2025-03-17 04:17:00              1     True
# 331 2025-03-17 04:17:00 2025-03-17 04:19:00              1     True
# 332 2025-03-17 04:19:00 2025-03-17 04:21:00              1     True
# 333 2025-03-17 04:21:00 2025-03-17 04:23:00              3     True
# 334 2025-03-17 04:23:00 2025-03-17 04:25:00              2     True
# 335 2025-03-17 04:25:00 2025-03-17 04:27:00              1     True
# 336 2025-03-17 04:27:00 2025-03-17 04:29:00              0    False
# 337 2025-03-17 04:29:00 2025-03-17 04:31:00              2     True
# 338 2025-03-17 04:31:00 2025-03-17 04:33:00              3     True
# 339 2025-03-17 04:33:00 2025-03-17 04:35:00              0    False
# 340 2025-03-17 04:35:00 2025-03-17 04:37:00              1    False
# 341 2025-03-17 04:37:00 2025-03-17 04:39:00              0    False
# 342 2025-03-17 04:39:00 2025-03-17 04:41:00              1     True
# 343 2025-03-17 04:41:00 2025-03-17 04:43:00              1     True
# 344 2025-03-17 04:43:00 2025-03-17 04:45:00              1     True
# 345 2025-03-17 04:45:00 2025-03-17 04:47:00              0    False
# 346 2025-03-17 04:47:00 2025-03-17 04:49:00              1     True
# 347 2025-03-17 04:49:00 2025-03-17 04:51:00              2     True
# 348 2025-03-17 04:51:00 2025-03-17 04:53:00              0    False
# 349 2025-03-17 04:53:00 2025-03-17 04:55:00              0    False
# 350 2025-03-17 04:55:00 2025-03-17 04:57:00              0    False
# 351 2025-03-17 04:57:00 2025-03-17 04:59:00              0    False
# 352 2025-03-17 04:59:00 2025-03-17 05:01:00              1     True
# 353 2025-03-17 05:01:00 2025-03-17 05:03:00              1     True
# 354 2025-03-17 05:03:00 2025-03-17 05:05:00              0    False
# 355 2025-03-17 05:05:00 2025-03-17 05:07:00              0    False
# 356 2025-03-17 05:07:00 2025-03-17 05:09:00              0    False
# 357 2025-03-17 05:09:00 2025-03-17 05:11:00              0    False
# 358 2025-03-17 05:11:00 2025-03-17 05:13:00              0    False
# 359 2025-03-17 05:13:00 2025-03-17 05:15:00              0    False
# 360 2025-03-17 05:15:00 2025-03-17 05:17:00              1    False
# 361 2025-03-17 05:17:00 2025-03-17 05:19:00              0    False
# 362 2025-03-17 05:19:00 2025-03-17 05:21:00              0    False
# 363 2025-03-17 05:21:00 2025-03-17 05:23:00              0    False
# 364 2025-03-17 05:23:00 2025-03-17 05:25:00              0    False
# 365 2025-03-17 05:25:00 2025-03-17 05:27:00              1    False
# 366 2025-03-17 05:27:00 2025-03-17 05:29:00              0    False
# 367 2025-03-17 05:29:00 2025-03-17 05:31:00              0    False
# 368 2025-03-17 05:31:00 2025-03-17 05:33:00              0    False
# 369 2025-03-17 05:33:00 2025-03-17 05:35:00              0    False
# 370 2025-03-17 05:35:00 2025-03-17 05:37:00              0    False
# 371 2025-03-17 05:37:00 2025-03-17 05:39:00              0    False
# 372 2025-03-17 05:39:00 2025-03-17 05:41:00              0    False
# 373 2025-03-17 05:41:00 2025-03-17 05:43:00              0    False
# 374 2025-03-17 05:43:00 2025-03-17 05:45:00              2     True
# 375 2025-03-17 05:45:00 2025-03-17 05:47:00              1     True
# 376 2025-03-17 05:47:00 2025-03-17 05:49:00              0    False
# 377 2025-03-17 05:49:00 2025-03-17 05:51:00              1    False
# 378 2025-03-17 05:51:00 2025-03-17 05:53:00              0    False
# 379 2025-03-17 05:53:00 2025-03-17 05:55:00              0    False
# 380 2025-03-17 05:55:00 2025-03-17 05:57:00              1     True
# 381 2025-03-17 05:57:00 2025-03-17 05:59:00              1     True
# 382 2025-03-17 05:59:00 2025-03-17 06:01:00              1     True
# 383 2025-03-17 06:01:00 2025-03-17 06:03:00              2     True
# 384 2025-03-17 06:03:00 2025-03-17 06:05:00              1     True
# 385 2025-03-17 06:05:00 2025-03-17 06:07:00              1     True
# 386 2025-03-17 06:07:00 2025-03-17 06:09:00              1     True
# 387 2025-03-17 06:09:00 2025-03-17 06:11:00              1     True
# 388 2025-03-17 06:11:00 2025-03-17 06:13:00              1     True
# 389 2025-03-17 06:13:00 2025-03-17 06:15:00              1     True
# 390 2025-03-17 06:15:00 2025-03-17 06:17:00              2     True
# 391 2025-03-17 06:17:00 2025-03-17 06:19:00              0    False
# 392 2025-03-17 06:19:00 2025-03-17 06:21:00              1    False
# 393 2025-03-17 06:21:00 2025-03-17 06:23:00              0    False
# 394 2025-03-17 06:23:00 2025-03-17 06:25:00              1    False
# 395 2025-03-17 06:25:00 2025-03-17 06:27:00              0    False
# 396 2025-03-17 06:27:00 2025-03-17 06:29:00              0    False
# 397 2025-03-17 06:29:00 2025-03-17 06:31:00              0    False
# 398 2025-03-17 06:31:00 2025-03-17 06:33:00              1     True
# 399 2025-03-17 06:33:00 2025-03-17 06:35:00              1     True
# 400 2025-03-17 06:35:00 2025-03-17 06:37:00              0    False
# 401 2025-03-17 06:37:00 2025-03-17 06:39:00              0    False
# 402 2025-03-17 06:39:00 2025-03-17 06:41:00              2     True
# 403 2025-03-17 06:41:00 2025-03-17 06:43:00              1     True
# 404 2025-03-17 06:43:00 2025-03-17 06:45:00              2     True
# 405 2025-03-17 06:45:00 2025-03-17 06:47:00              0    False
# 406 2025-03-17 06:47:00 2025-03-17 06:49:00              0    False
# 407 2025-03-17 06:49:00 2025-03-17 06:51:00              0    False
# 408 2025-03-17 06:51:00 2025-03-17 06:53:00              1     True
# 409 2025-03-17 06:53:00 2025-03-17 06:55:00              2     True
# 410 2025-03-17 06:55:00 2025-03-17 06:57:00              2     True
# 411 2025-03-17 06:57:00 2025-03-17 06:59:00              0    False
# 412 2025-03-17 06:59:00 2025-03-17 07:01:00              1    False
# 413 2025-03-17 07:01:00 2025-03-17 07:03:00              0    False
# 414 2025-03-17 07:03:00 2025-03-17 07:05:00              1    False
# 415 2025-03-17 07:05:00 2025-03-17 07:07:00              0    False
# 416 2025-03-17 07:07:00 2025-03-17 07:09:00              0    False
# 417 2025-03-17 07:09:00 2025-03-17 07:11:00              0    False
# 418 2025-03-17 07:11:00 2025-03-17 07:13:00              0    False
# 419 2025-03-17 07:13:00 2025-03-17 07:15:00              0    False
# 420 2025-03-17 07:15:00 2025-03-17 07:17:00              0    False
# 421 2025-03-17 07:17:00 2025-03-17 07:19:00              0    False
# 422 2025-03-17 07:19:00 2025-03-17 07:21:00              0    False
# 423 2025-03-17 07:21:00 2025-03-17 07:23:00              0    False
# 424 2025-03-17 07:23:00 2025-03-17 07:25:00              1     True
# 425 2025-03-17 07:25:00 2025-03-17 07:27:00              1     True
# 426 2025-03-17 07:27:00 2025-03-17 07:29:00              0    False
# 427 2025-03-17 07:29:00 2025-03-17 07:31:00              0    False
# 428 2025-03-17 07:31:00 2025-03-17 07:33:00              0    False
# 429 2025-03-17 07:33:00 2025-03-17 07:35:00              0    False
# 430 2025-03-17 07:35:00 2025-03-17 07:37:00              1    False
# 431 2025-03-17 07:37:00 2025-03-17 07:39:00              0    False
# 432 2025-03-17 07:39:00 2025-03-17 07:41:00              0    False
# 433 2025-03-17 07:41:00 2025-03-17 07:43:00              0    False
# 434 2025-03-17 07:43:00 2025-03-17 07:45:00              0    False
# 435 2025-03-17 07:45:00 2025-03-17 07:47:00              0    False
# 436 2025-03-17 07:47:00 2025-03-17 07:49:00              3    False
# 437 2025-03-17 07:49:00 2025-03-17 07:51:00              0    False
# 438 2025-03-17 07:51:00 2025-03-17 07:53:00              0    False
# 439 2025-03-17 07:53:00 2025-03-17 07:55:00              0    False
# 440 2025-03-17 07:55:00 2025-03-17 07:57:00              0    False
# 441 2025-03-17 07:57:00 2025-03-17 07:59:00              0    False
# 442 2025-03-17 07:59:00 2025-03-17 08:01:00              0    False
# 443 2025-03-17 08:01:00 2025-03-17 08:03:00              0    False
# 444 2025-03-17 08:03:00 2025-03-17 08:05:00              0    False
# 445 2025-03-17 08:05:00 2025-03-17 08:07:00              0    False
# 446 2025-03-17 08:07:00 2025-03-17 08:09:00              0    False
# 447 2025-03-17 08:09:00 2025-03-17 08:11:00              0    False
# 448 2025-03-17 08:11:00 2025-03-17 08:13:00              0    False
# 449 2025-03-17 08:13:00 2025-03-17 08:15:00              0    False
# 450 2025-03-17 08:15:00 2025-03-17 08:17:00              0    False
# 451 2025-03-17 08:17:00 2025-03-17 08:19:00              0    False
# 452 2025-03-17 08:19:00 2025-03-17 08:21:00              0    False
# 453 2025-03-17 08:21:00 2025-03-17 08:23:00              2    False
# 454 2025-03-17 08:23:00 2025-03-17 08:25:00              0    False
# 455 2025-03-17 08:25:00 2025-03-17 08:27:00              0    False
# 456 2025-03-17 08:27:00 2025-03-17 08:29:00              0    False
# 457 2025-03-17 08:29:00 2025-03-17 08:31:00              0    False
# 458 2025-03-17 08:31:00 2025-03-17 08:33:00              0    False
# 459 2025-03-17 08:33:00 2025-03-17 08:35:00              0    False
# 460 2025-03-17 08:35:00 2025-03-17 08:37:00              0    False
# 461 2025-03-17 08:37:00 2025-03-17 08:39:00              0    False
# 462 2025-03-17 08:39:00 2025-03-17 08:41:00              0    False
# 463 2025-03-17 08:41:00 2025-03-17 08:43:00              2    False
# 464 2025-03-17 08:43:00 2025-03-17 08:45:00              0    False
# 465 2025-03-17 08:45:00 2025-03-17 08:47:00              1    False
# 466 2025-03-17 08:47:00 2025-03-17 08:49:00              0    False
# 467 2025-03-17 08:49:00 2025-03-17 08:51:00              0    False
# 468 2025-03-17 08:51:00 2025-03-17 08:53:00              2    False
# 469 2025-03-17 08:53:00 2025-03-17 08:55:00              0    False
# 470 2025-03-17 08:55:00 2025-03-17 08:57:00              1    False
# 471 2025-03-17 08:57:00 2025-03-17 08:59:00              0    False
# 472 2025-03-17 08:59:00 2025-03-17 09:01:00              0    False
# 473 2025-03-17 09:01:00 2025-03-17 09:03:00              0    False
# 474 2025-03-17 09:03:00 2025-03-17 09:05:00              0    False
# 475 2025-03-17 09:05:00 2025-03-17 09:07:00              0    False
# 476 2025-03-17 09:07:00 2025-03-17 09:09:00              0    False
# 477 2025-03-17 09:09:00 2025-03-17 09:11:00              0    False
# 478 2025-03-17 09:11:00 2025-03-17 09:13:00              0    False
# 479 2025-03-17 09:13:00 2025-03-17 09:15:00              0    False
# 480 2025-03-17 09:15:00 2025-03-17 09:17:00              0    False
# 481 2025-03-17 09:17:00 2025-03-17 09:19:00              0    False
# 482 2025-03-17 09:19:00 2025-03-17 09:21:00              1     True
# 483 2025-03-17 09:21:00 2025-03-17 09:23:00              2     True
# 484 2025-03-17 09:23:00 2025-03-17 09:25:00              1     True
# 485 2025-03-17 09:25:00 2025-03-17 09:27:00              1     True
# 486 2025-03-17 09:27:00 2025-03-17 09:29:00              1     True
# 487 2025-03-17 09:29:00 2025-03-17 09:31:00              2     True
# 488 2025-03-17 09:31:00 2025-03-17 09:33:00              2     True
# 489 2025-03-17 09:33:00 2025-03-17 09:35:00              0    False
# 490 2025-03-17 09:35:00 2025-03-17 09:37:00              2    False
# 491 2025-03-17 09:37:00 2025-03-17 09:39:00              0    False
# 492 2025-03-17 09:39:00 2025-03-17 09:41:00              0    False
# 493 2025-03-17 09:41:00 2025-03-17 09:43:00              2    False
# 494 2025-03-17 09:43:00 2025-03-17 09:45:00              0    False
# 495 2025-03-17 09:45:00 2025-03-17 09:47:00              0    False
# 496 2025-03-17 09:47:00 2025-03-17 09:49:00              1    False
# 497 2025-03-17 09:49:00 2025-03-17 09:51:00              0    False
# 498 2025-03-17 09:51:00 2025-03-17 09:53:00              0    False
# 499 2025-03-17 09:53:00 2025-03-17 09:55:00              0    False

# %% [markdown]
# ## 3.Utilizar Modelo HTM Original

# %% [markdown]
# ### 3.1. Parametros del modelo

# %%
search_params = {'columnDimensions': [2048],
                 'sp_potentialPct': [0.4],
                 'sp_potentialRadius': [500],
                 'sp_stimulusThreshold': [5],
                 'sp_synPermInactiveDec': [0.005], #[0.001,0.005,0.01]
                 'sp_synPermActiveInc': [0.01], #[0.01,0.05,0.1]
                 'sp_synPermConnected': [0.2],
                 'sp_boostStrength': [0], #[1,1.5,2,3]
                 'tm_cellsPerColumn': [16],
                 'tm_activationThreshold':[17],
                 'tm_initialPermanence': [0.5],
                 'tm_connectedPermanence': [0.5],
                 'tm_minThreshold': [10],
                 'tm_maxNewSynapseCount': [32],
                 'tm_permanenceIncrement': [0.01], #[0.01,0.05,0.1]
                 'tm_permanenceDecrement': [0.1], #[0.01,0.05,0.1]
                 'tm_predictedSegmentDecrement': [0.001], # [0.001,0.005,0.01]
                 'tm_maxSegmentsPerCell': [128],
                 'tm_maxSynapsesPerSegment': [128],
                 'anom_wait_n': [0],      # [120,240,480,720,1440] tiempo de espera para calcular anomalias
                 'anom_window': [120],      # [120,240,480,720,1440] ventana de tiempo para el calculo de anomalias
                 'threshold': [0.1]       # list(np.arange(0.1, 0.3, 0.01)) umbral de deteccion de anomalias
                }        

combinations = list(itertools.product(*[val for key, val in search_params.items()]))

# %% [markdown]
# ### 3.2. Ejecución del modelo

# %%
# Calculo de metricas:
def found_metrics(actual, predicted):
    Accuracy = accuracy_score(actual, predicted)
    Precision = precision_score(actual, predicted, zero_division=0)
    Sensitivity_recall = recall_score(actual, predicted, zero_division=0)
    F1_score = f1_score(actual, predicted, zero_division=0)
    return {"Accuracy": Accuracy, "Precision": Precision, "Sensitivity_recall": Sensitivity_recall, "F1_score": F1_score}

def run_detection(params, monitor, anomalies, search=True):
    
    monitor.reset_index(drop=True, inplace=True) 
    df = monitor.copy()
    anom_df = anomalies.copy()
    
    # Encoder for TIME
    DateTimeEncoder = DateEncoder(timeOfDay=(21, 0.1))
    
    # Encoder for FC
    FCscalarEncoderParams = ScalarEncoderParameters()
    FCscalarEncoderParams.maximum = 200
    FCscalarEncoderParams.minimum = 0
    FCscalarEncoderParams.size = 240
    FCscalarEncoderParams.activeBits = 31
    FCscalarEncoderParams.clipInput = True
    FCscalarEncoderParams.periodic = False
    FCscalarEncoder = ScalarEncoder(FCscalarEncoderParams)
    
    # Encoder for FR (Respiratory rate)
    FRscalarEncoderParams = ScalarEncoderParameters()
    FRscalarEncoderParams.maximum = 150
    FRscalarEncoderParams.minimum = 0
    FRscalarEncoderParams.size = 190
    FRscalarEncoderParams.activeBits = 15
    FRscalarEncoderParams.clipInput = True
    FRscalarEncoderParams.periodic = False
    FRscalarEncoder = ScalarEncoder(FRscalarEncoderParams)
    
    # Encoder for SPO2
    SPO2scalarEncoderParams = ScalarEncoderParameters()
    SPO2scalarEncoderParams.maximum = 100
    SPO2scalarEncoderParams.minimum = 50
    SPO2scalarEncoderParams.size = 140
    SPO2scalarEncoderParams.activeBits = 21
    SPO2scalarEncoderParams.clipInput = True
    SPO2scalarEncoderParams.periodic = False
    SPO2scalarEncoder = ScalarEncoder(SPO2scalarEncoderParams)
    
    # Encoder for ARTs (for example, systolic arterial pressure)
    ARTsEncoderParams = ScalarEncoderParameters()
    ARTsEncoderParams.maximum = 180  # adjust based on your data range
    ARTsEncoderParams.minimum = 80
    ARTsEncoderParams.size = 160
    ARTsEncoderParams.activeBits = 21
    ARTsEncoderParams.clipInput = True
    ARTsEncoderParams.periodic = False
    ARTsEncoder = ScalarEncoder(ARTsEncoderParams)
    
    # Encoder for ARTd (for example, diastolic arterial pressure)
    ARTdEncoderParams = ScalarEncoderParameters()
    ARTdEncoderParams.maximum = 100  # adjust based on your data range
    ARTdEncoderParams.minimum = 40
    ARTdEncoderParams.size = 160
    ARTdEncoderParams.activeBits = 21
    ARTdEncoderParams.clipInput = True
    ARTdEncoderParams.periodic = False
    ARTdEncoder = ScalarEncoder(ARTdEncoderParams)
    
    # Update the total encoding width by including the new encoders:
    encodingWidth = DateTimeEncoder.size
    if 'FC' in studied_vital_signs:
        encodingWidth += FCscalarEncoder.size
    if 'Resp' in studied_vital_signs:
        encodingWidth += FRscalarEncoder.size
    if 'SpO2' in studied_vital_signs:
        encodingWidth += SPO2scalarEncoder.size
    if 'ARTs' in studied_vital_signs:
        encodingWidth += ARTsEncoder.size
    if 'ARTd' in studied_vital_signs:
        encodingWidth += ARTdEncoder.size
    enc_info = Metrics([encodingWidth], 999999999)

    # Make the HTM. SpatialPooler & TemporalMemory & associated tools.
    sp = SpatialPooler(
        inputDimensions=(encodingWidth,),
        columnDimensions=(params[0],),
        potentialPct=params[1],
        potentialRadius=params[2],
        globalInhibition=True,
        stimulusThreshold=params[3],
        localAreaDensity=0.02, 
        synPermInactiveDec=params[4],
        synPermActiveInc=params[5], 
        synPermConnected=params[6],
        boostStrength=params[7],
        wrapAround=False
    )
    sp_info = Metrics(sp.getColumnDimensions(), 999999999)

    tm = TemporalMemory(
        columnDimensions=(params[0],),
        cellsPerColumn=params[8], 
        activationThreshold=params[9], 
        initialPermanence=params[10], 
        connectedPermanence=params[11], 
        minThreshold=params[12],
        maxNewSynapseCount=params[13],
        permanenceIncrement=params[14],
        permanenceDecrement=params[15],
        predictedSegmentDecrement=params[16],
        maxSegmentsPerCell=params[17],
        maxSynapsesPerSegment=params[18]
    )
    tm_info = Metrics([tm.numberOfCells()], 999999999)

    df['anomalySc'] = 0
    df['anomalyProb'] = 0
    df['anomalyLogProb'] = 0

    anomaly_history = AnomalyLikelihood()

    # Run the model for each record in the monitor dataframe:
    for count, record in df.iterrows():
        date_bits = DateTimeEncoder.encode(record['Time'])
        fc_bits = FCscalarEncoder.encode(record['FC']) if 'FC' in studied_vital_signs else None
        fr_bits = FRscalarEncoder.encode(record['Resp']) if 'Resp' in studied_vital_signs else None
        spo2_bits = SPO2scalarEncoder.encode(record['SpO2']) if 'SpO2' in studied_vital_signs else None
        arts_bits = ARTsEncoder.encode(record['ARTs']) if 'ARTs' in studied_vital_signs else None
        artd_bits = ARTdEncoder.encode(record['ARTd']) if 'ARTd' in studied_vital_signs else None

        # Concatenate only the encoded bits that are not None:
        encoded_bits = [date_bits]
        for bits in [fc_bits, fr_bits, spo2_bits, arts_bits, artd_bits]:
            if bits is not None:
                encoded_bits.append(bits)

        encoding = SDR(encodingWidth).concatenate(encoded_bits)
        enc_info.addData(encoding)
        
        activeColumns = SDR(sp.getColumnDimensions())
        sp.compute(encoding, True, activeColumns)
        sp_info.addData(activeColumns)
        
        tm.compute(activeColumns, learn=True)
        tm_info.addData(tm.getActiveCells().flatten())
        
        df.loc[count, 'anomalySc'] = tm.anomaly
        df.loc[count, 'anomalyLogProb'] = anomaly_history.get_log_likelihood(df.loc[count, 'anomalySc'])
    
    df['anom_pred'] = df['anomalyLogProb'].apply(lambda x: True if x > params[21] else False)
    
    for idx, row in anom_df.iterrows():
        anom_period = df.loc[(df['Time'] >= row['Start Time']) & (df['Time'] < row['End Time'])]
        alarms = [i for i, val in enumerate(anom_period.anom_pred) if val]
        if alarms:
            anom_df.loc[idx, 'cnt_pred'] = len(alarms)
            anom_df.loc[idx, 'max_anomLikelihood_pred'] = anom_period.iloc[alarms]['anomalyLogProb'].max()
            anom_df.loc[idx, 'time_pred'] = anom_period.iloc[alarms]['Time'].min()
            anom_df.loc[idx, 'anom_pred'] = 1
        else:
            anom_df.loc[idx, 'anom_pred'] = 0
    
    if search:
        anom_eval = anom_df[anom_df['Start Time'] > df.iloc[params[19]]['Time']]
        metricas = found_metrics(anom_eval['Anomaly'], anom_eval.anom_pred)
    
        params_dict = {
            'columnDimensions': params[0],
            'potentialPct': params[1],
            'potentialRadius': params[2],
            'stimulusThreshold': params[3],
            'synPermInactiveDec': params[4],
            'synPermActiveInc': params[5],
            'synPermConnected': params[6],
            'boostStrength': params[7],
            'cellsPerColumn': params[8],
            'activationThreshold': params[9],
            'initialPermanence': params[10],
            'connectedPermanence': params[11],
            'minThreshold': params[12],
            'maxNewSynapseCount': params[13],
            'permanenceIncrement': params[14],
            'permanenceDecrement': params[15],
            'predictedSegmentDecrement': params[16],
            'maxSegmentsPerCell': params[17],
            'maxSynapsesPerSegment': params[18],
            'anom_wait_n': params[19],
            'anom_window': params[20],
            'threshold': params[21]
        }
        return {**params_dict, **metricas}
    else:
        return {'monitor': df, 'anomalies': anom_df}

# %%
paciente0.reset_index(inplace=True)
start_time = time.time()

# Run the detection function
result_1 = run_detection(combinations[0], monitor=paciente0, anomalies=anomaly_df, search=False)
execution_time = time.time() - start_time

results1 = result_1['anomalies']

num_data_points = results1.shape[0] if hasattr(results1, 'shape') else len(results1)

print(f"Execution time: {execution_time:.2f} seconds")
print(f"Number of data points analyzed: {num_data_points}")
# Out:
# /tmp/ipykernel_361/2615860022.py:146: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.375' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[count, 'anomalySc'] = tm.anomaly
# /tmp/ipykernel_361/2615860022.py:147: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.020411998331991598' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[count, 'anomalyLogProb'] = anomaly_history.get_log_likelihood(df.loc[count, 'anomalySc'])
# Execution time: 10.21 seconds
# Number of data points analyzed: 500

# %% [markdown]
# ### 3.4. Visualizar Anomalias

# %%
# Function to analyze and plot patient data along with model anomaly predictions
def analyze_and_plot_patient(patient_data, patient_id, results1):
    # Count anomalies for each row of patient data
    patient_data['Anomalies'] = patient_data.apply(count_anomalies, axis=1)
    
    # Define a dynamic color mapping based on the number of anomalies
    max_anomalies = len(normal_ranges)  # Maximum possible anomalies
    colors = ['lightgreen', '#ffffB3', 'yellow', 'orange', 'red']
    cmap = mcolors.LinearSegmentedColormap.from_list("custom_gradient", colors, N=max_anomalies + 1)
    norm = mcolors.Normalize(vmin=0, vmax=max_anomalies)
    color_values = patient_data['Anomalies'].apply(lambda x: cmap(norm(x)))
    
    # Create the base plot
    plt.figure(figsize=(16, 6))
    
    # Plot all vital signs dynamically
    for col in studied_vital_signs:
        plt.plot(patient_data.index, patient_data[col], label=col, linewidth=1)
    
    # Customize plot settings
    plt.title(f'Signos Vitales Paciente {patient_id} analizados por el modelo tradicional')
    plt.xlabel('Tiempo')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.grid(True)
    
    # Add a color bar for the number of anomalies
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    plt.colorbar(sm, ax=plt.gca(), orientation='horizontal', pad=0.2, ticks=range(max_anomalies + 1), label='Número de signos vitales fuera del rango normal')
    
    # Apply background coloring based on the number of anomalies
    for i in range(len(patient_data.index) - 1):
        plt.axvspan(patient_data.index[i], patient_data.index[i + 1], color=color_values.iloc[i], alpha=0.25)
    
    # Plot red diamond markers for model predicted anomalies.
    # Filter predictions where an anomaly was predicted (assuming anom_pred == 1.0 indicates an anomaly)
    predictions = results1.loc[results1['anom_pred'] == 1.0].copy()
    if not predictions.empty:
        # Ensure 'time_pred' and 'End Time' columns are in datetime format
        predictions['time_pred'] = pd.to_datetime(predictions['time_pred'],  format="%Y/%m/%d %H:%M:%S")
        predictions['End Time'] = pd.to_datetime(predictions['End Time'],  format="%Y/%m/%d %H:%M:%S")
        
        # Determine a y-coordinate for the marker: slightly above the maximum value among all vital signs.
        vitals_max = patient_data[list(studied_vital_signs)].max().max()
        vitals_min = patient_data[list(studied_vital_signs)].min().min()
        offset = (vitals_max - vitals_min) * 0.05
        y_marker = vitals_max + offset
        
        # To avoid duplicate legend entries, label only the first marker.
        first_marker = True
        for _, row in predictions.iterrows():
            # Plot the red diamond marker
            if first_marker:
                plt.scatter(row['time_pred'], y_marker, marker='D', color='red', s=100, zorder=5,
                            label='Anomalia Reportada por el Modelo')
                first_marker = False
            else:
                plt.scatter(row['time_pred'], y_marker, marker='D', color='red', s=100, zorder=5)
            
            ## Calculate the duration (difference between 'End Time' and 'time_pred') in minutes
            #duration = row['End Time'] - row['time_pred']
            #duration_minutes = duration.total_seconds() / 60
            #duration_str = f"{duration_minutes:.2f} min"
            
            ## Annotate the marker with the duration text rotated vertically (90°)
            #plt.text(row['time_pred'], y_marker + 1.5 * offset, duration_str,
                     # fontsize=9, color='black', ha='center', va='bottom', rotation=90, rotation_mode='anchor')
    
    # Format the x-axis to show time in HH:MM:SS format
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.8))  # Position legend outside the plot area
    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust layout to leave space for the legend
    plt.show()

# Example usage:
# Ensure that 'patient' and 'paciente0' are defined DataFrames with a proper 'Time' column
patient.set_index('Time', inplace=True)
analyze_and_plot_patient(paciente0, str(id_paciente), results1)

# %% [markdown]
# ## 4. Nueva Arquitectura del Modelo

# %% [markdown]
# ### 4.1. Algoritmo del predicción usando parejas maximas

# %%
def run_detection_pair(params, monitor, anomalies, selected_signals, search=True):
    # Validate selected_signals: must be a list of exactly 2 allowed signals.
    allowed_signals = {"FC", "Resp", "SpO2", "ARTs", "ARTd"}
    if not isinstance(selected_signals, list) or len(selected_signals) != 2 or not set(selected_signals).issubset(allowed_signals):
        raise ValueError("selected_signals must be a list of 2 signals chosen from: 'FC', 'Resp', 'SpO2', 'ARTs', 'ARTd'.")
    
    monitor.reset_index(drop=True, inplace=True)
    df = monitor.copy()
    anom_df = anomalies.copy()

    # Always create the Time encoder:
    DateTimeEncoder = DateEncoder(timeOfDay=(21, 0.1))
    
    # Create a dictionary to hold encoders for the selected signals.
    # Each entry is a tuple: (encoder_object, column_name in the dataframe)
    signal_encoders = {}
    
    if "FC" in selected_signals:
        FCscalarEncoderParams = ScalarEncoderParameters()
        FCscalarEncoderParams.maximum = 200
        FCscalarEncoderParams.minimum = 0
        FCscalarEncoderParams.size = 240
        FCscalarEncoderParams.activeBits = 31
        FCscalarEncoderParams.clipInput = True
        FCscalarEncoderParams.periodic = False
        FCscalarEncoder = ScalarEncoder(FCscalarEncoderParams)
        signal_encoders["FC"] = (FCscalarEncoder, "FC")
    
    if "Resp" in selected_signals:
        FRscalarEncoderParams = ScalarEncoderParameters()
        FRscalarEncoderParams.maximum = 150
        FRscalarEncoderParams.minimum = 0
        FRscalarEncoderParams.size = 190
        FRscalarEncoderParams.activeBits = 15
        FRscalarEncoderParams.clipInput = True
        FRscalarEncoderParams.periodic = False
        FRscalarEncoder = ScalarEncoder(FRscalarEncoderParams)
        signal_encoders["Resp"] = (FRscalarEncoder, "Resp")
    
    if "SpO2" in selected_signals:
        SPO2scalarEncoderParams = ScalarEncoderParameters()
        SPO2scalarEncoderParams.maximum = 100
        SPO2scalarEncoderParams.minimum = 50
        SPO2scalarEncoderParams.size = 140
        SPO2scalarEncoderParams.activeBits = 21
        SPO2scalarEncoderParams.clipInput = True
        SPO2scalarEncoderParams.periodic = False
        SPO2scalarEncoder = ScalarEncoder(SPO2scalarEncoderParams)
        signal_encoders["SpO2"] = (SPO2scalarEncoder, "SpO2")
    
    if "ARTs" in selected_signals:
        ARTsEncoderParams = ScalarEncoderParameters()
        ARTsEncoderParams.maximum = 180  # adjust based on your data range
        ARTsEncoderParams.minimum = 80
        ARTsEncoderParams.size = 160
        ARTsEncoderParams.activeBits = 21
        ARTsEncoderParams.clipInput = True
        ARTsEncoderParams.periodic = False
        ARTsEncoder = ScalarEncoder(ARTsEncoderParams)
        signal_encoders["ARTs"] = (ARTsEncoder, "ARTs")
    
    if "ARTd" in selected_signals:
        ARTdEncoderParams = ScalarEncoderParameters()
        ARTdEncoderParams.maximum = 100  # adjust based on your data range
        ARTdEncoderParams.minimum = 40
        ARTdEncoderParams.size = 160
        ARTdEncoderParams.activeBits = 21
        ARTdEncoderParams.clipInput = True
        ARTdEncoderParams.periodic = False
        ARTdEncoder = ScalarEncoder(ARTdEncoderParams)
        signal_encoders["ARTd"] = (ARTdEncoder, "ARTd")
    
    # Calculate the total encoding width: Time always plus the chosen signals.
    encodingWidth = DateTimeEncoder.size + sum(encoder.size for encoder, _ in signal_encoders.values())
    enc_info = Metrics([encodingWidth], 999999999)

    # Make the HTM components (SpatialPooler & TemporalMemory):
    sp = SpatialPooler(
        inputDimensions=(encodingWidth,),
        columnDimensions=(params[0],),
        potentialPct=params[1],
        potentialRadius=params[2],
        globalInhibition=True,
        stimulusThreshold=params[3],
        localAreaDensity=0.02, 
        synPermInactiveDec=params[4],
        synPermActiveInc=params[5], 
        synPermConnected=params[6],
        boostStrength=params[7],
        wrapAround=False
    )
    sp_info = Metrics(sp.getColumnDimensions(), 999999999)

    tm = TemporalMemory(
        columnDimensions=(params[0],),
        cellsPerColumn=params[8], 
        activationThreshold=params[9], 
        initialPermanence=params[10], 
        connectedPermanence=params[11], 
        minThreshold=params[12],
        maxNewSynapseCount=params[13],
        permanenceIncrement=params[14],
        permanenceDecrement=params[15],
        predictedSegmentDecrement=params[16],
        maxSegmentsPerCell=params[17],
        maxSynapsesPerSegment=params[18]
    )
    tm_info = Metrics([tm.numberOfCells()], 999999999)

    # Initialize anomaly-related columns as float
    df['anomalySc'] = 0.0
    df['anomalyProb'] = 0.0
    df['anomalyLogProb'] = 0.0

    anomaly_history = AnomalyLikelihood()

    # Run the model for each record:
    for count, record in df.iterrows():
        
        # Encode time always.
        date_bits = DateTimeEncoder.encode(record['Time'])
        encoding_list = [date_bits]
        
        # Encode each selected signal.
        for key, (encoder, col_name) in signal_encoders.items():
            bits = encoder.encode(record[col_name])
            encoding_list.append(bits)
        
        # Concatenate all encoded bits into one SDR.
        encoding = SDR(encodingWidth).concatenate(encoding_list)
        enc_info.addData(encoding)
        
        activeColumns = SDR(sp.getColumnDimensions())
        sp.compute(encoding, True, activeColumns)
        sp_info.addData(activeColumns)
        
        tm.compute(activeColumns, learn=True)
        tm_info.addData(tm.getActiveCells().flatten())
        
        df.loc[count, 'anomalySc'] = tm.anomaly
        df.loc[count, 'anomalyLogProb'] = anomaly_history.get_log_likelihood(df.loc[count, 'anomalySc'])
    
    # Determine anomaly predictions.
    df['anom_pred'] = df['anomalyLogProb'].apply(lambda x: True if x > params[21] else False)
    
    for idx, row in anom_df.iterrows():
        anom_period = df.loc[(df['Time'] >= row['Start Time']) & (df['Time'] < row['End Time'])]
        alarms = [i for i, val in enumerate(anom_period.anom_pred) if val]
        if alarms:
            anom_df.loc[idx, 'cnt_pred'] = len(alarms)
            anom_df.loc[idx, 'max_anomLikelihood_pred'] = anom_period.iloc[alarms]['anomalyLogProb'].max()
            anom_df.loc[idx, 'time_pred'] = anom_period.iloc[alarms]['Time'].min()
            anom_df.loc[idx, 'anom_pred'] = 1
        else:
            anom_df.loc[idx, 'anom_pred'] = 0
    
    if search:
        anom_eval = anom_df[anom_df['Start Time'] > df.iloc[params[19]]['Time']]
        metricas = found_metrics(anom_eval['Anomaly'], anom_eval.anom_pred)
    
        params_dict = {
            'columnDimensions': params[0],
            'potentialPct': params[1],
            'potentialRadius': params[2],
            'stimulusThreshold': params[3],
            'synPermInactiveDec': params[4],
            'synPermActiveInc': params[5],
            'synPermConnected': params[6],
            'boostStrength': params[7],
            'cellsPerColumn': params[8],
            'activationThreshold': params[9],
            'initialPermanence': params[10],
            'connectedPermanence': params[11],
            'minThreshold': params[12],
            'maxNewSynapseCount': params[13],
            'permanenceIncrement': params[14],
            'permanenceDecrement': params[15],
            'predictedSegmentDecrement': params[16],
            'maxSegmentsPerCell': params[17],
            'maxSynapsesPerSegment': params[18],
            'anom_wait_n': params[19],
            'anom_window': params[20],
            'threshold': params[21],
            'selected_signals': selected_signals
        }
        return {**params_dict, **metricas}
    else:
        return {'monitor': df, 'anomalies': anom_df}

# %% [markdown]
# ### 4.2. Calcular Parejas Maximas

# %%
# Generate all combinations of 2 signals
vital_signs_combinations = list(itertools.combinations(studied_vital_signs, 2))
# combinations now contains:
# [('FC', 'SpO2'), ('FC', 'Resp'), ('FC', 'ARTs'), ('FC', 'ARTd'),
#  ('SpO2', 'Resp'), ('SpO2', 'ARTs'), ('SpO2', 'ARTd'),
#  ('Resp', 'ARTs'), ('Resp', 'ARTd'), ('ARTs', 'ARTd')]

# Dictionary to store anomalies for each pair
results = {}

# %%
paciente0.reset_index(inplace=True)
start_time = time.time()

# Loop through each combination, running the detection and storing anomalies
for pair in vital_signs_combinations:
    
    # Convert tuple to list for the selected_signals argument if needed
    selected_signals = list(pair)
    
    # Run detection for the current pair
    result = run_detection_pair(combinations[0], monitor=paciente0, anomalies=anomaly_df, selected_signals=selected_signals, search=False)
    
    # Save the anomalies using a key for clarity
    results[f'{pair[0]} y {pair[1]}'] = result['anomalies']

    
num_data_points = results1.shape[0] if hasattr(results1, 'shape') else len(results1)
execution_time = time.time() - start_time

print(f"Execution time: {execution_time:.2f} seconds")
print(f"Number of data points analyzed: {num_data_points*len(vital_signs_combinations)}")
# Out:
# Execution time: 56.77 seconds
# Number of data points analyzed: 3000

# %%
# Imprimir los resultados de las anomalías para cada par de señales
for pair, anomalies in results.items():
    print(f"Anomalías para el par {pair}:")
    print(anomalies)
    print("\n")
# Out:
# Anomalías para el par FC y SpO2:
#              Start Time            End Time  Anomaly Level  Anomaly  cnt_pred  \
# 0   2025-03-16 17:15:00 2025-03-16 17:17:00              0    False       2.0
# 1   2025-03-16 17:17:00 2025-03-16 17:19:00              0    False       NaN
# 2   2025-03-16 17:19:00 2025-03-16 17:21:00              0    False       NaN
# 3   2025-03-16 17:21:00 2025-03-16 17:23:00              2     True       NaN
# 4   2025-03-16 17:23:00 2025-03-16 17:25:00              2     True       NaN
# 5   2025-03-16 17:25:00 2025-03-16 17:27:00              0    False       NaN
# 6   2025-03-16 17:27:00 2025-03-16 17:29:00              0    False       NaN
# 7   2025-03-16 17:29:00 2025-03-16 17:31:00              0    False       NaN
# 8   2025-03-16 17:31:00 2025-03-16 17:33:00              1     True       NaN
# 9   2025-03-16 17:33:00 2025-03-16 17:35:00              1     True       NaN
# 10  2025-03-16 17:35:00 2025-03-16 17:37:00              1     True       NaN
# 11  2025-03-16 17:37:00 2025-03-16 17:39:00              2     True       NaN
# 12  2025-03-16 17:39:00 2025-03-16 17:41:00              2     True       NaN
# 13  2025-03-16 17:41:00 2025-03-16 17:43:00              2     True       NaN
# 14  2025-03-16 17:43:00 2025-03-16 17:45:00              2     True       NaN
# 15  2025-03-16 17:45:00 2025-03-16 17:47:00              3     True       NaN
# 16  2025-03-16 17:47:00 2025-03-16 17:49:00              1     True       NaN
# 17  2025-03-16 17:49:00 2025-03-16 17:51:00              2     True       NaN
# 18  2025-03-16 17:51:00 2025-03-16 17:53:00              1     True       NaN
# 19  2025-03-16 17:53:00 2025-03-16 17:55:00              1     True       NaN
# 20  2025-03-16 17:55:00 2025-03-16 17:57:00              0    False       NaN
# 21  2025-03-16 17:57:00 2025-03-16 17:59:00              1    False       NaN
# 22  2025-03-16 17:59:00 2025-03-16 18:01:00              0    False       NaN
# 23  2025-03-16 18:01:00 2025-03-16 18:03:00              0    False       NaN
# 24  2025-03-16 18:03:00 2025-03-16 18:05:00              0    False       NaN
# 25  2025-03-16 18:05:00 2025-03-16 18:07:00              0    False       NaN
# 26  2025-03-16 18:07:00 2025-03-16 18:09:00              0    False       NaN
# 27  2025-03-16 18:09:00 2025-03-16 18:11:00              0    False       NaN
# 28  2025-03-16 18:11:00 2025-03-16 18:13:00              0    False       NaN
# 29  2025-03-16 18:13:00 2025-03-16 18:15:00              0    False       NaN
# 30  2025-03-16 18:15:00 2025-03-16 18:17:00              0    False       NaN
# 31  2025-03-16 18:17:00 2025-03-16 18:19:00              1    False       NaN
# 32  2025-03-16 18:19:00 2025-03-16 18:21:00              0    False       NaN
# 33  2025-03-16 18:21:00 2025-03-16 18:23:00              0    False       NaN
# 34  2025-03-16 18:23:00 2025-03-16 18:25:00              0    False       NaN
# 35  2025-03-16 18:25:00 2025-03-16 18:27:00              0    False       NaN
# 36  2025-03-16 18:27:00 2025-03-16 18:29:00              0    False       NaN
# 37  2025-03-16 18:29:00 2025-03-16 18:31:00              0    False       NaN
# 38  2025-03-16 18:31:00 2025-03-16 18:33:00              0    False       NaN
# 39  2025-03-16 18:33:00 2025-03-16 18:35:00              2    False       NaN
# 40  2025-03-16 18:35:00 2025-03-16 18:37:00              0    False       NaN
# 41  2025-03-16 18:37:00 2025-03-16 18:39:00              0    False       NaN
# 42  2025-03-16 18:39:00 2025-03-16 18:41:00              2    False       NaN
# 43  2025-03-16 18:41:00 2025-03-16 18:43:00              0    False       NaN
# 44  2025-03-16 18:43:00 2025-03-16 18:45:00              0    False       NaN
# 45  2025-03-16 18:45:00 2025-03-16 18:47:00              0    False       NaN
# 46  2025-03-16 18:47:00 2025-03-16 18:49:00              0    False       NaN
# 47  2025-03-16 18:49:00 2025-03-16 18:51:00              0    False       NaN
# 48  2025-03-16 18:51:00 2025-03-16 18:53:00              0    False       NaN
# 49  2025-03-16 18:53:00 2025-03-16 18:55:00              0    False       NaN
# 50  2025-03-16 18:55:00 2025-03-16 18:57:00              0    False       NaN
# 51  2025-03-16 18:57:00 2025-03-16 18:59:00              0    False       NaN
# 52  2025-03-16 18:59:00 2025-03-16 19:01:00              0    False       NaN
# 53  2025-03-16 19:01:00 2025-03-16 19:03:00              0    False       NaN
# 54  2025-03-16 19:03:00 2025-03-16 19:05:00              0    False       NaN
# 55  2025-03-16 19:05:00 2025-03-16 19:07:00              0    False       NaN
# 56  2025-03-16 19:07:00 2025-03-16 19:09:00              0    False       NaN
# 57  2025-03-16 19:09:00 2025-03-16 19:11:00              0    False       NaN
# 58  2025-03-16 19:11:00 2025-03-16 19:13:00              0    False       NaN
# 59  2025-03-16 19:13:00 2025-03-16 19:15:00              0    False       NaN
# 60  2025-03-16 19:15:00 2025-03-16 19:17:00              0    False       NaN
# 61  2025-03-16 19:17:00 2025-03-16 19:19:00              0    False       NaN
# 62  2025-03-16 19:19:00 2025-03-16 19:21:00              1    False       NaN
# 63  2025-03-16 19:21:00 2025-03-16 19:23:00              0    False       NaN
# 64  2025-03-16 19:23:00 2025-03-16 19:25:00              0    False       NaN
# 65  2025-03-16 19:25:00 2025-03-16 19:27:00              0    False       NaN
# 66  2025-03-16 19:27:00 2025-03-16 19:29:00              0    False       NaN
# 67  2025-03-16 19:29:00 2025-03-16 19:31:00              0    False       NaN
# 68  2025-03-16 19:31:00 2025-03-16 19:33:00              0    False       NaN
# 69  2025-03-16 19:33:00 2025-03-16 19:35:00              0    False       NaN
# 70  2025-03-16 19:35:00 2025-03-16 19:37:00              0    False       NaN
# 71  2025-03-16 19:37:00 2025-03-16 19:39:00              0    False       NaN
# 72  2025-03-16 19:39:00 2025-03-16 19:41:00              0    False       NaN
# 73  2025-03-16 19:41:00 2025-03-16 19:43:00              0    False       NaN
# 74  2025-03-16 19:43:00 2025-03-16 19:45:00              1     True       NaN
# 75  2025-03-16 19:45:00 2025-03-16 19:47:00              1     True       NaN
# 76  2025-03-16 19:47:00 2025-03-16 19:49:00              0    False       NaN
# 77  2025-03-16 19:49:00 2025-03-16 19:51:00              0    False       NaN
# 78  2025-03-16 19:51:00 2025-03-16 19:53:00              2     True       NaN
# 79  2025-03-16 19:53:00 2025-03-16 19:55:00              1     True       NaN
# 80  2025-03-16 19:55:00 2025-03-16 19:57:00              1     True       NaN
# 81  2025-03-16 19:57:00 2025-03-16 19:59:00              0    False       NaN
# 82  2025-03-16 19:59:00 2025-03-16 20:01:00              0    False       NaN
# 83  2025-03-16 20:01:00 2025-03-16 20:03:00              0    False       NaN
# 84  2025-03-16 20:03:00 2025-03-16 20:05:00              0    False       NaN
# 85  2025-03-16 20:05:00 2025-03-16 20:07:00              0    False       NaN
# 86  2025-03-16 20:07:00 2025-03-16 20:09:00              0    False       NaN
# 87  2025-03-16 20:09:00 2025-03-16 20:11:00              1    False       NaN
# 88  2025-03-16 20:11:00 2025-03-16 20:13:00              0    False       NaN
# 89  2025-03-16 20:13:00 2025-03-16 20:15:00              1    False       NaN
# 90  2025-03-16 20:15:00 2025-03-16 20:17:00              0    False       NaN
# 91  2025-03-16 20:17:00 2025-03-16 20:19:00              0    False       NaN
# 92  2025-03-16 20:19:00 2025-03-16 20:21:00              0    False       NaN
# 93  2025-03-16 20:21:00 2025-03-16 20:23:00              1     True       NaN
# 94  2025-03-16 20:23:00 2025-03-16 20:25:00              1     True       NaN
# 95  2025-03-16 20:25:00 2025-03-16 20:27:00              2     True       NaN
# 96  2025-03-16 20:27:00 2025-03-16 20:29:00              2     True       NaN
# 97  2025-03-16 20:29:00 2025-03-16 20:31:00              2     True       NaN
# 98  2025-03-16 20:31:00 2025-03-16 20:33:00              1     True       NaN
# 99  2025-03-16 20:33:00 2025-03-16 20:35:00              1     True       NaN
# 100 2025-03-16 20:35:00 2025-03-16 20:37:00              1     True       NaN
# 101 2025-03-16 20:37:00 2025-03-16 20:39:00              2     True       NaN
# 102 2025-03-16 20:39:00 2025-03-16 20:41:00              1     True       NaN
# 103 2025-03-16 20:41:00 2025-03-16 20:43:00              1     True       NaN
# 104 2025-03-16 20:43:00 2025-03-16 20:45:00              2     True       NaN
# 105 2025-03-16 20:45:00 2025-03-16 20:47:00              1     True       NaN
# 106 2025-03-16 20:47:00 2025-03-16 20:49:00              1     True       NaN
# 107 2025-03-16 20:49:00 2025-03-16 20:51:00              1     True       NaN
# 108 2025-03-16 20:51:00 2025-03-16 20:53:00              1     True       NaN
# 109 2025-03-16 20:53:00 2025-03-16 20:55:00              2     True       NaN
# 110 2025-03-16 20:55:00 2025-03-16 20:57:00              1     True       NaN
# 111 2025-03-16 20:57:00 2025-03-16 20:59:00              1     True       NaN
# 112 2025-03-16 20:59:00 2025-03-16 21:01:00              1     True       NaN
# 113 2025-03-16 21:01:00 2025-03-16 21:03:00              2     True       NaN
# 114 2025-03-16 21:03:00 2025-03-16 21:05:00              1     True       NaN
# 115 2025-03-16 21:05:00 2025-03-16 21:07:00              2     True       NaN
# 116 2025-03-16 21:07:00 2025-03-16 21:09:00              2     True       NaN
# 117 2025-03-16 21:09:00 2025-03-16 21:11:00              1     True       NaN
# 118 2025-03-16 21:11:00 2025-03-16 21:13:00              1     True       NaN
# 119 2025-03-16 21:13:00 2025-03-16 21:15:00              2     True       NaN
# 120 2025-03-16 21:15:00 2025-03-16 21:17:00              1     True       NaN
# 121 2025-03-16 21:17:00 2025-03-16 21:19:00              2     True       NaN
# 122 2025-03-16 21:19:00 2025-03-16 21:21:00              2     True       NaN
# 123 2025-03-16 21:21:00 2025-03-16 21:23:00              2     True       NaN
# 124 2025-03-16 21:23:00 2025-03-16 21:25:00              1     True       NaN
# 125 2025-03-16 21:25:00 2025-03-16 21:27:00              1     True       NaN
# 126 2025-03-16 21:27:00 2025-03-16 21:29:00              1     True       NaN
# 127 2025-03-16 21:29:00 2025-03-16 21:31:00              2     True       NaN
# 128 2025-03-16 21:31:00 2025-03-16 21:33:00              2     True       NaN
# 129 2025-03-16 21:33:00 2025-03-16 21:35:00              2     True       NaN
# 130 2025-03-16 21:35:00 2025-03-16 21:37:00              2     True       NaN
# 131 2025-03-16 21:37:00 2025-03-16 21:39:00              2     True       NaN
# 132 2025-03-16 21:39:00 2025-03-16 21:41:00              2     True       NaN
# 133 2025-03-16 21:41:00 2025-03-16 21:43:00              1     True       NaN
# 134 2025-03-16 21:43:00 2025-03-16 21:45:00              1     True       NaN
# 135 2025-03-16 21:45:00 2025-03-16 21:47:00              2     True       NaN
# 136 2025-03-16 21:47:00 2025-03-16 21:49:00              2     True       NaN
# 137 2025-03-16 21:49:00 2025-03-16 21:51:00              2     True       NaN
# 138 2025-03-16 21:51:00 2025-03-16 21:53:00              2     True       NaN
# 139 2025-03-16 21:53:00 2025-03-16 21:55:00              1     True       NaN
# 140 2025-03-16 21:55:00 2025-03-16 21:57:00              2     True       NaN
# 141 2025-03-16 21:57:00 2025-03-16 21:59:00              2     True       NaN
# 142 2025-03-16 21:59:00 2025-03-16 22:01:00              2     True       NaN
# 143 2025-03-16 22:01:00 2025-03-16 22:03:00              2     True       NaN
# 144 2025-03-16 22:03:00 2025-03-16 22:05:00              2     True       NaN
# 145 2025-03-16 22:05:00 2025-03-16 22:07:00              2     True       1.0
# 146 2025-03-16 22:07:00 2025-03-16 22:09:00              2     True       NaN
# 147 2025-03-16 22:09:00 2025-03-16 22:11:00              2     True       NaN
# 148 2025-03-16 22:11:00 2025-03-16 22:13:00              2     True       NaN
# 149 2025-03-16 22:13:00 2025-03-16 22:15:00              1     True       NaN
# 150 2025-03-16 22:15:00 2025-03-16 22:17:00              1     True       NaN
# 151 2025-03-16 22:17:00 2025-03-16 22:19:00              2     True       NaN
# 152 2025-03-16 22:19:00 2025-03-16 22:21:00              1     True       NaN
# 153 2025-03-16 22:21:00 2025-03-16 22:23:00              2     True       NaN
# 154 2025-03-16 22:23:00 2025-03-16 22:25:00              2     True       NaN
# 155 2025-03-16 22:25:00 2025-03-16 22:27:00              2     True       NaN
# 156 2025-03-16 22:27:00 2025-03-16 22:29:00              2     True       NaN
# 157 2025-03-16 22:29:00 2025-03-16 22:31:00              1     True       NaN
# 158 2025-03-16 22:31:00 2025-03-16 22:33:00              1     True       NaN
# 159 2025-03-16 22:33:00 2025-03-16 22:35:00              1     True       NaN
# 160 2025-03-16 22:35:00 2025-03-16 22:37:00              1     True       NaN
# 161 2025-03-16 22:37:00 2025-03-16 22:39:00              2     True       NaN
# 162 2025-03-16 22:39:00 2025-03-16 22:41:00              1     True       NaN
# 163 2025-03-16 22:41:00 2025-03-16 22:43:00              1     True       NaN
# 164 2025-03-16 22:43:00 2025-03-16 22:45:00              1     True       NaN
# 165 2025-03-16 22:45:00 2025-03-16 22:47:00              1     True       NaN
# 166 2025-03-16 22:47:00 2025-03-16 22:49:00              1     True       NaN
# 167 2025-03-16 22:49:00 2025-03-16 22:51:00              1     True       NaN
# 168 2025-03-16 22:51:00 2025-03-16 22:53:00              2     True       NaN
# 169 2025-03-16 22:53:00 2025-03-16 22:55:00              2     True       NaN
# 170 2025-03-16 22:55:00 2025-03-16 22:57:00              1     True       NaN
# 171 2025-03-16 22:57:00 2025-03-16 22:59:00              1     True       NaN
# 172 2025-03-16 22:59:00 2025-03-16 23:01:00              2     True       NaN
# 173 2025-03-16 23:01:00 2025-03-16 23:03:00              2     True       NaN
# 174 2025-03-16 23:03:00 2025-03-16 23:05:00              2     True       NaN
# 175 2025-03-16 23:05:00 2025-03-16 23:07:00              2     True       NaN
# 176 2025-03-16 23:07:00 2025-03-16 23:09:00              2     True       NaN
# 177 2025-03-16 23:09:00 2025-03-16 23:11:00              2     True       NaN
# 178 2025-03-16 23:11:00 2025-03-16 23:13:00              2     True       NaN
# 179 2025-03-16 23:13:00 2025-03-16 23:15:00              2     True       NaN
# 180 2025-03-16 23:15:00 2025-03-16 23:17:00              2     True       NaN
# 181 2025-03-16 23:17:00 2025-03-16 23:19:00              2     True       NaN
# 182 2025-03-16 23:19:00 2025-03-16 23:21:00              1     True       NaN
# 183 2025-03-16 23:21:00 2025-03-16 23:23:00              2     True       NaN
# 184 2025-03-16 23:23:00 2025-03-16 23:25:00              2     True       NaN
# 185 2025-03-16 23:25:00 2025-03-16 23:27:00              2     True       NaN
# 186 2025-03-16 23:27:00 2025-03-16 23:29:00              2     True       NaN
# 187 2025-03-16 23:29:00 2025-03-16 23:31:00              2     True       NaN
# 188 2025-03-16 23:31:00 2025-03-16 23:33:00              2     True       NaN
# 189 2025-03-16 23:33:00 2025-03-16 23:35:00              1     True       NaN
# 190 2025-03-16 23:35:00 2025-03-16 23:37:00              1     True       NaN
# 191 2025-03-16 23:37:00 2025-03-16 23:39:00              1     True       NaN
# 192 2025-03-16 23:39:00 2025-03-16 23:41:00              1     True       NaN
# 193 2025-03-16 23:41:00 2025-03-16 23:43:00              1     True       NaN
# 194 2025-03-16 23:43:00 2025-03-16 23:45:00              2     True       NaN
# 195 2025-03-16 23:45:00 2025-03-16 23:47:00              2     True       NaN
# 196 2025-03-16 23:47:00 2025-03-16 23:49:00              2     True       NaN
# 197 2025-03-16 23:49:00 2025-03-16 23:51:00              2     True       NaN
# 198 2025-03-16 23:51:00 2025-03-16 23:53:00              2     True       NaN
# 199 2025-03-16 23:53:00 2025-03-16 23:55:00              2     True       NaN
# 200 2025-03-16 23:55:00 2025-03-16 23:57:00              2     True       NaN
# 201 2025-03-16 23:57:00 2025-03-16 23:59:00              1     True       NaN
# 202 2025-03-16 23:59:00 2025-03-17 00:01:00              2     True       NaN
# 203 2025-03-17 00:01:00 2025-03-17 00:03:00              2     True       NaN
# 204 2025-03-17 00:03:00 2025-03-17 00:05:00              2     True       NaN
# 205 2025-03-17 00:05:00 2025-03-17 00:07:00              2     True       NaN
# 206 2025-03-17 00:07:00 2025-03-17 00:09:00              2     True       NaN
# 207 2025-03-17 00:09:00 2025-03-17 00:11:00              2     True       NaN
# 208 2025-03-17 00:11:00 2025-03-17 00:13:00              2     True       NaN
# 209 2025-03-17 00:13:00 2025-03-17 00:15:00              2     True       NaN
# 210 2025-03-17 00:15:00 2025-03-17 00:17:00              1     True       NaN
# 211 2025-03-17 00:17:00 2025-03-17 00:19:00              2     True       NaN
# 212 2025-03-17 00:19:00 2025-03-17 00:21:00              2     True       NaN
# 213 2025-03-17 00:21:00 2025-03-17 00:23:00              2     True       NaN
# 214 2025-03-17 00:23:00 2025-03-17 00:25:00              2     True       NaN
# 215 2025-03-17 00:25:00 2025-03-17 00:27:00              2     True       NaN
# 216 2025-03-17 00:27:00 2025-03-17 00:29:00              0    False       NaN
# 217 2025-03-17 00:29:00 2025-03-17 00:31:00              2     True       NaN
# 218 2025-03-17 00:31:00 2025-03-17 00:33:00              2     True       NaN
# 219 2025-03-17 00:33:00 2025-03-17 00:35:00              3     True       NaN
# 220 2025-03-17 00:35:00 2025-03-17 00:37:00              3     True       NaN
# 221 2025-03-17 00:37:00 2025-03-17 00:39:00              2     True       NaN
# 222 2025-03-17 00:39:00 2025-03-17 00:41:00              2     True       NaN
# 223 2025-03-17 00:41:00 2025-03-17 00:43:00              2     True       NaN
# 224 2025-03-17 00:43:00 2025-03-17 00:45:00              2     True       NaN
# 225 2025-03-17 00:45:00 2025-03-17 00:47:00              1     True       NaN
# 226 2025-03-17 00:47:00 2025-03-17 00:49:00              2     True       NaN
# 227 2025-03-17 00:49:00 2025-03-17 00:51:00              2     True       NaN
# 228 2025-03-17 00:51:00 2025-03-17 00:53:00              3     True       NaN
# 229 2025-03-17 00:53:00 2025-03-17 00:55:00              3     True       NaN
# 230 2025-03-17 00:55:00 2025-03-17 00:57:00              2     True       NaN
# 231 2025-03-17 00:57:00 2025-03-17 00:59:00              2     True       NaN
# 232 2025-03-17 00:59:00 2025-03-17 01:01:00              2     True       NaN
# 233 2025-03-17 01:01:00 2025-03-17 01:03:00              2     True       NaN
# 234 2025-03-17 01:03:00 2025-03-17 01:05:00              2     True       NaN
# 235 2025-03-17 01:05:00 2025-03-17 01:07:00              2     True       1.0
# 236 2025-03-17 01:07:00 2025-03-17 01:09:00              2     True       NaN
# 237 2025-03-17 01:09:00 2025-03-17 01:11:00              2     True       NaN
# 238 2025-03-17 01:11:00 2025-03-17 01:13:00              3     True       NaN
# 239 2025-03-17 01:13:00 2025-03-17 01:15:00              2     True       NaN
# 240 2025-03-17 01:15:00 2025-03-17 01:17:00              1     True       NaN
# 241 2025-03-17 01:17:00 2025-03-17 01:19:00              1     True       NaN
# 242 2025-03-17 01:19:00 2025-03-17 01:21:00              0    False       NaN
# 243 2025-03-17 01:21:00 2025-03-17 01:23:00              0    False       NaN
# 244 2025-03-17 01:23:00 2025-03-17 01:25:00              1     True       NaN
# 245 2025-03-17 01:25:00 2025-03-17 01:27:00              1     True       NaN
# 246 2025-03-17 01:27:00 2025-03-17 01:29:00              1     True       NaN
# 247 2025-03-17 01:29:00 2025-03-17 01:31:00              2     True       NaN
# 248 2025-03-17 01:31:00 2025-03-17 01:33:00              1     True       NaN
# 249 2025-03-17 01:33:00 2025-03-17 01:35:00              1     True       NaN
# 250 2025-03-17 01:35:00 2025-03-17 01:37:00              1     True       NaN
# 251 2025-03-17 01:37:00 2025-03-17 01:39:00              1     True       NaN
# 252 2025-03-17 01:39:00 2025-03-17 01:41:00              1     True       NaN
# 253 2025-03-17 01:41:00 2025-03-17 01:43:00              1     True       NaN
# 254 2025-03-17 01:43:00 2025-03-17 01:45:00              2     True       NaN
# 255 2025-03-17 01:45:00 2025-03-17 01:47:00              2     True       NaN
# 256 2025-03-17 01:47:00 2025-03-17 01:49:00              1     True       NaN
# 257 2025-03-17 01:49:00 2025-03-17 01:51:00              1     True       NaN
# 258 2025-03-17 01:51:00 2025-03-17 01:53:00              1     True       NaN
# 259 2025-03-17 01:53:00 2025-03-17 01:55:00              1     True       NaN
# 260 2025-03-17 01:55:00 2025-03-17 01:57:00              1     True       NaN
# 261 2025-03-17 01:57:00 2025-03-17 01:59:00              2     True       NaN
# 262 2025-03-17 01:59:00 2025-03-17 02:01:00              2     True       NaN
# 263 2025-03-17 02:01:00 2025-03-17 02:03:00              2     True       NaN
# 264 2025-03-17 02:03:00 2025-03-17 02:05:00              1     True       NaN
# 265 2025-03-17 02:05:00 2025-03-17 02:07:00              3     True       NaN
# 266 2025-03-17 02:07:00 2025-03-17 02:09:00              0    False       NaN
# 267 2025-03-17 02:09:00 2025-03-17 02:11:00              1    False       NaN
# 268 2025-03-17 02:11:00 2025-03-17 02:13:00              0    False       NaN
# 269 2025-03-17 02:13:00 2025-03-17 02:15:00              0    False       NaN
# 270 2025-03-17 02:15:00 2025-03-17 02:17:00              0    False       NaN
# 271 2025-03-17 02:17:00 2025-03-17 02:19:00              0    False       NaN
# 272 2025-03-17 02:19:00 2025-03-17 02:21:00              3     True       NaN
# 273 2025-03-17 02:21:00 2025-03-17 02:23:00              1     True       NaN
# 274 2025-03-17 02:23:00 2025-03-17 02:25:00              3     True       NaN
# 275 2025-03-17 02:25:00 2025-03-17 02:27:00              0    False       NaN
# 276 2025-03-17 02:27:00 2025-03-17 02:29:00              0    False       NaN
# 277 2025-03-17 02:29:00 2025-03-17 02:31:00              3    False       NaN
# 278 2025-03-17 02:31:00 2025-03-17 02:33:00              0    False       NaN
# 279 2025-03-17 02:33:00 2025-03-17 02:35:00              0    False       NaN
# 280 2025-03-17 02:35:00 2025-03-17 02:37:00              1     True       NaN
# 281 2025-03-17 02:37:00 2025-03-17 02:39:00              1     True       NaN
# 282 2025-03-17 02:39:00 2025-03-17 02:41:00              1     True       NaN
# 283 2025-03-17 02:41:00 2025-03-17 02:43:00              1     True       NaN
# 284 2025-03-17 02:43:00 2025-03-17 02:45:00              0    False       NaN
# 285 2025-03-17 02:45:00 2025-03-17 02:47:00              0    False       NaN
# 286 2025-03-17 02:47:00 2025-03-17 02:49:00              2     True       NaN
# 287 2025-03-17 02:49:00 2025-03-17 02:51:00              2     True       NaN
# 288 2025-03-17 02:51:00 2025-03-17 02:53:00              0    False       NaN
# 289 2025-03-17 02:53:00 2025-03-17 02:55:00              2    False       NaN
# 290 2025-03-17 02:55:00 2025-03-17 02:57:00              0    False       NaN
# 291 2025-03-17 02:57:00 2025-03-17 02:59:00              2     True       1.0
# 292 2025-03-17 02:59:00 2025-03-17 03:01:00              2     True       1.0
# 293 2025-03-17 03:01:00 2025-03-17 03:03:00              4     True       NaN
# 294 2025-03-17 03:03:00 2025-03-17 03:05:00              1     True       1.0
# 295 2025-03-17 03:05:00 2025-03-17 03:07:00              1     True       NaN
# 296 2025-03-17 03:07:00 2025-03-17 03:09:00              3     True       NaN
# 297 2025-03-17 03:09:00 2025-03-17 03:11:00              0    False       NaN
# 298 2025-03-17 03:11:00 2025-03-17 03:13:00              2     True       NaN
# 299 2025-03-17 03:13:00 2025-03-17 03:15:00              2     True       NaN
# 300 2025-03-17 03:15:00 2025-03-17 03:17:00              3     True       NaN
# 301 2025-03-17 03:17:00 2025-03-17 03:19:00              3     True       NaN
# 302 2025-03-17 03:19:00 2025-03-17 03:21:00              3     True       NaN
# 303 2025-03-17 03:21:00 2025-03-17 03:23:00              3     True       NaN
# 304 2025-03-17 03:23:00 2025-03-17 03:25:00              3     True       NaN
# 305 2025-03-17 03:25:00 2025-03-17 03:27:00              2     True       NaN
# 306 2025-03-17 03:27:00 2025-03-17 03:29:00              2     True       NaN
# 307 2025-03-17 03:29:00 2025-03-17 03:31:00              2     True       NaN
# 308 2025-03-17 03:31:00 2025-03-17 03:33:00              3     True       NaN
# 309 2025-03-17 03:33:00 2025-03-17 03:35:00              1     True       NaN
# 310 2025-03-17 03:35:00 2025-03-17 03:37:00              3     True       NaN
# 311 2025-03-17 03:37:00 2025-03-17 03:39:00              2     True       NaN
# 312 2025-03-17 03:39:00 2025-03-17 03:41:00              1     True       NaN
# 313 2025-03-17 03:41:00 2025-03-17 03:43:00              1     True       NaN
# 314 2025-03-17 03:43:00 2025-03-17 03:45:00              1     True       NaN
# 315 2025-03-17 03:45:00 2025-03-17 03:47:00              0    False       NaN
# 316 2025-03-17 03:47:00 2025-03-17 03:49:00              1    False       NaN
# 317 2025-03-17 03:49:00 2025-03-17 03:51:00              0    False       NaN
# 318 2025-03-17 03:51:00 2025-03-17 03:53:00              1     True       NaN
# 319 2025-03-17 03:53:00 2025-03-17 03:55:00              2     True       NaN
# 320 2025-03-17 03:55:00 2025-03-17 03:57:00              0    False       NaN
# 321 2025-03-17 03:57:00 2025-03-17 03:59:00              1    False       NaN
# 322 2025-03-17 03:59:00 2025-03-17 04:01:00              0    False       NaN
# 323 2025-03-17 04:01:00 2025-03-17 04:03:00              1    False       NaN
# 324 2025-03-17 04:03:00 2025-03-17 04:05:00              0    False       NaN
# 325 2025-03-17 04:05:00 2025-03-17 04:07:00              2     True       NaN
# 326 2025-03-17 04:07:00 2025-03-17 04:09:00              1     True       NaN
# 327 2025-03-17 04:09:00 2025-03-17 04:11:00              1     True       NaN
# 328 2025-03-17 04:11:00 2025-03-17 04:13:00              1     True       1.0
# 329 2025-03-17 04:13:00 2025-03-17 04:15:00              0    False       1.0
# 330 2025-03-17 04:15:00 2025-03-17 04:17:00              1     True       1.0
# 331 2025-03-17 04:17:00 2025-03-17 04:19:00              1     True       1.0
# 332 2025-03-17 04:19:00 2025-03-17 04:21:00              1     True       NaN
# 333 2025-03-17 04:21:00 2025-03-17 04:23:00              3     True       NaN
# 334 2025-03-17 04:23:00 2025-03-17 04:25:00              2     True       NaN
# 335 2025-03-17 04:25:00 2025-03-17 04:27:00              1     True       NaN
# 336 2025-03-17 04:27:00 2025-03-17 04:29:00              0    False       NaN
# 337 2025-03-17 04:29:00 2025-03-17 04:31:00              2     True       NaN
# 338 2025-03-17 04:31:00 2025-03-17 04:33:00              3     True       NaN
# 339 2025-03-17 04:33:00 2025-03-17 04:35:00              0    False       NaN
# 340 2025-03-17 04:35:00 2025-03-17 04:37:00              1    False       NaN
# 341 2025-03-17 04:37:00 2025-03-17 04:39:00              0    False       NaN
# 342 2025-03-17 04:39:00 2025-03-17 04:41:00              1     True       NaN
# 343 2025-03-17 04:41:00 2025-03-17 04:43:00              1     True       NaN
# 344 2025-03-17 04:43:00 2025-03-17 04:45:00              1     True       NaN
# 345 2025-03-17 04:45:00 2025-03-17 04:47:00              0    False       1.0
# 346 2025-03-17 04:47:00 2025-03-17 04:49:00              1     True       NaN
# 347 2025-03-17 04:49:00 2025-03-17 04:51:00              2     True       NaN
# 348 2025-03-17 04:51:00 2025-03-17 04:53:00              0    False       NaN
# 349 2025-03-17 04:53:00 2025-03-17 04:55:00              0    False       1.0
# 350 2025-03-17 04:55:00 2025-03-17 04:57:00              0    False       1.0
# 351 2025-03-17 04:57:00 2025-03-17 04:59:00              0    False       NaN
# 352 2025-03-17 04:59:00 2025-03-17 05:01:00              1     True       NaN
# 353 2025-03-17 05:01:00 2025-03-17 05:03:00              1     True       NaN
# 354 2025-03-17 05:03:00 2025-03-17 05:05:00              0    False       NaN
# 355 2025-03-17 05:05:00 2025-03-17 05:07:00              0    False       NaN
# 356 2025-03-17 05:07:00 2025-03-17 05:09:00              0    False       NaN
# 357 2025-03-17 05:09:00 2025-03-17 05:11:00              0    False       NaN
# 358 2025-03-17 05:11:00 2025-03-17 05:13:00              0    False       NaN
# 359 2025-03-17 05:13:00 2025-03-17 05:15:00              0    False       NaN
# 360 2025-03-17 05:15:00 2025-03-17 05:17:00              1    False       NaN
# 361 2025-03-17 05:17:00 2025-03-17 05:19:00              0    False       NaN
# 362 2025-03-17 05:19:00 2025-03-17 05:21:00              0    False       NaN
# 363 2025-03-17 05:21:00 2025-03-17 05:23:00              0    False       NaN
# 364 2025-03-17 05:23:00 2025-03-17 05:25:00              0    False       NaN
# 365 2025-03-17 05:25:00 2025-03-17 05:27:00              1    False       NaN
# 366 2025-03-17 05:27:00 2025-03-17 05:29:00              0    False       NaN
# 367 2025-03-17 05:29:00 2025-03-17 05:31:00              0    False       NaN
# 368 2025-03-17 05:31:00 2025-03-17 05:33:00              0    False       NaN
# 369 2025-03-17 05:33:00 2025-03-17 05:35:00              0    False       NaN
# 370 2025-03-17 05:35:00 2025-03-17 05:37:00              0    False       NaN
# 371 2025-03-17 05:37:00 2025-03-17 05:39:00              0    False       NaN
# 372 2025-03-17 05:39:00 2025-03-17 05:41:00              0    False       NaN
# 373 2025-03-17 05:41:00 2025-03-17 05:43:00              0    False       NaN
# 374 2025-03-17 05:43:00 2025-03-17 05:45:00              2     True       NaN
# 375 2025-03-17 05:45:00 2025-03-17 05:47:00              1     True       NaN
# 376 2025-03-17 05:47:00 2025-03-17 05:49:00              0    False       NaN
# 377 2025-03-17 05:49:00 2025-03-17 05:51:00              1    False       NaN
# 378 2025-03-17 05:51:00 2025-03-17 05:53:00              0    False       NaN
# 379 2025-03-17 05:53:00 2025-03-17 05:55:00              0    False       NaN
# 380 2025-03-17 05:55:00 2025-03-17 05:57:00              1     True       NaN
# 381 2025-03-17 05:57:00 2025-03-17 05:59:00              1     True       1.0
# 382 2025-03-17 05:59:00 2025-03-17 06:01:00              1     True       NaN
# 383 2025-03-17 06:01:00 2025-03-17 06:03:00              2     True       NaN
# 384 2025-03-17 06:03:00 2025-03-17 06:05:00              1     True       1.0
# 385 2025-03-17 06:05:00 2025-03-17 06:07:00              1     True       NaN
# 386 2025-03-17 06:07:00 2025-03-17 06:09:00              1     True       1.0
# 387 2025-03-17 06:09:00 2025-03-17 06:11:00              1     True       NaN
# 388 2025-03-17 06:11:00 2025-03-17 06:13:00              1     True       NaN
# 389 2025-03-17 06:13:00 2025-03-17 06:15:00              1     True       NaN
# 390 2025-03-17 06:15:00 2025-03-17 06:17:00              2     True       NaN
# 391 2025-03-17 06:17:00 2025-03-17 06:19:00              0    False       NaN
# 392 2025-03-17 06:19:00 2025-03-17 06:21:00              1    False       NaN
# 393 2025-03-17 06:21:00 2025-03-17 06:23:00              0    False       NaN
# 394 2025-03-17 06:23:00 2025-03-17 06:25:00              1    False       NaN
# 395 2025-03-17 06:25:00 2025-03-17 06:27:00              0    False       1.0
# 396 2025-03-17 06:27:00 2025-03-17 06:29:00              0    False       NaN
# 397 2025-03-17 06:29:00 2025-03-17 06:31:00              0    False       NaN
# 398 2025-03-17 06:31:00 2025-03-17 06:33:00              1     True       NaN
# 399 2025-03-17 06:33:00 2025-03-17 06:35:00              1     True       NaN
# 400 2025-03-17 06:35:00 2025-03-17 06:37:00              0    False       1.0
# 401 2025-03-17 06:37:00 2025-03-17 06:39:00              0    False       NaN
# 402 2025-03-17 06:39:00 2025-03-17 06:41:00              2     True       NaN
# 403 2025-03-17 06:41:00 2025-03-17 06:43:00              1     True       NaN
# 404 2025-03-17 06:43:00 2025-03-17 06:45:00              2     True       NaN
# 405 2025-03-17 06:45:00 2025-03-17 06:47:00              0    False       NaN
# 406 2025-03-17 06:47:00 2025-03-17 06:49:00              0    False       NaN
# 407 2025-03-17 06:49:00 2025-03-17 06:51:00              0    False       NaN
# 408 2025-03-17 06:51:00 2025-03-17 06:53:00              1     True       NaN
# 409 2025-03-17 06:53:00 2025-03-17 06:55:00              2     True       NaN
# 410 2025-03-17 06:55:00 2025-03-17 06:57:00              2     True       NaN
# 411 2025-03-17 06:57:00 2025-03-17 06:59:00              0    False       NaN
# 412 2025-03-17 06:59:00 2025-03-17 07:01:00              1    False       NaN
# 413 2025-03-17 07:01:00 2025-03-17 07:03:00              0    False       NaN
# 414 2025-03-17 07:03:00 2025-03-17 07:05:00              1    False       NaN
# 415 2025-03-17 07:05:00 2025-03-17 07:07:00              0    False       NaN
# 416 2025-03-17 07:07:00 2025-03-17 07:09:00              0    False       NaN
# 417 2025-03-17 07:09:00 2025-03-17 07:11:00              0    False       NaN
# 418 2025-03-17 07:11:00 2025-03-17 07:13:00              0    False       NaN
# 419 2025-03-17 07:13:00 2025-03-17 07:15:00              0    False       NaN
# 420 2025-03-17 07:15:00 2025-03-17 07:17:00              0    False       NaN
# 421 2025-03-17 07:17:00 2025-03-17 07:19:00              0    False       NaN
# 422 2025-03-17 07:19:00 2025-03-17 07:21:00              0    False       NaN
# 423 2025-03-17 07:21:00 2025-03-17 07:23:00              0    False       NaN
# 424 2025-03-17 07:23:00 2025-03-17 07:25:00              1     True       NaN
# 425 2025-03-17 07:25:00 2025-03-17 07:27:00              1     True       NaN
# 426 2025-03-17 07:27:00 2025-03-17 07:29:00              0    False       NaN
# 427 2025-03-17 07:29:00 2025-03-17 07:31:00              0    False       NaN
# 428 2025-03-17 07:31:00 2025-03-17 07:33:00              0    False       NaN
# 429 2025-03-17 07:33:00 2025-03-17 07:35:00              0    False       NaN
# 430 2025-03-17 07:35:00 2025-03-17 07:37:00              1    False       NaN
# 431 2025-03-17 07:37:00 2025-03-17 07:39:00              0    False       NaN
# 432 2025-03-17 07:39:00 2025-03-17 07:41:00              0    False       NaN
# 433 2025-03-17 07:41:00 2025-03-17 07:43:00              0    False       NaN
# 434 2025-03-17 07:43:00 2025-03-17 07:45:00              0    False       1.0
# 435 2025-03-17 07:45:00 2025-03-17 07:47:00              0    False       NaN
# 436 2025-03-17 07:47:00 2025-03-17 07:49:00              3    False       1.0
# 437 2025-03-17 07:49:00 2025-03-17 07:51:00              0    False       1.0
# 438 2025-03-17 07:51:00 2025-03-17 07:53:00              0    False       NaN
# 439 2025-03-17 07:53:00 2025-03-17 07:55:00              0    False       NaN
# 440 2025-03-17 07:55:00 2025-03-17 07:57:00              0    False       NaN
# 441 2025-03-17 07:57:00 2025-03-17 07:59:00              0    False       NaN
# 442 2025-03-17 07:59:00 2025-03-17 08:01:00              0    False       NaN
# 443 2025-03-17 08:01:00 2025-03-17 08:03:00              0    False       NaN
# 444 2025-03-17 08:03:00 2025-03-17 08:05:00              0    False       NaN
# 445 2025-03-17 08:05:00 2025-03-17 08:07:00              0    False       NaN
# 446 2025-03-17 08:07:00 2025-03-17 08:09:00              0    False       NaN
# 447 2025-03-17 08:09:00 2025-03-17 08:11:00              0    False       NaN
# 448 2025-03-17 08:11:00 2025-03-17 08:13:00              0    False       NaN
# 449 2025-03-17 08:13:00 2025-03-17 08:15:00              0    False       NaN
# 450 2025-03-17 08:15:00 2025-03-17 08:17:00              0    False       NaN
# 451 2025-03-17 08:17:00 2025-03-17 08:19:00              0    False       NaN
# 452 2025-03-17 08:19:00 2025-03-17 08:21:00              0    False       NaN
# 453 2025-03-17 08:21:00 2025-03-17 08:23:00              2    False       1.0
# 454 2025-03-17 08:23:00 2025-03-17 08:25:00              0    False       NaN
# 455 2025-03-17 08:25:00 2025-03-17 08:27:00              0    False       NaN
# 456 2025-03-17 08:27:00 2025-03-17 08:29:00              0    False       NaN
# 457 2025-03-17 08:29:00 2025-03-17 08:31:00              0    False       NaN
# 458 2025-03-17 08:31:00 2025-03-17 08:33:00              0    False       NaN
# 459 2025-03-17 08:33:00 2025-03-17 08:35:00              0    False       NaN
# 460 2025-03-17 08:35:00 2025-03-17 08:37:00              0    False       NaN
# 461 2025-03-17 08:37:00 2025-03-17 08:39:00              0    False       NaN
# 462 2025-03-17 08:39:00 2025-03-17 08:41:00              0    False       NaN
# 463 2025-03-17 08:41:00 2025-03-17 08:43:00              2    False       1.0
# 464 2025-03-17 08:43:00 2025-03-17 08:45:00              0    False       NaN
# 465 2025-03-17 08:45:00 2025-03-17 08:47:00              1    False       1.0
# 466 2025-03-17 08:47:00 2025-03-17 08:49:00              0    False       1.0
# 467 2025-03-17 08:49:00 2025-03-17 08:51:00              0    False       NaN
# 468 2025-03-17 08:51:00 2025-03-17 08:53:00              2    False       NaN
# 469 2025-03-17 08:53:00 2025-03-17 08:55:00              0    False       NaN
# 470 2025-03-17 08:55:00 2025-03-17 08:57:00              1    False       NaN
# 471 2025-03-17 08:57:00 2025-03-17 08:59:00              0    False       NaN
# 472 2025-03-17 08:59:00 2025-03-17 09:01:00              0    False       NaN
# 473 2025-03-17 09:01:00 2025-03-17 09:03:00              0    False       1.0
# 474 2025-03-17 09:03:00 2025-03-17 09:05:00              0    False       NaN
# 475 2025-03-17 09:05:00 2025-03-17 09:07:00              0    False       NaN
# 476 2025-03-17 09:07:00 2025-03-17 09:09:00              0    False       NaN
# 477 2025-03-17 09:09:00 2025-03-17 09:11:00              0    False       NaN
# 478 2025-03-17 09:11:00 2025-03-17 09:13:00              0    False       NaN
# 479 2025-03-17 09:13:00 2025-03-17 09:15:00              0    False       NaN
# 480 2025-03-17 09:15:00 2025-03-17 09:17:00              0    False       NaN
# 481 2025-03-17 09:17:00 2025-03-17 09:19:00              0    False       NaN
# 482 2025-03-17 09:19:00 2025-03-17 09:21:00              1     True       NaN
# 483 2025-03-17 09:21:00 2025-03-17 09:23:00              2     True       NaN
# 484 2025-03-17 09:23:00 2025-03-17 09:25:00              1     True       NaN
# 485 2025-03-17 09:25:00 2025-03-17 09:27:00              1     True       NaN
# 486 2025-03-17 09:27:00 2025-03-17 09:29:00              1     True       NaN
# 487 2025-03-17 09:29:00 2025-03-17 09:31:00              2     True       NaN
# 488 2025-03-17 09:31:00 2025-03-17 09:33:00              2     True       NaN
# 489 2025-03-17 09:33:00 2025-03-17 09:35:00              0    False       NaN
# 490 2025-03-17 09:35:00 2025-03-17 09:37:00              2    False       NaN
# 491 2025-03-17 09:37:00 2025-03-17 09:39:00              0    False       NaN
# 492 2025-03-17 09:39:00 2025-03-17 09:41:00              0    False       NaN
# 493 2025-03-17 09:41:00 2025-03-17 09:43:00              2    False       NaN
# 494 2025-03-17 09:43:00 2025-03-17 09:45:00              0    False       NaN
# 495 2025-03-17 09:45:00 2025-03-17 09:47:00              0    False       NaN
# 496 2025-03-17 09:47:00 2025-03-17 09:49:00              1    False       NaN
# 497 2025-03-17 09:49:00 2025-03-17 09:51:00              0    False       NaN
# 498 2025-03-17 09:51:00 2025-03-17 09:53:00              0    False       NaN
# 499 2025-03-17 09:53:00 2025-03-17 09:55:00              0    False       NaN
#
#      max_anomLikelihood_pred           time_pred  anom_pred
# 0                   1.000000 2025-03-16 17:15:00        1.0
# 1                        NaN                 NaT        0.0
# 2                        NaN                 NaT        0.0
# 3                        NaN                 NaT        0.0
# 4                        NaN                 NaT        0.0
# 5                        NaN                 NaT        0.0
# 6                        NaN                 NaT        0.0
# 7                        NaN                 NaT        0.0
# 8                        NaN                 NaT        0.0
# 9                        NaN                 NaT        0.0
# 10                       NaN                 NaT        0.0
# 11                       NaN                 NaT        0.0
# 12                       NaN                 NaT        0.0
# 13                       NaN                 NaT        0.0
# 14                       NaN                 NaT        0.0
# 15                       NaN                 NaT        0.0
# 16                       NaN                 NaT        0.0
# 17                       NaN                 NaT        0.0
# 18                       NaN                 NaT        0.0
# 19                       NaN                 NaT        0.0
# 20                       NaN                 NaT        0.0
# 21                       NaN                 NaT        0.0
# 22                       NaN                 NaT        0.0
# 23                       NaN                 NaT        0.0
# 24                       NaN                 NaT        0.0
# 25                       NaN                 NaT        0.0
# 26                       NaN                 NaT        0.0
# 27                       NaN                 NaT        0.0
# 28                       NaN                 NaT        0.0
# 29                       NaN                 NaT        0.0
# 30                       NaN                 NaT        0.0
# 31                       NaN                 NaT        0.0
# 32                       NaN                 NaT        0.0
# 33                       NaN                 NaT        0.0
# 34                       NaN                 NaT        0.0
# 35                       NaN                 NaT        0.0
# 36                       NaN                 NaT        0.0
# 37                       NaN                 NaT        0.0
# 38                       NaN                 NaT        0.0
# 39                       NaN                 NaT        0.0
# 40                       NaN                 NaT        0.0
# 41                       NaN                 NaT        0.0
# 42                       NaN                 NaT        0.0
# 43                       NaN                 NaT        0.0
# 44                       NaN                 NaT        0.0
# 45                       NaN                 NaT        0.0
# 46                       NaN                 NaT        0.0
# 47                       NaN                 NaT        0.0
# 48                       NaN                 NaT        0.0
# 49                       NaN                 NaT        0.0
# 50                       NaN                 NaT        0.0
# 51                       NaN                 NaT        0.0
# 52                       NaN                 NaT        0.0
# 53                       NaN                 NaT        0.0
# 54                       NaN                 NaT        0.0
# 55                       NaN                 NaT        0.0
# 56                       NaN                 NaT        0.0
# 57                       NaN                 NaT        0.0
# 58                       NaN                 NaT        0.0
# 59                       NaN                 NaT        0.0
# 60                       NaN                 NaT        0.0
# 61                       NaN                 NaT        0.0
# 62                       NaN                 NaT        0.0
# 63                       NaN                 NaT        0.0
# 64                       NaN                 NaT        0.0
# 65                       NaN                 NaT        0.0
# 66                       NaN                 NaT        0.0
# 67                       NaN                 NaT        0.0
# 68                       NaN                 NaT        0.0
# 69                       NaN                 NaT        0.0
# 70                       NaN                 NaT        0.0
# 71                       NaN                 NaT        0.0
# 72                       NaN                 NaT        0.0
# 73                       NaN                 NaT        0.0
# 74                       NaN                 NaT        0.0
# 75                       NaN                 NaT        0.0
# 76                       NaN                 NaT        0.0
# 77                       NaN                 NaT        0.0
# 78                       NaN                 NaT        0.0
# 79                       NaN                 NaT        0.0
# 80                       NaN                 NaT        0.0
# 81                       NaN                 NaT        0.0
# 82                       NaN                 NaT        0.0
# 83                       NaN                 NaT        0.0
# 84                       NaN                 NaT        0.0
# 85                       NaN                 NaT        0.0
# 86                       NaN                 NaT        0.0
# 87                       NaN                 NaT        0.0
# 88                       NaN                 NaT        0.0
# 89                       NaN                 NaT        0.0
# 90                       NaN                 NaT        0.0
# 91                       NaN                 NaT        0.0
# 92                       NaN                 NaT        0.0
# 93                       NaN                 NaT        0.0
# 94                       NaN                 NaT        0.0
# 95                       NaN                 NaT        0.0
# 96                       NaN                 NaT        0.0
# 97                       NaN                 NaT        0.0
# 98                       NaN                 NaT        0.0
# 99                       NaN                 NaT        0.0
# 100                      NaN                 NaT        0.0
# 101                      NaN                 NaT        0.0
# 102                      NaN                 NaT        0.0
# 103                      NaN                 NaT        0.0
# 104                      NaN                 NaT        0.0
# 105                      NaN                 NaT        0.0
# 106                      NaN                 NaT        0.0
# 107                      NaN                 NaT        0.0
# 108                      NaN                 NaT        0.0
# 109                      NaN                 NaT        0.0
# 110                      NaN                 NaT        0.0
# 111                      NaN                 NaT        0.0
# 112                      NaN                 NaT        0.0
# 113                      NaN                 NaT        0.0
# 114                      NaN                 NaT        0.0
# 115                      NaN                 NaT        0.0
# 116                      NaN                 NaT        0.0
# 117                      NaN                 NaT        0.0
# ...
# 242                 0.112494 2025-03-17 01:20:00        1.0
# 243                      NaN                 NaT        0.0
# 244                 1.000000 2025-03-17 01:24:00        1.0
# 245                      NaN                 NaT        0.0
# 246                      NaN                 NaT        0.0
# 247                      NaN                 NaT        0.0
# 248                 1.000000 2025-03-17 01:31:00        1.0
# 249                      NaN                 NaT        0.0
# 250                      NaN                 NaT        0.0
# 251                      NaN                 NaT        0.0
# 252                 1.000000 2025-03-17 01:39:00        1.0
# 253                 1.000000 2025-03-17 01:41:00        1.0
# 254                 1.000000 2025-03-17 01:44:00        1.0
# 255                      NaN                 NaT        0.0
# 256                      NaN                 NaT        0.0
# 257                      NaN                 NaT        0.0
# 258                      NaN                 NaT        0.0
# 259                 0.160206 2025-03-17 01:53:00        1.0
# 260                 1.000000 2025-03-17 01:56:00        1.0
# 261                 1.000000 2025-03-17 01:57:00        1.0
# 262                 1.000000 2025-03-17 01:59:00        1.0
# 263                 0.160206 2025-03-17 02:01:00        1.0
# 264                 0.160206 2025-03-17 02:03:00        1.0
# 265                 1.000000 2025-03-17 02:05:00        1.0
# 266                      NaN                 NaT        0.0
# 267                      NaN                 NaT        0.0
# 268                      NaN                 NaT        0.0
# 269                      NaN                 NaT        0.0
# 270                      NaN                 NaT        0.0
# 271                      NaN                 NaT        0.0
# 272                 0.112494 2025-03-17 02:19:00        1.0
# 273                      NaN                 NaT        0.0
# 274                 0.130103 2025-03-17 02:24:00        1.0
# 275                      NaN                 NaT        0.0
# 276                 0.160206 2025-03-17 02:28:00        1.0
# 277                      NaN                 NaT        0.0
# 278                      NaN                 NaT        0.0
# 279                 0.112494 2025-03-17 02:33:00        1.0
# 280                 0.160206 2025-03-17 02:36:00        1.0
# 281                      NaN                 NaT        0.0
# 282                      NaN                 NaT        0.0
# 283                      NaN                 NaT        0.0
# 284                      NaN                 NaT        0.0
# 285                      NaN                 NaT        0.0
# 286                      NaN                 NaT        0.0
# 287                      NaN                 NaT        0.0
# 288                      NaN                 NaT        0.0
# 289                      NaN                 NaT        0.0
# 290                 1.000000 2025-03-17 02:56:00        1.0
# 291                 1.000000 2025-03-17 02:57:00        1.0
# 292                      NaN                 NaT        0.0
# 293                 1.000000 2025-03-17 03:02:00        1.0
# 294                      NaN                 NaT        0.0
# 295                      NaN                 NaT        0.0
# 296                      NaN                 NaT        0.0
# 297                      NaN                 NaT        0.0
# 298                      NaN                 NaT        0.0
# 299                      NaN                 NaT        0.0
# 300                      NaN                 NaT        0.0
# 301                      NaN                 NaT        0.0
# 302                      NaN                 NaT        0.0
# 303                      NaN                 NaT        0.0
# 304                      NaN                 NaT        0.0
# 305                      NaN                 NaT        0.0
# 306                      NaN                 NaT        0.0
# 307                      NaN                 NaT        0.0
# 308                      NaN                 NaT        0.0
# 309                      NaN                 NaT        0.0
# 310                      NaN                 NaT        0.0
# 311                      NaN                 NaT        0.0
# 312                      NaN                 NaT        0.0
# 313                      NaN                 NaT        0.0
# 314                      NaN                 NaT        0.0
# 315                      NaN                 NaT        0.0
# 316                      NaN                 NaT        0.0
# 317                      NaN                 NaT        0.0
# 318                      NaN                 NaT        0.0
# 319                      NaN                 NaT        0.0
# 320                      NaN                 NaT        0.0
# 321                      NaN                 NaT        0.0
# 322                      NaN                 NaT        0.0
# 323                      NaN                 NaT        0.0
# 324                      NaN                 NaT        0.0
# 325                      NaN                 NaT        0.0
# 326                      NaN                 NaT        0.0
# 327                 0.130103 2025-03-17 04:10:00        1.0
# 328                 0.130103 2025-03-17 04:12:00        1.0
# 329                 0.130103 2025-03-17 04:13:00        1.0
# 330                      NaN                 NaT        0.0
# 331                      NaN                 NaT        0.0
# 332                      NaN                 NaT        0.0
# 333                      NaN                 NaT        0.0
# 334                      NaN                 NaT        0.0
# 335                      NaN                 NaT        0.0
# 336                      NaN                 NaT        0.0
# 337                      NaN                 NaT        0.0
# 338                      NaN                 NaT        0.0
# 339                      NaN                 NaT        0.0
# 340                 1.000000 2025-03-17 04:35:00        1.0
# 341                      NaN                 NaT        0.0
# 342                      NaN                 NaT        0.0
# 343                 0.130103 2025-03-17 04:42:00        1.0
# 344                      NaN                 NaT        0.0
# 345                 0.160206 2025-03-17 04:45:00        1.0
# 346                 1.000000 2025-03-17 04:48:00        1.0
# 347                 0.130103 2025-03-17 04:49:00        1.0
# 348                 1.000000 2025-03-17 04:51:00        1.0
# 349                 0.112494 2025-03-17 04:53:00        1.0
# 350                      NaN                 NaT        0.0
# 351                      NaN                 NaT        0.0
# 352                      NaN                 NaT        0.0
# 353                      NaN                 NaT        0.0
# 354                      NaN                 NaT        0.0
# 355                 0.160206 2025-03-17 05:05:00        1.0
# 356                 0.130103 2025-03-17 05:07:00        1.0
# 357                      NaN                 NaT        0.0
# 358                 0.130103 2025-03-17 05:12:00        1.0
# 359                      NaN                 NaT        0.0
# 360                 1.000000 2025-03-17 05:16:00        1.0
# 361                      NaN                 NaT        0.0
# 362                      NaN                 NaT        0.0
# 363                      NaN                 NaT        0.0
# 364                      NaN                 NaT        0.0
# 365                      NaN                 NaT        0.0
# 366                 0.130103 2025-03-17 05:27:00        1.0
# 367                      NaN                 NaT        0.0
# 368                      NaN                 NaT        0.0
# 369                      NaN                 NaT        0.0
# 370                 0.112494 2025-03-17 05:35:00        1.0
# 371                      NaN                 NaT        0.0
# 372                      NaN                 NaT        0.0
# 373                      NaN                 NaT        0.0
# 374                 1.000000 2025-03-17 05:43:00        1.0
# 375                      NaN                 NaT        0.0
# 376                      NaN                 NaT        0.0
# 377                 0.112494 2025-03-17 05:49:00        1.0
# 378                      NaN                 NaT        0.0
# 379                      NaN                 NaT        0.0
# 380                      NaN                 NaT        0.0
# 381                      NaN                 NaT        0.0
# 382                 0.160206 2025-03-17 06:00:00        1.0
# 383                 1.000000 2025-03-17 06:01:00        1.0
# 384                      NaN                 NaT        0.0
# 385                 0.112494 2025-03-17 06:06:00        1.0
# 386                      NaN                 NaT        0.0
# 387                      NaN                 NaT        0.0
# 388                      NaN                 NaT        0.0
# 389                      NaN                 NaT        0.0
# 390                      NaN                 NaT        0.0
# 391                      NaN                 NaT        0.0
# 392                      NaN                 NaT        0.0
# 393                 0.112494 2025-03-17 06:21:00        1.0
# 394                 1.000000 2025-03-17 06:23:00        1.0
# 395                      NaN                 NaT        0.0
# 396                      NaN                 NaT        0.0
# 397                      NaN                 NaT        0.0
# 398                      NaN                 NaT        0.0
# 399                 0.160206 2025-03-17 06:34:00        1.0
# 400                 0.160206 2025-03-17 06:35:00        1.0
# 401                      NaN                 NaT        0.0
# 402                 1.000000 2025-03-17 06:40:00        1.0
# 403                      NaN                 NaT        0.0
# 404                      NaN                 NaT        0.0
# 405                      NaN                 NaT        0.0
# 406                      NaN                 NaT        0.0
# 407                      NaN                 NaT        0.0
# 408                 0.130103 2025-03-17 06:51:00        1.0
# 409                      NaN                 NaT        0.0
# 410                 1.000000 2025-03-17 06:56:00        1.0
# 411                      NaN                 NaT        0.0
# 412                      NaN                 NaT        0.0
# 413                      NaN                 NaT        0.0
# 414                      NaN                 NaT        0.0
# 415                 0.112494 2025-03-17 07:06:00        1.0
# 416                 0.160206 2025-03-17 07:07:00        1.0
# 417                      NaN                 NaT        0.0
# 418                      NaN                 NaT        0.0
# 419                 0.130103 2025-03-17 07:14:00        1.0
# 420                      NaN                 NaT        0.0
# 421                      NaN                 NaT        0.0
# 422                      NaN                 NaT        0.0
# 423                      NaN                 NaT        0.0
# 424                      NaN                 NaT        0.0
# 425                      NaN                 NaT        0.0
# 426                      NaN                 NaT        0.0
# 427                 0.130103 2025-03-17 07:30:00        1.0
# 428                      NaN                 NaT        0.0
# 429                      NaN                 NaT        0.0
# 430                 0.112494 2025-03-17 07:35:00        1.0
# 431                 0.130103 2025-03-17 07:37:00        1.0
# 432                      NaN                 NaT        0.0
# 433                      NaN                 NaT        0.0
# 434                 0.160206 2025-03-17 07:44:00        1.0
# 435                      NaN                 NaT        0.0
# 436                 1.000000 2025-03-17 07:47:00        1.0
# 437                 0.160206 2025-03-17 07:49:00        1.0
# 438                      NaN                 NaT        0.0
# 439                      NaN                 NaT        0.0
# 440                      NaN                 NaT        0.0
# 441                 0.160206 2025-03-17 07:57:00        1.0
# 442                      NaN                 NaT        0.0
# 443                      NaN                 NaT        0.0
# 444                 0.160206 2025-03-17 08:03:00        1.0
# 445                      NaN                 NaT        0.0
# 446                      NaN                 NaT        0.0
# 447                      NaN                 NaT        0.0
# 448                      NaN                 NaT        0.0
# 449                      NaN                 NaT        0.0
# 450                      NaN                 NaT        0.0
# 451                      NaN                 NaT        0.0
# 452                      NaN                 NaT        0.0
# 453                 0.130103 2025-03-17 08:21:00        1.0
# 454                      NaN                 NaT        0.0
# 455                 0.112494 2025-03-17 08:25:00        1.0
# 456                      NaN                 NaT        0.0
# 457                      NaN                 NaT        0.0
# 458                      NaN                 NaT        0.0
# 459                      NaN                 NaT        0.0
# 460                      NaN                 NaT        0.0
# 461                      NaN                 NaT        0.0
# 462                      NaN                 NaT        0.0
# 463                 0.130103 2025-03-17 08:42:00        1.0
# 464                 0.130103 2025-03-17 08:44:00        1.0
# 465                      NaN                 NaT        0.0
# 466                      NaN                 NaT        0.0
# 467                      NaN                 NaT        0.0
# 468                 0.130103 2025-03-17 08:52:00        1.0
# 469                      NaN                 NaT        0.0
# 470                 0.160206 2025-03-17 08:56:00        1.0
# 471                 0.130103 2025-03-17 08:58:00        1.0
# 472                      NaN                 NaT        0.0
# 473                      NaN                 NaT        0.0
# 474                      NaN                 NaT        0.0
# 475                      NaN                 NaT        0.0
# 476                      NaN                 NaT        0.0
# 477                      NaN                 NaT        0.0
# 478                      NaN                 NaT        0.0
# 479                      NaN                 NaT        0.0
# 480                      NaN                 NaT        0.0
# 481                      NaN                 NaT        0.0
# 482                      NaN                 NaT        0.0
# 483                 1.000000 2025-03-17 09:22:00        1.0
# 484                 0.130103 2025-03-17 09:23:00        1.0
# 485                 0.112494 2025-03-17 09:25:00        1.0
# 486                 0.112494 2025-03-17 09:27:00        1.0
# 487                 0.160206 2025-03-17 09:29:00        1.0
# 488                      NaN                 NaT        0.0
# 489                 0.112494 2025-03-17 09:33:00        1.0
# 490                 0.130103 2025-03-17 09:36:00        1.0
# 491                 0.130103 2025-03-17 09:37:00        1.0
# 492                      NaN                 NaT        0.0
# 493                 0.112494 2025-03-17 09:42:00        1.0
# 494                 0.160206 2025-03-17 09:44:00        1.0
# 495                      NaN                 NaT        0.0
# 496                      NaN                 NaT        0.0
# 497                      NaN                 NaT        0.0
# 498                      NaN                 NaT        0.0
# 499                      NaN                 NaT        0.0

# %%
# Post processing step: si un par de señales tiene una anomalia, pero esos dos signos vitales estan dentro del rango normal, entonces se elimina la anomalia, poniendo anom_pred a 0
def post_process_anomalies(results, normal_ranges):
    for pair, anomalies in results.items():
        for idx, row in anomalies.iterrows():
            # Check if the anomaly is predicted
            if row['anom_pred'] == 1:
                # Check if both vital signs are within normal ranges, only if both are in a normal range, change anom_pred to 0
                vital_signs = pair.split(' y ')
                print("Checking pair:", vital_signs)
                within_normal_range = True
                for vital_sign in vital_signs:
                    if vital_sign in normal_ranges:
                        
                        age_range = get_age_range(studied_patients_ages[0], vital_sign)
                        if age_range and age_range in normal_ranges[vital_sign]:
                            min_val, max_val = normal_ranges[vital_sign][age_range]
                            
                            # the actual value of the vital sings are in patient data, but we need to get the timestamp from the row
                            start_time = row['Start Time']
                            end_time = row['End Time']
                            # Filter the patient data to get the values at the start and end time
                            vital_sign_values = paciente0[(paciente0['Time'] >= start_time) & (paciente0['Time'] < end_time)][vital_sign]
                            
                            # if the vital sign has value Nan or is emtpy or zero, it cant be reported as an anomaly
                            if vital_sign_values.isnull().any() or vital_sign_values.empty or (vital_sign_values == 0).all():
                                within_normal_range = False
                                print(f"Anomaly for {pair} at index {idx} is not available for {vital_sign}.")
                                anomalies.at[idx, 'anom_pred'] = 0
                                break
                            
                            if not vital_sign_values.empty:
                                
                                # Check if all values are within the normal range
                                if not ((vital_sign_values >= min_val) & (vital_sign_values <= max_val)).all():
                                    within_normal_range = False
                                    print(f"Anomaly for {pair} at index {idx} is outside normal range for {vital_sign}.")
                                    break
                            else:
                                within_normal_range = False
                                print(f"No data available for {vital_sign} at the specified time range for anomaly {pair} at index {idx}, so it cant be reported as an anomaly.")
                                anomalies.at[idx, 'anom_pred'] = 0
                                                    
                        
                if within_normal_range:
                    print(f"Anomaly for {pair} at index {idx} is within normal range, setting anom_pred to 0.")
                    
                    anomalies.at[idx, 'anom_pred'] = 0
                    
    return results

results = post_process_anomalies(results, normal_ranges)
# Out:
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 0 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 145 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 235 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 291 is outside normal range for FC.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 292 is outside normal range for FC.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 294 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 328 is outside normal range for FC.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 329 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 330 is outside normal range for FC.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 331 is outside normal range for FC.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 345 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 349 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 350 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 381 is outside normal range for FC.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 384 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 386 is outside normal range for FC.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 395 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 400 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 434 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 436 is outside normal range for FC.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 437 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 453 is outside normal range for FC.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 463 is outside normal range for FC.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 465 is outside normal range for FC.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 466 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'SpO2']
# Anomaly for FC y SpO2 at index 473 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 0 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 4 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 5 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 113 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 145 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 216 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 226 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 228 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 229 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 230 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 232 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 234 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 235 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 237 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 238 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 239 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 244 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 259 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 260 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 261 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 262 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 275 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 279 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 292 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 293 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 294 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 329 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 330 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 340 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 347 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 348 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 349 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 355 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 385 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 386 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 394 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 400 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 408 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 416 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 434 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 436 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 437 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 441 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 443 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 445 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 453 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 463 is outside normal range for FC.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 464 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 466 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 469 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 484 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTs']
# Anomaly for FC y ARTs at index 488 is outside normal range for ARTs.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 0 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 1 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 4 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 15 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 43 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 113 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 127 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 132 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 143 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 144 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 145 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 147 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 149 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 155 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 156 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 159 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 177 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 187 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 229 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 235 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 238 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 239 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 244 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 248 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 259 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 260 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 261 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 262 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 263 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 266 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 272 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 275 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 277 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 278 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 279 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 281 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 291 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 292 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 293 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 297 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 324 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 328 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 329 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 330 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 341 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 345 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 347 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 348 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 349 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 355 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 358 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 373 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 374 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 381 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 384 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 385 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 386 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 394 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 395 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 399 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 400 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 407 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 408 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 416 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 417 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 419 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 427 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 434 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 436 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 437 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 439 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 443 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 444 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 445 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 446 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 449 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 453 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 460 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 461 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 462 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 463 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 465 is outside normal range for FC.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 466 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 467 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 468 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 469 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 470 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 471 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 473 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 474 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 475 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 476 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 477 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 478 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 479 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 480 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 483 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 484 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 486 is within normal range, setting anom_pred to 0.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 487 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 488 is outside normal range for ARTd.
# Checking pair: ['FC', 'ARTd']
# Anomaly for FC y ARTd at index 491 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 0 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 4 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 5 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 11 is outside normal range for SpO2.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 13 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 15 is outside normal range for SpO2.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 50 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 94 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 95 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 97 is outside normal range for SpO2.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 98 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 101 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 105 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 111 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 113 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 116 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 118 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 121 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 127 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 133 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 135 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 138 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 139 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 140 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 143 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 147 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 150 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 151 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 152 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 155 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 156 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 157 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 158 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 159 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 160 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 169 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 170 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 171 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 177 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 180 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 182 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 184 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 185 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 187 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 188 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 192 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 195 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 196 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 197 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 198 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 200 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 201 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 206 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 207 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 216 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 217 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 220 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 222 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 226 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 228 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 229 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 230 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 244 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 254 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 261 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 262 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 263 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 264 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 265 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 266 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 272 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 273 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 274 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 291 is outside normal range for SpO2.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 292 is outside normal range for SpO2.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 293 is outside normal range for SpO2.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 297 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 344 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 347 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 348 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 349 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 374 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 383 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 400 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 436 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 437 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 444 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 453 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 463 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 469 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 483 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 484 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 487 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 488 is outside normal range for ARTs.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 489 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 494 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTs']
# Anomaly for SpO2 y ARTs at index 497 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 0 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 6 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 11 is outside normal range for SpO2.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 12 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 13 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 15 is outside normal range for SpO2.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 16 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 98 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 113 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 122 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 133 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 137 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 138 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 139 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 140 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 143 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 146 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 148 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 155 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 156 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 159 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 160 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 170 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 177 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 184 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 187 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 195 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 197 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 200 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 202 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 207 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 210 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 218 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 226 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 227 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 228 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 229 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 230 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 231 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 236 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 237 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 239 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 244 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 248 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 249 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 252 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 253 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 255 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 256 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 260 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 261 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 262 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 263 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 264 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 265 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 266 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 272 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 273 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 274 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 275 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 276 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 277 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 278 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 279 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 282 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 284 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 286 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 289 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 290 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 291 is outside normal range for SpO2.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 292 is outside normal range for SpO2.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 293 is outside normal range for SpO2.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 294 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 297 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 324 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 329 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 338 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 344 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 345 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 346 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 347 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 348 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 349 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 350 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 355 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 358 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 362 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 364 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 374 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 375 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 385 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 386 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 389 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 391 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 394 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 400 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 417 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 427 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 434 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 436 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 444 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 449 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 460 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 464 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 471 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 478 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 479 is within normal range, setting anom_pred to 0.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 488 is outside normal range for ARTd.
# Checking pair: ['SpO2', 'ARTd']
# Anomaly for SpO2 y ARTd at index 491 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 0 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 1 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 3 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 4 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 6 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 9 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 10 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 15 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 20 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 22 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 23 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 25 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 35 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 42 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 43 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 46 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 49 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 61 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 78 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 81 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 101 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 105 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 109 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 113 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 116 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 123 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 124 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 125 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 127 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 132 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 138 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 143 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 144 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 145 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 146 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 147 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 149 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 150 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 151 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 153 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 154 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 155 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 156 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 157 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 158 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 160 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 163 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 164 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 165 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 167 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 168 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 171 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 172 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 176 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 177 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 178 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 180 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 184 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 185 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 187 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 188 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 189 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 190 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 191 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 192 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 193 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 195 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 196 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 197 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 198 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 200 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 202 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 203 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 204 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 205 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 206 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 207 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 208 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 209 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 210 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 212 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 213 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 214 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 216 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 217 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 218 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 220 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 221 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 222 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 225 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 226 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 228 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 229 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 230 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 231 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 233 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 234 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 238 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 239 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 240 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 241 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 242 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 244 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 248 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 252 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 253 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 254 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 259 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 260 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 261 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 262 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 263 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 264 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 265 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 272 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 274 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 276 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 279 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 280 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 290 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 291 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 293 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 327 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 328 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 329 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 340 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 343 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 345 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 346 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 347 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 348 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 349 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 355 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 356 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 358 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 360 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 366 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 370 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 374 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 377 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 382 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 383 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 385 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 393 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 394 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 399 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 400 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 402 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 408 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 410 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 415 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 416 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 419 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 427 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 430 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 431 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 434 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 436 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 437 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 441 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 444 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 453 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 455 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 463 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 464 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 468 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 470 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 471 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 483 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 484 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 485 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 486 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 487 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 489 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 490 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 491 is within normal range, setting anom_pred to 0.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 493 is outside normal range for ARTs.
# Checking pair: ['ARTs', 'ARTd']
# Anomaly for ARTs y ARTd at index 494 is within normal range, setting anom_pred to 0.

# %% [markdown]
# ## 5. Composición de modelos Para la nueva Arquitectura

# %% [markdown]
# ### 5.1. Estrategia 1: Utilizar el modelo de mayor confianza como representante de la anomalia.

# %% [markdown]
# OBJETIVO: Lo que buscan los medicos es buscar que conjunto de señales están mal/se están poniendo mal, esto les permite afirmar "que señales influyen mas en la condición del paciente" y tratarlo acorde a estos resultados
#
# SOLUCIÓN: podemos afirmar que la pareja de señales que se está poniendo peor es aquella que reporta una anomalia con mayor confianza.

# %%
import pandas as pd

# Step 1: Add a new column to each dataframe indicating the pair name.
dfs = [df.assign(Pair=pair) for pair, df in results.items()]

# Step 2: Combine all dataframes into one.
combined_df = pd.concat(dfs, ignore_index=True)

# Step 3: Identify unique time windows based on 'Start Time' and 'End Time'.
time_windows = combined_df[['Start Time', 'End Time']].drop_duplicates()

# Step 4: For each time window, find the row with the highest anomaly confidence,
#         or set default values if all anomaly probabilities are NaN.
final_rows = []  # To store the selected row information for each time window.
for _, time_window in time_windows.iterrows():
    start_time = time_window['Start Time']
    end_time = time_window['End Time']
    
    # Filter combined_df to the current time window.
    window_df = combined_df[(combined_df['Start Time'] == start_time) &
                              (combined_df['End Time'] == end_time)]
    
    # Count the number of pairs reporting an anomaly (where Anomaly is True)
    anomaly_count = window_df['anom_pred'].sum()  # True values count as 1
    
    if not window_df.empty:
        # Check if all values in "max_anomLikelihood_pred" are NaN.
        if window_df['max_anomLikelihood_pred'].isna().all():
            final_rows.append({
                'Start Time': start_time,
                'End Time': end_time,
                'Pair': "None",
                'Anomaly Level': 0,
                'Confidence': 0,
                'Anomaly Count': anomaly_count
            })
        else:
            # Select the row with the highest anomaly probability.
            best_idx = window_df['max_anomLikelihood_pred'].idxmax()
            best_row = window_df.loc[best_idx]
            final_rows.append({
                'Start Time': start_time,
                'End Time': end_time,
                'Pair': best_row['Pair'],
                'Anomaly Level': best_row['Anomaly Level'],
                'Confidence': best_row['max_anomLikelihood_pred'],
                'Anomaly Count': anomaly_count
            })

# Step 5: Create the final combined dataframe from the collected rows.
results_combined = pd.DataFrame(final_rows)

# Optionally, sort the final results by start time for clarity.
results_combined.sort_values('Start Time', inplace=True)

print(results_combined)
# Out:
#              Start Time            End Time         Pair  Anomaly Level  \
# 0   2025-03-16 17:15:00 2025-03-16 17:17:00    FC y SpO2              0
# 1   2025-03-16 17:17:00 2025-03-16 17:19:00    FC y ARTd              0
# 2   2025-03-16 17:19:00 2025-03-16 17:21:00         None              0
# 3   2025-03-16 17:21:00 2025-03-16 17:23:00  ARTs y ARTd              2
# 4   2025-03-16 17:23:00 2025-03-16 17:25:00    FC y ARTs              2
# 5   2025-03-16 17:25:00 2025-03-16 17:27:00    FC y ARTs              0
# 6   2025-03-16 17:27:00 2025-03-16 17:29:00  ARTs y ARTd              0
# 7   2025-03-16 17:29:00 2025-03-16 17:31:00         None              0
# 8   2025-03-16 17:31:00 2025-03-16 17:33:00         None              0
# 9   2025-03-16 17:33:00 2025-03-16 17:35:00  ARTs y ARTd              1
# 10  2025-03-16 17:35:00 2025-03-16 17:37:00  ARTs y ARTd              1
# 11  2025-03-16 17:37:00 2025-03-16 17:39:00  SpO2 y ARTs              2
# 12  2025-03-16 17:39:00 2025-03-16 17:41:00  SpO2 y ARTd              2
# 13  2025-03-16 17:41:00 2025-03-16 17:43:00  SpO2 y ARTs              2
# 14  2025-03-16 17:43:00 2025-03-16 17:45:00         None              0
# 15  2025-03-16 17:45:00 2025-03-16 17:47:00    FC y ARTd              3
# 16  2025-03-16 17:47:00 2025-03-16 17:49:00  SpO2 y ARTd              1
# 17  2025-03-16 17:49:00 2025-03-16 17:51:00         None              0
# 18  2025-03-16 17:51:00 2025-03-16 17:53:00         None              0
# 19  2025-03-16 17:53:00 2025-03-16 17:55:00         None              0
# 20  2025-03-16 17:55:00 2025-03-16 17:57:00  ARTs y ARTd              0
# 21  2025-03-16 17:57:00 2025-03-16 17:59:00         None              0
# 22  2025-03-16 17:59:00 2025-03-16 18:01:00  ARTs y ARTd              0
# 23  2025-03-16 18:01:00 2025-03-16 18:03:00  ARTs y ARTd              0
# 24  2025-03-16 18:03:00 2025-03-16 18:05:00         None              0
# 25  2025-03-16 18:05:00 2025-03-16 18:07:00  ARTs y ARTd              0
# 26  2025-03-16 18:07:00 2025-03-16 18:09:00         None              0
# 27  2025-03-16 18:09:00 2025-03-16 18:11:00         None              0
# 28  2025-03-16 18:11:00 2025-03-16 18:13:00         None              0
# 29  2025-03-16 18:13:00 2025-03-16 18:15:00         None              0
# 30  2025-03-16 18:15:00 2025-03-16 18:17:00         None              0
# 31  2025-03-16 18:17:00 2025-03-16 18:19:00         None              0
# 32  2025-03-16 18:19:00 2025-03-16 18:21:00         None              0
# 33  2025-03-16 18:21:00 2025-03-16 18:23:00         None              0
# 34  2025-03-16 18:23:00 2025-03-16 18:25:00         None              0
# 35  2025-03-16 18:25:00 2025-03-16 18:27:00  ARTs y ARTd              0
# 36  2025-03-16 18:27:00 2025-03-16 18:29:00         None              0
# 37  2025-03-16 18:29:00 2025-03-16 18:31:00         None              0
# 38  2025-03-16 18:31:00 2025-03-16 18:33:00         None              0
# 39  2025-03-16 18:33:00 2025-03-16 18:35:00         None              0
# 40  2025-03-16 18:35:00 2025-03-16 18:37:00         None              0
# 41  2025-03-16 18:37:00 2025-03-16 18:39:00         None              0
# 42  2025-03-16 18:39:00 2025-03-16 18:41:00  ARTs y ARTd              2
# 43  2025-03-16 18:41:00 2025-03-16 18:43:00    FC y ARTd              0
# 44  2025-03-16 18:43:00 2025-03-16 18:45:00         None              0
# 45  2025-03-16 18:45:00 2025-03-16 18:47:00         None              0
# 46  2025-03-16 18:47:00 2025-03-16 18:49:00  ARTs y ARTd              0
# 47  2025-03-16 18:49:00 2025-03-16 18:51:00         None              0
# 48  2025-03-16 18:51:00 2025-03-16 18:53:00         None              0
# 49  2025-03-16 18:53:00 2025-03-16 18:55:00  ARTs y ARTd              0
# 50  2025-03-16 18:55:00 2025-03-16 18:57:00  SpO2 y ARTs              0
# 51  2025-03-16 18:57:00 2025-03-16 18:59:00         None              0
# 52  2025-03-16 18:59:00 2025-03-16 19:01:00         None              0
# 53  2025-03-16 19:01:00 2025-03-16 19:03:00         None              0
# 54  2025-03-16 19:03:00 2025-03-16 19:05:00         None              0
# 55  2025-03-16 19:05:00 2025-03-16 19:07:00         None              0
# 56  2025-03-16 19:07:00 2025-03-16 19:09:00         None              0
# 57  2025-03-16 19:09:00 2025-03-16 19:11:00         None              0
# 58  2025-03-16 19:11:00 2025-03-16 19:13:00         None              0
# 59  2025-03-16 19:13:00 2025-03-16 19:15:00         None              0
# 60  2025-03-16 19:15:00 2025-03-16 19:17:00         None              0
# 61  2025-03-16 19:17:00 2025-03-16 19:19:00  ARTs y ARTd              0
# 62  2025-03-16 19:19:00 2025-03-16 19:21:00         None              0
# 63  2025-03-16 19:21:00 2025-03-16 19:23:00         None              0
# 64  2025-03-16 19:23:00 2025-03-16 19:25:00         None              0
# 65  2025-03-16 19:25:00 2025-03-16 19:27:00         None              0
# 66  2025-03-16 19:27:00 2025-03-16 19:29:00         None              0
# 67  2025-03-16 19:29:00 2025-03-16 19:31:00         None              0
# 68  2025-03-16 19:31:00 2025-03-16 19:33:00         None              0
# 69  2025-03-16 19:33:00 2025-03-16 19:35:00         None              0
# 70  2025-03-16 19:35:00 2025-03-16 19:37:00         None              0
# 71  2025-03-16 19:37:00 2025-03-16 19:39:00         None              0
# 72  2025-03-16 19:39:00 2025-03-16 19:41:00         None              0
# 73  2025-03-16 19:41:00 2025-03-16 19:43:00         None              0
# 74  2025-03-16 19:43:00 2025-03-16 19:45:00         None              0
# 75  2025-03-16 19:45:00 2025-03-16 19:47:00         None              0
# 76  2025-03-16 19:47:00 2025-03-16 19:49:00         None              0
# 77  2025-03-16 19:49:00 2025-03-16 19:51:00         None              0
# 78  2025-03-16 19:51:00 2025-03-16 19:53:00  ARTs y ARTd              2
# 79  2025-03-16 19:53:00 2025-03-16 19:55:00         None              0
# 80  2025-03-16 19:55:00 2025-03-16 19:57:00         None              0
# 81  2025-03-16 19:57:00 2025-03-16 19:59:00  ARTs y ARTd              0
# 82  2025-03-16 19:59:00 2025-03-16 20:01:00         None              0
# 83  2025-03-16 20:01:00 2025-03-16 20:03:00         None              0
# 84  2025-03-16 20:03:00 2025-03-16 20:05:00         None              0
# 85  2025-03-16 20:05:00 2025-03-16 20:07:00         None              0
# 86  2025-03-16 20:07:00 2025-03-16 20:09:00         None              0
# 87  2025-03-16 20:09:00 2025-03-16 20:11:00         None              0
# 88  2025-03-16 20:11:00 2025-03-16 20:13:00         None              0
# 89  2025-03-16 20:13:00 2025-03-16 20:15:00         None              0
# 90  2025-03-16 20:15:00 2025-03-16 20:17:00         None              0
# 91  2025-03-16 20:17:00 2025-03-16 20:19:00         None              0
# 92  2025-03-16 20:19:00 2025-03-16 20:21:00         None              0
# 93  2025-03-16 20:21:00 2025-03-16 20:23:00         None              0
# 94  2025-03-16 20:23:00 2025-03-16 20:25:00  SpO2 y ARTs              1
# 95  2025-03-16 20:25:00 2025-03-16 20:27:00  SpO2 y ARTs              2
# 96  2025-03-16 20:27:00 2025-03-16 20:29:00         None              0
# 97  2025-03-16 20:29:00 2025-03-16 20:31:00  SpO2 y ARTs              2
# 98  2025-03-16 20:31:00 2025-03-16 20:33:00  SpO2 y ARTs              1
# 99  2025-03-16 20:33:00 2025-03-16 20:35:00         None              0
# 100 2025-03-16 20:35:00 2025-03-16 20:37:00         None              0
# 101 2025-03-16 20:37:00 2025-03-16 20:39:00  ARTs y ARTd              2
# 102 2025-03-16 20:39:00 2025-03-16 20:41:00         None              0
# 103 2025-03-16 20:41:00 2025-03-16 20:43:00         None              0
# 104 2025-03-16 20:43:00 2025-03-16 20:45:00         None              0
# 105 2025-03-16 20:45:00 2025-03-16 20:47:00  SpO2 y ARTs              1
# 106 2025-03-16 20:47:00 2025-03-16 20:49:00         None              0
# 107 2025-03-16 20:49:00 2025-03-16 20:51:00         None              0
# 108 2025-03-16 20:51:00 2025-03-16 20:53:00         None              0
# 109 2025-03-16 20:53:00 2025-03-16 20:55:00  ARTs y ARTd              2
# 110 2025-03-16 20:55:00 2025-03-16 20:57:00         None              0
# 111 2025-03-16 20:57:00 2025-03-16 20:59:00  SpO2 y ARTs              1
# 112 2025-03-16 20:59:00 2025-03-16 21:01:00         None              0
# 113 2025-03-16 21:01:00 2025-03-16 21:03:00    FC y ARTs              2
# 114 2025-03-16 21:03:00 2025-03-16 21:05:00         None              0
# 115 2025-03-16 21:05:00 2025-03-16 21:07:00         None              0
# 116 2025-03-16 21:07:00 2025-03-16 21:09:00  ARTs y ARTd              2
# 117 2025-03-16 21:09:00 2025-03-16 21:11:00         None              0
# 118 2025-03-16 21:11:00 2025-03-16 21:13:00  SpO2 y ARTs              1
# 119 2025-03-16 21:13:00 2025-03-16 21:15:00         None              0
# 120 2025-03-16 21:15:00 2025-03-16 21:17:00         None              0
# 121 2025-03-16 21:17:00 2025-03-16 21:19:00  SpO2 y ARTs              2
# 122 2025-03-16 21:19:00 2025-03-16 21:21:00  SpO2 y ARTd              2
# 123 2025-03-16 21:21:00 2025-03-16 21:23:00  ARTs y ARTd              2
# 124 2025-03-16 21:23:00 2025-03-16 21:25:00  ARTs y ARTd              1
# 125 2025-03-16 21:25:00 2025-03-16 21:27:00  ARTs y ARTd              1
# 126 2025-03-16 21:27:00 2025-03-16 21:29:00         None              0
# 127 2025-03-16 21:29:00 2025-03-16 21:31:00    FC y ARTd              2
# 128 2025-03-16 21:31:00 2025-03-16 21:33:00         None              0
# 129 2025-03-16 21:33:00 2025-03-16 21:35:00         None              0
# 130 2025-03-16 21:35:00 2025-03-16 21:37:00         None              0
# 131 2025-03-16 21:37:00 2025-03-16 21:39:00         None              0
# 132 2025-03-16 21:39:00 2025-03-16 21:41:00  ARTs y ARTd              2
# 133 2025-03-16 21:41:00 2025-03-16 21:43:00  SpO2 y ARTs              1
# 134 2025-03-16 21:43:00 2025-03-16 21:45:00         None              0
# 135 2025-03-16 21:45:00 2025-03-16 21:47:00  SpO2 y ARTs              2
# 136 2025-03-16 21:47:00 2025-03-16 21:49:00         None              0
# 137 2025-03-16 21:49:00 2025-03-16 21:51:00  SpO2 y ARTd              2
# 138 2025-03-16 21:51:00 2025-03-16 21:53:00  SpO2 y ARTd              2
# 139 2025-03-16 21:53:00 2025-03-16 21:55:00  SpO2 y ARTs              1
# 140 2025-03-16 21:55:00 2025-03-16 21:57:00  SpO2 y ARTs              2
# 141 2025-03-16 21:57:00 2025-03-16 21:59:00         None              0
# 142 2025-03-16 21:59:00 2025-03-16 22:01:00         None              0
# 143 2025-03-16 22:01:00 2025-03-16 22:03:00    FC y ARTd              2
# 144 2025-03-16 22:03:00 2025-03-16 22:05:00  ARTs y ARTd              2
# 145 2025-03-16 22:05:00 2025-03-16 22:07:00    FC y ARTs              2
# 146 2025-03-16 22:07:00 2025-03-16 22:09:00  ARTs y ARTd              2
# 147 2025-03-16 22:09:00 2025-03-16 22:11:00  SpO2 y ARTs              2
# 148 2025-03-16 22:11:00 2025-03-16 22:13:00  SpO2 y ARTd              2
# 149 2025-03-16 22:13:00 2025-03-16 22:15:00  ARTs y ARTd              1
# 150 2025-03-16 22:15:00 2025-03-16 22:17:00  ARTs y ARTd              1
# 151 2025-03-16 22:17:00 2025-03-16 22:19:00  SpO2 y ARTs              2
# 152 2025-03-16 22:19:00 2025-03-16 22:21:00  SpO2 y ARTs              1
# 153 2025-03-16 22:21:00 2025-03-16 22:23:00  ARTs y ARTd              2
# 154 2025-03-16 22:23:00 2025-03-16 22:25:00  ARTs y ARTd              2
# 155 2025-03-16 22:25:00 2025-03-16 22:27:00    FC y ARTd              2
# 156 2025-03-16 22:27:00 2025-03-16 22:29:00  ARTs y ARTd              2
# 157 2025-03-16 22:29:00 2025-03-16 22:31:00  ARTs y ARTd              1
# 158 2025-03-16 22:31:00 2025-03-16 22:33:00  ARTs y ARTd              1
# 159 2025-03-16 22:33:00 2025-03-16 22:35:00    FC y ARTd              1
# 160 2025-03-16 22:35:00 2025-03-16 22:37:00  SpO2 y ARTd              1
# 161 2025-03-16 22:37:00 2025-03-16 22:39:00         None              0
# 162 2025-03-16 22:39:00 2025-03-16 22:41:00         None              0
# 163 2025-03-16 22:41:00 2025-03-16 22:43:00  ARTs y ARTd              1
# 164 2025-03-16 22:43:00 2025-03-16 22:45:00  ARTs y ARTd              1
# 165 2025-03-16 22:45:00 2025-03-16 22:47:00  ARTs y ARTd              1
# 166 2025-03-16 22:47:00 2025-03-16 22:49:00         None              0
# 167 2025-03-16 22:49:00 2025-03-16 22:51:00  ARTs y ARTd              1
# 168 2025-03-16 22:51:00 2025-03-16 22:53:00  ARTs y ARTd              2
# 169 2025-03-16 22:53:00 2025-03-16 22:55:00  SpO2 y ARTs              2
# 170 2025-03-16 22:55:00 2025-03-16 22:57:00  SpO2 y ARTs              1
# 171 2025-03-16 22:57:00 2025-03-16 22:59:00  SpO2 y ARTs              1
# 172 2025-03-16 22:59:00 2025-03-16 23:01:00  ARTs y ARTd              2
# 173 2025-03-16 23:01:00 2025-03-16 23:03:00         None              0
# 174 2025-03-16 23:03:00 2025-03-16 23:05:00         None              0
# 175 2025-03-16 23:05:00 2025-03-16 23:07:00         None              0
# 176 2025-03-16 23:07:00 2025-03-16 23:09:00  ARTs y ARTd              2
# 177 2025-03-16 23:09:00 2025-03-16 23:11:00  SpO2 y ARTs              2
# 178 2025-03-16 23:11:00 2025-03-16 23:13:00  ARTs y ARTd              2
# 179 2025-03-16 23:13:00 2025-03-16 23:15:00         None              0
# 180 2025-03-16 23:15:00 2025-03-16 23:17:00  SpO2 y ARTs              2
# 181 2025-03-16 23:17:00 2025-03-16 23:19:00         None              0
# 182 2025-03-16 23:19:00 2025-03-16 23:21:00  SpO2 y ARTs              1
# 183 2025-03-16 23:21:00 2025-03-16 23:23:00         None              0
# 184 2025-03-16 23:23:00 2025-03-16 23:25:00  SpO2 y ARTs              2
# 185 2025-03-16 23:25:00 2025-03-16 23:27:00  SpO2 y ARTs              2
# 186 2025-03-16 23:27:00 2025-03-16 23:29:00         None              0
# 187 2025-03-16 23:29:00 2025-03-16 23:31:00    FC y ARTd              2
# 188 2025-03-16 23:31:00 2025-03-16 23:33:00  ARTs y ARTd              2
# 189 2025-03-16 23:33:00 2025-03-16 23:35:00  ARTs y ARTd              1
# 190 2025-03-16 23:35:00 2025-03-16 23:37:00  ARTs y ARTd              1
# 191 2025-03-16 23:37:00 2025-03-16 23:39:00  ARTs y ARTd              1
# 192 2025-03-16 23:39:00 2025-03-16 23:41:00  ARTs y ARTd              1
# 193 2025-03-16 23:41:00 2025-03-16 23:43:00  ARTs y ARTd              1
# 194 2025-03-16 23:43:00 2025-03-16 23:45:00         None              0
# 195 2025-03-16 23:45:00 2025-03-16 23:47:00  SpO2 y ARTd              2
# 196 2025-03-16 23:47:00 2025-03-16 23:49:00  ARTs y ARTd              2
# 197 2025-03-16 23:49:00 2025-03-16 23:51:00  SpO2 y ARTd              2
# 198 2025-03-16 23:51:00 2025-03-16 23:53:00  ARTs y ARTd              2
# 199 2025-03-16 23:53:00 2025-03-16 23:55:00         None              0
# 200 2025-03-16 23:55:00 2025-03-16 23:57:00  SpO2 y ARTs              2
# 201 2025-03-16 23:57:00 2025-03-16 23:59:00  SpO2 y ARTs              1
# 202 2025-03-16 23:59:00 2025-03-17 00:01:00  ARTs y ARTd              2
# 203 2025-03-17 00:01:00 2025-03-17 00:03:00  ARTs y ARTd              2
# 204 2025-03-17 00:03:00 2025-03-17 00:05:00  ARTs y ARTd              2
# 205 2025-03-17 00:05:00 2025-03-17 00:07:00  ARTs y ARTd              2
# 206 2025-03-17 00:07:00 2025-03-17 00:09:00  ARTs y ARTd              2
# 207 2025-03-17 00:09:00 2025-03-17 00:11:00  SpO2 y ARTd              2
# 208 2025-03-17 00:11:00 2025-03-17 00:13:00  ARTs y ARTd              2
# 209 2025-03-17 00:13:00 2025-03-17 00:15:00  ARTs y ARTd              2
# 210 2025-03-17 00:15:00 2025-03-17 00:17:00  ARTs y ARTd              1
# 211 2025-03-17 00:17:00 2025-03-17 00:19:00         None              0
# 212 2025-03-17 00:19:00 2025-03-17 00:21:00  ARTs y ARTd              2
# 213 2025-03-17 00:21:00 2025-03-17 00:23:00  ARTs y ARTd              2
# 214 2025-03-17 00:23:00 2025-03-17 00:25:00  ARTs y ARTd              2
# 215 2025-03-17 00:25:00 2025-03-17 00:27:00         None              0
# 216 2025-03-17 00:27:00 2025-03-17 00:29:00    FC y ARTs              0
# 217 2025-03-17 00:29:00 2025-03-17 00:31:00  SpO2 y ARTs              2
# 218 2025-03-17 00:31:00 2025-03-17 00:33:00  SpO2 y ARTd              2
# 219 2025-03-17 00:33:00 2025-03-17 00:35:00         None              0
# 220 2025-03-17 00:35:00 2025-03-17 00:37:00  SpO2 y ARTs              3
# 221 2025-03-17 00:37:00 2025-03-17 00:39:00  ARTs y ARTd              2
# 222 2025-03-17 00:39:00 2025-03-17 00:41:00  ARTs y ARTd              2
# 223 2025-03-17 00:41:00 2025-03-17 00:43:00         None              0
# 224 2025-03-17 00:43:00 2025-03-17 00:45:00         None              0
# 225 2025-03-17 00:45:00 2025-03-17 00:47:00  ARTs y ARTd              1
# 226 2025-03-17 00:47:00 2025-03-17 00:49:00    FC y ARTs              2
# 227 2025-03-17 00:49:00 2025-03-17 00:51:00  SpO2 y ARTd              2
# 228 2025-03-17 00:51:00 2025-03-17 00:53:00    FC y ARTs              3
# 229 2025-03-17 00:53:00 2025-03-17 00:55:00    FC y ARTs              3
# 230 2025-03-17 00:55:00 2025-03-17 00:57:00    FC y ARTs              2
# 231 2025-03-17 00:57:00 2025-03-17 00:59:00  SpO2 y ARTd              2
# 232 2025-03-17 00:59:00 2025-03-17 01:01:00    FC y ARTs              2
# 233 2025-03-17 01:01:00 2025-03-17 01:03:00  ARTs y ARTd              2
# 234 2025-03-17 01:03:00 2025-03-17 01:05:00  ARTs y ARTd              2
# 235 2025-03-17 01:05:00 2025-03-17 01:07:00    FC y SpO2              2
# 236 2025-03-17 01:07:00 2025-03-17 01:09:00  SpO2 y ARTd              2
# 237 2025-03-17 01:09:00 2025-03-17 01:11:00  SpO2 y ARTd              2
# 238 2025-03-17 01:11:00 2025-03-17 01:13:00    FC y ARTs              3
# 239 2025-03-17 01:13:00 2025-03-17 01:15:00    FC y ARTd              2
# 240 2025-03-17 01:15:00 2025-03-17 01:17:00  ARTs y ARTd              1
# 241 2025-03-17 01:17:00 2025-03-17 01:19:00  ARTs y ARTd              1
# 242 2025-03-17 01:19:00 2025-03-17 01:21:00  ARTs y ARTd              0
# 243 2025-03-17 01:21:00 2025-03-17 01:23:00         None              0
# 244 2025-03-17 01:23:00 2025-03-17 01:25:00    FC y ARTd              1
# 245 2025-03-17 01:25:00 2025-03-17 01:27:00         None              0
# 246 2025-03-17 01:27:00 2025-03-17 01:29:00         None              0
# 247 2025-03-17 01:29:00 2025-03-17 01:31:00         None              0
# 248 2025-03-17 01:31:00 2025-03-17 01:33:00  ARTs y ARTd              1
# 249 2025-03-17 01:33:00 2025-03-17 01:35:00  SpO2 y ARTd              1
# 250 2025-03-17 01:35:00 2025-03-17 01:37:00         None              0
# 251 2025-03-17 01:37:00 2025-03-17 01:39:00         None              0
# 252 2025-03-17 01:39:00 2025-03-17 01:41:00  ARTs y ARTd              1
# 253 2025-03-17 01:41:00 2025-03-17 01:43:00  SpO2 y ARTd              1
# 254 2025-03-17 01:43:00 2025-03-17 01:45:00  ARTs y ARTd              2
# 255 2025-03-17 01:45:00 2025-03-17 01:47:00  SpO2 y ARTd              2
# 256 2025-03-17 01:47:00 2025-03-17 01:49:00  SpO2 y ARTd              1
# 257 2025-03-17 01:49:00 2025-03-17 01:51:00         None              0
# 258 2025-03-17 01:51:00 2025-03-17 01:53:00         None              0
# 259 2025-03-17 01:53:00 2025-03-17 01:55:00    FC y ARTs              1
# 260 2025-03-17 01:55:00 2025-03-17 01:57:00  ARTs y ARTd              1
# 261 2025-03-17 01:57:00 2025-03-17 01:59:00    FC y ARTd              2
# 262 2025-03-17 01:59:00 2025-03-17 02:01:00  SpO2 y ARTs              2
# 263 2025-03-17 02:01:00 2025-03-17 02:03:00  SpO2 y ARTs              2
# 264 2025-03-17 02:03:00 2025-03-17 02:05:00  SpO2 y ARTd              1
# 265 2025-03-17 02:05:00 2025-03-17 02:07:00  SpO2 y ARTs              3
# 266 2025-03-17 02:07:00 2025-03-17 02:09:00    FC y ARTd              0
# 267 2025-03-17 02:09:00 2025-03-17 02:11:00         None              0
# 268 2025-03-17 02:11:00 2025-03-17 02:13:00         None              0
# 269 2025-03-17 02:13:00 2025-03-17 02:15:00         None              0
# 270 2025-03-17 02:15:00 2025-03-17 02:17:00         None              0
# 271 2025-03-17 02:17:00 2025-03-17 02:19:00         None              0
# 272 2025-03-17 02:19:00 2025-03-17 02:21:00  SpO2 y ARTd              3
# 273 2025-03-17 02:21:00 2025-03-17 02:23:00  SpO2 y ARTd              1
# 274 2025-03-17 02:23:00 2025-03-17 02:25:00  SpO2 y ARTd              3
# 275 2025-03-17 02:25:00 2025-03-17 02:27:00    FC y ARTd              0
# 276 2025-03-17 02:27:00 2025-03-17 02:29:00  SpO2 y ARTd              0
# 277 2025-03-17 02:29:00 2025-03-17 02:31:00  SpO2 y ARTd              3
# 278 2025-03-17 02:31:00 2025-03-17 02:33:00    FC y ARTd              0
# 279 2025-03-17 02:33:00 2025-03-17 02:35:00    FC y ARTd              0
# 280 2025-03-17 02:35:00 2025-03-17 02:37:00  ARTs y ARTd              1
# 281 2025-03-17 02:37:00 2025-03-17 02:39:00    FC y ARTd              1
# 282 2025-03-17 02:39:00 2025-03-17 02:41:00  SpO2 y ARTd              1
# 283 2025-03-17 02:41:00 2025-03-17 02:43:00         None              0
# 284 2025-03-17 02:43:00 2025-03-17 02:45:00  SpO2 y ARTd              0
# 285 2025-03-17 02:45:00 2025-03-17 02:47:00         None              0
# 286 2025-03-17 02:47:00 2025-03-17 02:49:00  SpO2 y ARTd              2
# 287 2025-03-17 02:49:00 2025-03-17 02:51:00         None              0
# 288 2025-03-17 02:51:00 2025-03-17 02:53:00         None              0
# 289 2025-03-17 02:53:00 2025-03-17 02:55:00  SpO2 y ARTd              2
# 290 2025-03-17 02:55:00 2025-03-17 02:57:00  SpO2 y ARTd              0
# 291 2025-03-17 02:57:00 2025-03-17 02:59:00    FC y SpO2              2
# 292 2025-03-17 02:59:00 2025-03-17 03:01:00    FC y SpO2              2
# 293 2025-03-17 03:01:00 2025-03-17 03:03:00    FC y ARTd              4
# 294 2025-03-17 03:03:00 2025-03-17 03:05:00  SpO2 y ARTd              1
# 295 2025-03-17 03:05:00 2025-03-17 03:07:00         None              0
# 296 2025-03-17 03:07:00 2025-03-17 03:09:00         None              0
# 297 2025-03-17 03:09:00 2025-03-17 03:11:00  SpO2 y ARTd              0
# 298 2025-03-17 03:11:00 2025-03-17 03:13:00         None              0
# 299 2025-03-17 03:13:00 2025-03-17 03:15:00         None              0
# 300 2025-03-17 03:15:00 2025-03-17 03:17:00         None              0
# 301 2025-03-17 03:17:00 2025-03-17 03:19:00         None              0
# 302 2025-03-17 03:19:00 2025-03-17 03:21:00         None              0
# 303 2025-03-17 03:21:00 2025-03-17 03:23:00         None              0
# 304 2025-03-17 03:23:00 2025-03-17 03:25:00         None              0
# 305 2025-03-17 03:25:00 2025-03-17 03:27:00         None              0
# 306 2025-03-17 03:27:00 2025-03-17 03:29:00         None              0
# 307 2025-03-17 03:29:00 2025-03-17 03:31:00         None              0
# 308 2025-03-17 03:31:00 2025-03-17 03:33:00         None              0
# 309 2025-03-17 03:33:00 2025-03-17 03:35:00         None              0
# 310 2025-03-17 03:35:00 2025-03-17 03:37:00         None              0
# 311 2025-03-17 03:37:00 2025-03-17 03:39:00         None              0
# 312 2025-03-17 03:39:00 2025-03-17 03:41:00         None              0
# 313 2025-03-17 03:41:00 2025-03-17 03:43:00         None              0
# 314 2025-03-17 03:43:00 2025-03-17 03:45:00         None              0
# 315 2025-03-17 03:45:00 2025-03-17 03:47:00         None              0
# 316 2025-03-17 03:47:00 2025-03-17 03:49:00         None              0
# 317 2025-03-17 03:49:00 2025-03-17 03:51:00         None              0
# 318 2025-03-17 03:51:00 2025-03-17 03:53:00         None              0
# 319 2025-03-17 03:53:00 2025-03-17 03:55:00         None              0
# 320 2025-03-17 03:55:00 2025-03-17 03:57:00         None              0
# 321 2025-03-17 03:57:00 2025-03-17 03:59:00         None              0
# 322 2025-03-17 03:59:00 2025-03-17 04:01:00         None              0
# 323 2025-03-17 04:01:00 2025-03-17 04:03:00         None              0
# 324 2025-03-17 04:03:00 2025-03-17 04:05:00    FC y ARTd              0
# 325 2025-03-17 04:05:00 2025-03-17 04:07:00         None              0
# 326 2025-03-17 04:07:00 2025-03-17 04:09:00         None              0
# 327 2025-03-17 04:09:00 2025-03-17 04:11:00  ARTs y ARTd              1
# 328 2025-03-17 04:11:00 2025-03-17 04:13:00    FC y ARTd              1
# 329 2025-03-17 04:13:00 2025-03-17 04:15:00    FC y SpO2              0
# 330 2025-03-17 04:15:00 2025-03-17 04:17:00    FC y ARTd              1
# 331 2025-03-17 04:17:00 2025-03-17 04:19:00    FC y SpO2              1
# 332 2025-03-17 04:19:00 2025-03-17 04:21:00         None              0
# 333 2025-03-17 04:21:00 2025-03-17 04:23:00         None              0
# 334 2025-03-17 04:23:00 2025-03-17 04:25:00         None              0
# 335 2025-03-17 04:25:00 2025-03-17 04:27:00         None              0
# 336 2025-03-17 04:27:00 2025-03-17 04:29:00         None              0
# 337 2025-03-17 04:29:00 2025-03-17 04:31:00         None              0
# 338 2025-03-17 04:31:00 2025-03-17 04:33:00  SpO2 y ARTd              3
# 339 2025-03-17 04:33:00 2025-03-17 04:35:00         None              0
# 340 2025-03-17 04:35:00 2025-03-17 04:37:00  ARTs y ARTd              1
# 341 2025-03-17 04:37:00 2025-03-17 04:39:00    FC y ARTd              0
# 342 2025-03-17 04:39:00 2025-03-17 04:41:00         None              0
# 343 2025-03-17 04:41:00 2025-03-17 04:43:00  ARTs y ARTd              1
# 344 2025-03-17 04:43:00 2025-03-17 04:45:00  SpO2 y ARTs              1
# 345 2025-03-17 04:45:00 2025-03-17 04:47:00    FC y SpO2              0
# 346 2025-03-17 04:47:00 2025-03-17 04:49:00  ARTs y ARTd              1
# 347 2025-03-17 04:49:00 2025-03-17 04:51:00    FC y ARTs              2
# 348 2025-03-17 04:51:00 2025-03-17 04:53:00    FC y ARTd              0
# 349 2025-03-17 04:53:00 2025-03-17 04:55:00    FC y ARTd              0
# 350 2025-03-17 04:55:00 2025-03-17 04:57:00  SpO2 y ARTd              0
# 351 2025-03-17 04:57:00 2025-03-17 04:59:00         None              0
# 352 2025-03-17 04:59:00 2025-03-17 05:01:00         None              0
# 353 2025-03-17 05:01:00 2025-03-17 05:03:00         None              0
# 354 2025-03-17 05:03:00 2025-03-17 05:05:00         None              0
# 355 2025-03-17 05:05:00 2025-03-17 05:07:00    FC y ARTd              0
# 356 2025-03-17 05:07:00 2025-03-17 05:09:00  ARTs y ARTd              0
# 357 2025-03-17 05:09:00 2025-03-17 05:11:00         None              0
# 358 2025-03-17 05:11:00 2025-03-17 05:13:00  SpO2 y ARTd              0
# 359 2025-03-17 05:13:00 2025-03-17 05:15:00         None              0
# 360 2025-03-17 05:15:00 2025-03-17 05:17:00  ARTs y ARTd              1
# 361 2025-03-17 05:17:00 2025-03-17 05:19:00         None              0
# 362 2025-03-17 05:19:00 2025-03-17 05:21:00  SpO2 y ARTd              0
# 363 2025-03-17 05:21:00 2025-03-17 05:23:00         None              0
# 364 2025-03-17 05:23:00 2025-03-17 05:25:00  SpO2 y ARTd              0
# 365 2025-03-17 05:25:00 2025-03-17 05:27:00         None              0
# 366 2025-03-17 05:27:00 2025-03-17 05:29:00  ARTs y ARTd              0
# 367 2025-03-17 05:29:00 2025-03-17 05:31:00         None              0
# 368 2025-03-17 05:31:00 2025-03-17 05:33:00         None              0
# 369 2025-03-17 05:33:00 2025-03-17 05:35:00         None              0
# 370 2025-03-17 05:35:00 2025-03-17 05:37:00  ARTs y ARTd              0
# 371 2025-03-17 05:37:00 2025-03-17 05:39:00         None              0
# 372 2025-03-17 05:39:00 2025-03-17 05:41:00         None              0
# 373 2025-03-17 05:41:00 2025-03-17 05:43:00    FC y ARTd              0
# 374 2025-03-17 05:43:00 2025-03-17 05:45:00    FC y ARTd              2
# 375 2025-03-17 05:45:00 2025-03-17 05:47:00  SpO2 y ARTd              1
# 376 2025-03-17 05:47:00 2025-03-17 05:49:00         None              0
# 377 2025-03-17 05:49:00 2025-03-17 05:51:00  ARTs y ARTd              1
# 378 2025-03-17 05:51:00 2025-03-17 05:53:00         None              0
# 379 2025-03-17 05:53:00 2025-03-17 05:55:00         None              0
# 380 2025-03-17 05:55:00 2025-03-17 05:57:00         None              0
# 381 2025-03-17 05:57:00 2025-03-17 05:59:00    FC y ARTd              1
# 382 2025-03-17 05:59:00 2025-03-17 06:01:00  ARTs y ARTd              1
# 383 2025-03-17 06:01:00 2025-03-17 06:03:00  ARTs y ARTd              2
# 384 2025-03-17 06:03:00 2025-03-17 06:05:00    FC y SpO2              1
# 385 2025-03-17 06:05:00 2025-03-17 06:07:00    FC y ARTs              1
# 386 2025-03-17 06:07:00 2025-03-17 06:09:00    FC y ARTs              1
# 387 2025-03-17 06:09:00 2025-03-17 06:11:00         None              0
# 388 2025-03-17 06:11:00 2025-03-17 06:13:00         None              0
# 389 2025-03-17 06:13:00 2025-03-17 06:15:00  SpO2 y ARTd              1
# 390 2025-03-17 06:15:00 2025-03-17 06:17:00         None              0
# 391 2025-03-17 06:17:00 2025-03-17 06:19:00  SpO2 y ARTd              0
# 392 2025-03-17 06:19:00 2025-03-17 06:21:00         None              0
# 393 2025-03-17 06:21:00 2025-03-17 06:23:00  ARTs y ARTd              0
# 394 2025-03-17 06:23:00 2025-03-17 06:25:00    FC y ARTs              1
# 395 2025-03-17 06:25:00 2025-03-17 06:27:00    FC y SpO2              0
# 396 2025-03-17 06:27:00 2025-03-17 06:29:00         None              0
# 397 2025-03-17 06:29:00 2025-03-17 06:31:00         None              0
# 398 2025-03-17 06:31:00 2025-03-17 06:33:00         None              0
# 399 2025-03-17 06:33:00 2025-03-17 06:35:00  ARTs y ARTd              1
# 400 2025-03-17 06:35:00 2025-03-17 06:37:00    FC y ARTs              0
# 401 2025-03-17 06:37:00 2025-03-17 06:39:00         None              0
# 402 2025-03-17 06:39:00 2025-03-17 06:41:00  ARTs y ARTd              2
# 403 2025-03-17 06:41:00 2025-03-17 06:43:00         None              0
# 404 2025-03-17 06:43:00 2025-03-17 06:45:00         None              0
# 405 2025-03-17 06:45:00 2025-03-17 06:47:00         None              0
# 406 2025-03-17 06:47:00 2025-03-17 06:49:00         None              0
# 407 2025-03-17 06:49:00 2025-03-17 06:51:00    FC y ARTd              0
# 408 2025-03-17 06:51:00 2025-03-17 06:53:00    FC y ARTd              1
# 409 2025-03-17 06:53:00 2025-03-17 06:55:00         None              0
# 410 2025-03-17 06:55:00 2025-03-17 06:57:00  ARTs y ARTd              2
# 411 2025-03-17 06:57:00 2025-03-17 06:59:00         None              0
# 412 2025-03-17 06:59:00 2025-03-17 07:01:00         None              0
# 413 2025-03-17 07:01:00 2025-03-17 07:03:00         None              0
# 414 2025-03-17 07:03:00 2025-03-17 07:05:00         None              0
# 415 2025-03-17 07:05:00 2025-03-17 07:07:00  ARTs y ARTd              0
# 416 2025-03-17 07:07:00 2025-03-17 07:09:00    FC y ARTd              0
# 417 2025-03-17 07:09:00 2025-03-17 07:11:00    FC y ARTd              0
# 418 2025-03-17 07:11:00 2025-03-17 07:13:00         None              0
# 419 2025-03-17 07:13:00 2025-03-17 07:15:00  ARTs y ARTd              0
# 420 2025-03-17 07:15:00 2025-03-17 07:17:00         None              0
# 421 2025-03-17 07:17:00 2025-03-17 07:19:00         None              0
# 422 2025-03-17 07:19:00 2025-03-17 07:21:00         None              0
# 423 2025-03-17 07:21:00 2025-03-17 07:23:00         None              0
# 424 2025-03-17 07:23:00 2025-03-17 07:25:00         None              0
# 425 2025-03-17 07:25:00 2025-03-17 07:27:00         None              0
# 426 2025-03-17 07:27:00 2025-03-17 07:29:00         None              0
# 427 2025-03-17 07:29:00 2025-03-17 07:31:00    FC y ARTd              0
# 428 2025-03-17 07:31:00 2025-03-17 07:33:00         None              0
# 429 2025-03-17 07:33:00 2025-03-17 07:35:00         None              0
# 430 2025-03-17 07:35:00 2025-03-17 07:37:00  ARTs y ARTd              1
# 431 2025-03-17 07:37:00 2025-03-17 07:39:00  ARTs y ARTd              0
# 432 2025-03-17 07:39:00 2025-03-17 07:41:00         None              0
# 433 2025-03-17 07:41:00 2025-03-17 07:43:00         None              0
# 434 2025-03-17 07:43:00 2025-03-17 07:45:00    FC y ARTs              0
# 435 2025-03-17 07:45:00 2025-03-17 07:47:00         None              0
# 436 2025-03-17 07:47:00 2025-03-17 07:49:00    FC y ARTs              3
# 437 2025-03-17 07:49:00 2025-03-17 07:51:00    FC y SpO2              0
# 438 2025-03-17 07:51:00 2025-03-17 07:53:00         None              0
# 439 2025-03-17 07:53:00 2025-03-17 07:55:00    FC y ARTd              0
# 440 2025-03-17 07:55:00 2025-03-17 07:57:00         None              0
# 441 2025-03-17 07:57:00 2025-03-17 07:59:00    FC y ARTs              0
# 442 2025-03-17 07:59:00 2025-03-17 08:01:00         None              0
# 443 2025-03-17 08:01:00 2025-03-17 08:03:00    FC y ARTd              0
# 444 2025-03-17 08:03:00 2025-03-17 08:05:00  ARTs y ARTd              0
# 445 2025-03-17 08:05:00 2025-03-17 08:07:00    FC y ARTs              0
# 446 2025-03-17 08:07:00 2025-03-17 08:09:00    FC y ARTd              0
# 447 2025-03-17 08:09:00 2025-03-17 08:11:00         None              0
# 448 2025-03-17 08:11:00 2025-03-17 08:13:00         None              0
# 449 2025-03-17 08:13:00 2025-03-17 08:15:00    FC y ARTd              0
# 450 2025-03-17 08:15:00 2025-03-17 08:17:00         None              0
# 451 2025-03-17 08:17:00 2025-03-17 08:19:00         None              0
# 452 2025-03-17 08:19:00 2025-03-17 08:21:00         None              0
# 453 2025-03-17 08:21:00 2025-03-17 08:23:00    FC y ARTd              2
# 454 2025-03-17 08:23:00 2025-03-17 08:25:00         None              0
# 455 2025-03-17 08:25:00 2025-03-17 08:27:00  ARTs y ARTd              0
# 456 2025-03-17 08:27:00 2025-03-17 08:29:00         None              0
# 457 2025-03-17 08:29:00 2025-03-17 08:31:00         None              0
# 458 2025-03-17 08:31:00 2025-03-17 08:33:00         None              0
# 459 2025-03-17 08:33:00 2025-03-17 08:35:00         None              0
# 460 2025-03-17 08:35:00 2025-03-17 08:37:00    FC y ARTd              0
# 461 2025-03-17 08:37:00 2025-03-17 08:39:00    FC y ARTd              0
# 462 2025-03-17 08:39:00 2025-03-17 08:41:00    FC y ARTd              0
# 463 2025-03-17 08:41:00 2025-03-17 08:43:00    FC y ARTs              2
# 464 2025-03-17 08:43:00 2025-03-17 08:45:00    FC y ARTs              0
# 465 2025-03-17 08:45:00 2025-03-17 08:47:00    FC y SpO2              1
# 466 2025-03-17 08:47:00 2025-03-17 08:49:00    FC y ARTd              0
# 467 2025-03-17 08:49:00 2025-03-17 08:51:00    FC y ARTd              0
# 468 2025-03-17 08:51:00 2025-03-17 08:53:00    FC y ARTd              2
# 469 2025-03-17 08:53:00 2025-03-17 08:55:00    FC y ARTs              0
# 470 2025-03-17 08:55:00 2025-03-17 08:57:00    FC y ARTd              1
# 471 2025-03-17 08:57:00 2025-03-17 08:59:00    FC y ARTd              0
# 472 2025-03-17 08:59:00 2025-03-17 09:01:00         None              0
# 473 2025-03-17 09:01:00 2025-03-17 09:03:00    FC y ARTd              0
# 474 2025-03-17 09:03:00 2025-03-17 09:05:00    FC y ARTd              0
# 475 2025-03-17 09:05:00 2025-03-17 09:07:00    FC y ARTd              0
# 476 2025-03-17 09:07:00 2025-03-17 09:09:00    FC y ARTd              0
# 477 2025-03-17 09:09:00 2025-03-17 09:11:00    FC y ARTd              0
# 478 2025-03-17 09:11:00 2025-03-17 09:13:00    FC y ARTd              0
# 479 2025-03-17 09:13:00 2025-03-17 09:15:00    FC y ARTd              0
# 480 2025-03-17 09:15:00 2025-03-17 09:17:00    FC y ARTd              0
# 481 2025-03-17 09:17:00 2025-03-17 09:19:00         None              0
# 482 2025-03-17 09:19:00 2025-03-17 09:21:00         None              0
# 483 2025-03-17 09:21:00 2025-03-17 09:23:00    FC y ARTd              2
# 484 2025-03-17 09:23:00 2025-03-17 09:25:00    FC y ARTs              1
# 485 2025-03-17 09:25:00 2025-03-17 09:27:00  ARTs y ARTd              1
# 486 2025-03-17 09:27:00 2025-03-17 09:29:00    FC y ARTd              1
# 487 2025-03-17 09:29:00 2025-03-17 09:31:00  ARTs y ARTd              2
# 488 2025-03-17 09:31:00 2025-03-17 09:33:00    FC y ARTd              2
# 489 2025-03-17 09:33:00 2025-03-17 09:35:00  SpO2 y ARTs              0
# 490 2025-03-17 09:35:00 2025-03-17 09:37:00  ARTs y ARTd              2
# 491 2025-03-17 09:37:00 2025-03-17 09:39:00    FC y ARTd              0
# 492 2025-03-17 09:39:00 2025-03-17 09:41:00         None              0
# 493 2025-03-17 09:41:00 2025-03-17 09:43:00  ARTs y ARTd              2
# 494 2025-03-17 09:43:00 2025-03-17 09:45:00  SpO2 y ARTs              0
# 495 2025-03-17 09:45:00 2025-03-17 09:47:00         None              0
# 496 2025-03-17 09:47:00 2025-03-17 09:49:00         None              0
# 497 2025-03-17 09:49:00 2025-03-17 09:51:00  SpO2 y ARTs              0
# 498 2025-03-17 09:51:00 2025-03-17 09:53:00         None              0
# 499 2025-03-17 09:53:00 2025-03-17 09:55:00         None              0
#
#      Confidence  Anomaly Count
# 0      1.000000            0.0
# 1      1.000000            0.0
# 2      0.000000            0.0
# 3      0.112494            1.0
# 4      1.000000            4.0
# 5      0.130103            0.0
# 6      1.000000            0.0
# 7      0.000000            0.0
# 8      0.000000            0.0
# 9      1.000000            1.0
# 10     1.000000            1.0
# 11     1.000000            2.0
# 12     0.112494            1.0
# 13     0.160206            2.0
# 14     0.000000            0.0
# 15     1.000000            4.0
# 16     0.160206            0.0
# 17     0.000000            0.0
# 18     0.000000            0.0
# 19     0.000000            0.0
# 20     0.112494            0.0
# 21     0.000000            0.0
# 22     1.000000            0.0
# 23     0.130103            0.0
# 24     0.000000            0.0
# 25     0.112494            0.0
# 26     0.000000            0.0
# 27     0.000000            0.0
# 28     0.000000            0.0
# 29     0.000000            0.0
# 30     0.000000            0.0
# 31     0.000000            0.0
# 32     0.000000            0.0
# 33     0.000000            0.0
# 34     0.000000            0.0
# 35     0.112494            0.0
# 36     0.000000            0.0
# 37     0.000000            0.0
# 38     0.000000            0.0
# 39     0.000000            0.0
# 40     0.000000            0.0
# 41     0.000000            0.0
# 42     0.130103            1.0
# 43     1.000000            0.0
# 44     0.000000            0.0
# 45     0.000000            0.0
# 46     1.000000            0.0
# 47     0.000000            0.0
# 48     0.000000            0.0
# 49     0.112494            0.0
# 50     1.000000            0.0
# 51     0.000000            0.0
# 52     0.000000            0.0
# 53     0.000000            0.0
# 54     0.000000            0.0
# 55     0.000000            0.0
# 56     0.000000            0.0
# 57     0.000000            0.0
# 58     0.000000            0.0
# 59     0.000000            0.0
# 60     0.000000            0.0
# 61     0.130103            0.0
# 62     0.000000            0.0
# 63     0.000000            0.0
# 64     0.000000            0.0
# 65     0.000000            0.0
# 66     0.000000            0.0
# 67     0.000000            0.0
# 68     0.000000            0.0
# 69     0.000000            0.0
# 70     0.000000            0.0
# 71     0.000000            0.0
# 72     0.000000            0.0
# 73     0.000000            0.0
# 74     0.000000            0.0
# 75     0.000000            0.0
# 76     0.000000            0.0
# 77     0.000000            0.0
# 78     1.000000            1.0
# 79     0.000000            0.0
# 80     0.000000            0.0
# 81     0.112494            0.0
# 82     0.000000            0.0
# 83     0.000000            0.0
# 84     0.000000            0.0
# 85     0.000000            0.0
# 86     0.000000            0.0
# 87     0.000000            0.0
# 88     0.000000            0.0
# 89     0.000000            0.0
# 90     0.000000            0.0
# 91     0.000000            0.0
# 92     0.000000            0.0
# 93     0.000000            0.0
# 94     0.112494            1.0
# 95     1.000000            1.0
# 96     0.000000            0.0
# 97     0.112494            1.0
# 98     1.000000            1.0
# 99     0.000000            0.0
# 100    0.000000            0.0
# 101    0.130103            2.0
# 102    0.000000            0.0
# 103    0.000000            0.0
# 104    0.000000            0.0
# 105    1.000000            2.0
# 106    0.000000            0.0
# 107    0.000000            0.0
# 108    0.000000            0.0
# 109    0.160206            1.0
# 110    0.000000            0.0
# 111    1.000000            1.0
# 112    0.000000            0.0
# 113    1.000000            5.0
# 114    0.000000            0.0
# 115    0.000000            0.0
# 116    1.000000            2.0
# 117    0.000000            0.0
# 118    1.000000            1.0
# 119    0.000000            0.0
# 120    0.000000            0.0
# 121    0.112494            1.0
# 122    0.130103            1.0
# 123    1.000000            1.0
# 124    0.160206            1.0
# 125    0.160206            1.0
# 126    0.000000            0.0
# 127    0.160206            3.0
# 128    0.000000            0.0
# 129    0.000000            0.0
# 130    0.000000            0.0
# 131    0.000000            0.0
# 132    1.000000            2.0
# 133    1.000000            1.0
# 134    0.000000            0.0
# 135    0.160206            1.0
# 136    0.000000            0.0
# 137    0.112494            1.0
# 138    0.160206            3.0
# 139    0.112494            1.0
# 140    0.112494            2.0
# 141    0.000000            0.0
# 142    0.000000            0.0
# 143    1.000000            4.0
# 144    0.130103            2.0
# 145    1.000000            3.0
# 146    0.130103            2.0
# 147    0.160206            3.0
# 148    0.112494            1.0
# 149    0.160206            1.0
# 150    1.000000            2.0
# 151    1.000000            2.0
# 152    0.160206            1.0
# 153    1.000000            1.0
# 154    0.112494            1.0
# 155    1.000000            4.0
# 156    1.000000            4.0
# 157    0.160206            2.0
# 158    1.000000            2.0
# 159    0.160206            1.0
# 160    1.000000            2.0
# 161    0.000000            0.0
# 162    0.000000            0.0
# 163    0.130103            1.0
# 164    0.112494            1.0
# 165    0.160206            1.0
# 166    0.000000            0.0
# 167    0.130103            1.0
# 168    0.130103            1.0
# 169    1.000000            1.0
# 170    1.000000            1.0
# 171    0.160206            2.0
# 172    0.130103            1.0
# 173    0.000000            0.0
# 174    0.000000            0.0
# 175    0.000000            0.0
# 176    0.130103            1.0
# 177    1.000000            3.0
# 178    0.160206            1.0
# 179    0.000000            0.0
# 180    0.130103            2.0
# 181    0.000000            0.0
# 182    0.130103            1.0
# 183    0.000000            0.0
# 184    1.000000            2.0
# 185    0.130103            2.0
# 186    0.000000            0.0
# 187    1.000000            4.0
# 188    0.160206            2.0
# 189    0.130103            1.0
# 190    0.112494            1.0
# 191    1.000000            1.0
# 192    1.000000            2.0
# 193    0.130103            1.0
# 194    0.000000            0.0
# 195    0.160206            2.0
# 196    1.000000            2.0
# 197    1.000000            2.0
# 198    1.000000            2.0
# 199    0.000000            0.0
# 200    1.000000            3.0
# 201    0.112494            1.0
# 202    0.130103            1.0
# 203    0.130103            1.0
# 204    0.130103            1.0
# 205    0.130103            1.0
# 206    1.000000            2.0
# 207    1.000000            2.0
# 208    0.160206            1.0
# 209    0.160206            1.0
# 210    1.000000            0.0
# 211    0.000000            0.0
# 212    1.000000            1.0
# 213    0.160206            1.0
# 214    0.160206            1.0
# 215    0.000000            0.0
# 216    1.000000            0.0
# 217    1.000000            2.0
# 218    1.000000            1.0
# 219    0.000000            0.0
# 220    1.000000            2.0
# 221    0.160206            1.0
# 222    0.130103            2.0
# 223    0.000000            0.0
# 224    0.000000            0.0
# 225    1.000000            1.0
# 226    1.000000            4.0
# 227    0.112494            1.0
# 228    1.000000            4.0
# 229    1.000000            5.0
# 230    1.000000            4.0
# 231    0.160206            2.0
# 232    0.130103            1.0
# 233    1.000000            1.0
# 234    1.000000            2.0
# 235    1.000000            2.0
# 236    1.000000            1.0
# 237    0.130103            2.0
# 238    1.000000            3.0
# 239    1.000000            3.0
# 240    1.000000            0.0
# 241    0.112494            0.0
# 242    0.112494            0.0
# 243    0.000000            0.0
# 244    1.000000            4.0
# 245    0.000000            0.0
# 246    0.000000            0.0
# 247    0.000000            0.0
# 248    1.000000            1.0
# 249    0.112494            0.0
# 250    0.000000            0.0
# 251    0.000000            0.0
# 252    1.000000            0.0
# 253    1.000000            0.0
# 254    1.000000            2.0
# 255    0.130103            0.0
# 256    0.160206            0.0
# 257    0.000000            0.0
# 258    0.000000            0.0
# 259    1.000000            2.0
# 260    1.000000            2.0
# 261    1.000000            5.0
# 262    1.000000            5.0
# 263    1.000000            3.0
# 264    1.000000            0.0
# 265    1.000000            3.0
# 266    1.000000            0.0
# 267    0.000000            0.0
# 268    0.000000            0.0
# 269    0.000000            0.0
# 270    0.000000            0.0
# 271    0.000000            0.0
# 272    1.000000            4.0
# 273    1.000000            0.0
# 274    1.000000            3.0
# 275    0.160206            0.0
# 276    0.160206            0.0
# 277    1.000000            2.0
# 278    0.130103            0.0
# 279    1.000000            0.0
# 280    0.160206            0.0
# 281    0.112494            1.0
# 282    0.160206            0.0
# 283    0.000000            0.0
# 284    0.112494            0.0
# 285    0.000000            0.0
# 286    0.130103            0.0
# 287    0.000000            0.0
# 288    0.000000            0.0
# 289    0.130103            0.0
# 290    1.000000            0.0
# 291    1.000000            4.0
# 292    1.000000            5.0
# 293    1.000000            5.0
# 294    0.160206            1.0
# 295    0.000000            0.0
# 296    0.000000            0.0
# 297    1.000000            0.0
# 298    0.000000            0.0
# 299    0.000000            0.0
# 300    0.000000            0.0
# 301    0.000000            0.0
# 302    0.000000            0.0
# 303    0.000000            0.0
# 304    0.000000            0.0
# 305    0.000000            0.0
# 306    0.000000            0.0
# 307    0.000000            0.0
# 308    0.000000            0.0
# 309    0.000000            0.0
# 310    0.000000            0.0
# 311    0.000000            0.0
# 312    0.000000            0.0
# 313    0.000000            0.0
# 314    0.000000            0.0
# 315    0.000000            0.0
# 316    0.000000            0.0
# 317    0.000000            0.0
# 318    0.000000            0.0
# 319    0.000000            0.0
# 320    0.000000            0.0
# 321    0.000000            0.0
# 322    0.000000            0.0
# 323    0.000000            0.0
# 324    0.160206            0.0
# 325    0.000000            0.0
# 326    0.000000            0.0
# 327    0.130103            0.0
# 328    0.160206            2.0
# 329    1.000000            0.0
# 330    1.000000            3.0
# 331    1.000000            1.0
# 332    0.000000            0.0
# 333    0.000000            0.0
# 334    0.000000            0.0
# 335    0.000000            0.0
# 336    0.000000            0.0
# 337    0.000000            0.0
# 338    1.000000            1.0
# 339    0.000000            0.0
# 340    1.000000            1.0
# 341    0.130103            0.0
# 342    0.000000            0.0
# 343    0.130103            0.0
# 344    1.000000            1.0
# 345    1.000000            0.0
# 346    1.000000            1.0
# 347    1.000000            5.0
# 348    1.000000            0.0
# 349    1.000000            0.0
# 350    0.160206            0.0
# 351    0.000000            0.0
# 352    0.000000            0.0
# 353    0.000000            0.0
# 354    0.000000            0.0
# 355    1.000000            0.0
# 356    0.130103            0.0
# 357    0.000000            0.0
# 358    1.000000            0.0
# 359    0.000000            0.0
# 360    1.000000            0.0
# 361    0.000000            0.0
# 362    0.112494            0.0
# 363    0.000000            0.0
# 364    1.000000            0.0
# 365    0.000000            0.0
# 366    0.130103            0.0
# 367    0.000000            0.0
# 368    0.000000            0.0
# 369    0.000000            0.0
# 370    0.112494            0.0
# 371    0.000000            0.0
# 372    0.000000            0.0
# 373    0.130103            0.0
# 374    1.000000            4.0
# 375    0.112494            0.0
# 376    0.000000            0.0
# 377    0.112494            0.0
# 378    0.000000            0.0
# 379    0.000000            0.0
# 380    0.000000            0.0
# 381    1.000000            2.0
# 382    0.160206            0.0
# 383    1.000000            2.0
# 384    1.000000            0.0
# 385    1.000000            2.0
# 386    1.000000            3.0
# 387    0.000000            0.0
# 388    0.000000            0.0
# 389    0.112494            0.0
# 390    0.000000            0.0
# 391    0.160206            0.0
# 392    0.000000            0.0
# 393    0.112494            0.0
# 394    1.000000            2.0
# 395    1.000000            0.0
# 396    0.000000            0.0
# 397    0.000000            0.0
# 398    0.000000            0.0
# 399    0.160206            1.0
# 400    1.000000            0.0
# 401    0.000000            0.0
# 402    1.000000            1.0
# 403    0.000000            0.0
# 404    0.000000            0.0
# 405    0.000000            0.0
# 406    0.000000            0.0
# 407    1.000000            0.0
# 408    1.000000            2.0
# 409    0.000000            0.0
# 410    1.000000            1.0
# 411    0.000000            0.0
# 412    0.000000            0.0
# 413    0.000000            0.0
# 414    0.000000            0.0
# 415    0.112494            0.0
# 416    0.160206            0.0
# 417    0.130103            0.0
# 418    0.000000            0.0
# 419    0.130103            0.0
# 420    0.000000            0.0
# 421    0.000000            0.0
# 422    0.000000            0.0
# 423    0.000000            0.0
# 424    0.000000            0.0
# 425    0.000000            0.0
# 426    0.000000            0.0
# 427    1.000000            0.0
# 428    0.000000            0.0
# 429    0.000000            0.0
# 430    0.112494            0.0
# 431    0.130103            0.0
# 432    0.000000            0.0
# 433    0.000000            0.0
# 434    1.000000            0.0
# 435    0.000000            0.0
# 436    1.000000            6.0
# 437    0.160206            0.0
# 438    0.000000            0.0
# 439    0.112494            0.0
# 440    0.000000            0.0
# 441    0.160206            0.0
# 442    0.000000            0.0
# 443    1.000000            0.0
# 444    0.160206            0.0
# 445    1.000000            0.0
# 446    0.160206            0.0
# 447    0.000000            0.0
# 448    0.000000            0.0
# 449    0.112494            0.0
# 450    0.000000            0.0
# 451    0.000000            0.0
# 452    0.000000            0.0
# 453    1.000000            5.0
# 454    0.000000            0.0
# 455    0.112494            0.0
# 456    0.000000            0.0
# 457    0.000000            0.0
# 458    0.000000            0.0
# 459    0.000000            0.0
# 460    1.000000            0.0
# 461    1.000000            0.0
# 462    0.160206            0.0
# 463    1.000000            5.0
# 464    0.130103            0.0
# 465    1.000000            2.0
# 466    1.000000            0.0
# 467    1.000000            0.0
# 468    0.160206            2.0
# 469    1.000000            0.0
# 470    0.160206            1.0
# 471    0.130103            0.0
# 472    0.000000            0.0
# 473    1.000000            0.0
# 474    1.000000            0.0
# 475    0.130103            0.0
# 476    0.160206            0.0
# 477    0.130103            0.0
# 478    0.160206            0.0
# 479    0.160206            0.0
# 480    0.112494            0.0
# 481    0.000000            0.0
# 482    0.000000            0.0
# 483    1.000000            3.0
# 484    1.000000            3.0
# 485    0.112494            1.0
# 486    0.160206            1.0
# 487    0.160206            3.0
# 488    1.000000            4.0
# 489    0.160206            0.0
# 490    0.130103            1.0
# 491    0.160206            0.0
# 492    0.000000            0.0
# 493    0.112494            1.0
# 494    0.160206            0.0
# 495    0.000000            0.0
# 496    0.000000            0.0
# 497    0.130103            0.0
# 498    0.000000            0.0
# 499    0.000000            0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.dates as mdates

# Function to analyze and plot patient data along with model anomaly predictions.
# The background is shaded according to the number of pairs reporting anomalies.
# Above each diamond marker, the origin pair is annotated vertically.
def analyze_and_plot_patient(patient_data, patient_id, results1):
    # Count anomalies for each row of patient data
    patient_data['Anomalies'] = patient_data.apply(count_anomalies, axis=1)
    
    # Define a dynamic color mapping based on the number of anomalies
    max_anomalies = len(normal_ranges)  # Maximum possible anomalies
    colors = ['lightgreen', '#ffffB3', 'yellow', 'orange', 'red']
    cmap = mcolors.LinearSegmentedColormap.from_list("custom_gradient", colors, N=max_anomalies + 1)
    norm = mcolors.Normalize(vmin=0, vmax=max_anomalies)
    color_values = patient_data['Anomalies'].apply(lambda x: cmap(norm(x)))
    
    # Create the base plot
    plt.figure(figsize=(18, 6))
    
    # Plot all vital signs dynamically
    for col in studied_vital_signs:
        plt.plot(patient_data.index, patient_data[col], label=col, linewidth=1)
    
    # Raise the title much higher using the 'y' parameter (e.g., y=1.2)
    plt.title(f'Signos Vitales Paciente {patient_id} analizados', y=1.5)
    plt.xlabel('Tiempo')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.grid(True)
    
    # Add a color bar for the number of anomalies
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    plt.colorbar(sm, ax=plt.gca(), orientation='horizontal', pad=0.2, ticks=range(max_anomalies + 1), label='Número de signos vitales fuera del rango normal')
    
    # Apply background coloring based on the number of anomalies
    for i in range(len(patient_data.index) - 1):
        plt.axvspan(patient_data.index[i], patient_data.index[i + 1], 
                    color=color_values.iloc[i], alpha=0.25)
    
    # Plot diamond markers for model predicted anomalies.
    # Filter predictions based on Confidence and Anomaly Count.
    predictions = results1.loc[
        (results1['Confidence'] >= 0.1) & (results1['Confidence'] <= 1.0) & (results1['Anomaly Count'] >= 7.0)
    ].copy()
    
    if not predictions.empty:
        # Ensure time columns are in datetime format
        predictions['Start Time'] = pd.to_datetime(predictions['Start Time'],  format="%Y/%m/%d %H:%M:%S")
        predictions['End Time'] = pd.to_datetime(predictions['End Time'],  format="%Y/%m/%d %H:%M:%S")
        
        
        # Determine a y-coordinate for the markers: slightly above the maximum value among all vital signs.
        vitals_max = patient_data[list(studied_vital_signs)].max().max()
        vitals_min = patient_data[list(studied_vital_signs)].min().min()
        offset = (vitals_max - vitals_min) * 0.05
        y_marker = vitals_max + offset
        # Increase text_offset to add more spacing between the diamond and its annotation.
        text_offset = (vitals_max - vitals_min) * 0.08
        
        first_marker = True
        for _, row in predictions.iterrows():
            # Plot the diamond marker (colored red)
            marker_color = 'red'
            if first_marker:
                plt.scatter(row['Start Time'], y_marker, marker='D', color=marker_color, s=100, zorder=5,
                            label='Anomalia Reportada por el Modelo')
                first_marker = False
            else:
                plt.scatter(row['Start Time'], y_marker, marker='D', color=marker_color, s=100, zorder=5)
            
            # Annotate above the diamond with the origin pair, rotated vertically
            plt.text(row['Start Time'], y_marker + text_offset, str(row['Pair']),
                     horizontalalignment='center', verticalalignment='bottom',
                     fontsize=10, color='black', rotation=90)
    
    # Format the x-axis to show time in HH:MM:SS format
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.8))  # Position legend outside the plot area
    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust layout to leave space for the legend and raised title
    plt.show()
    
    
patient.set_index('Time', inplace=True)
analyze_and_plot_patient(paciente0, patient_id=str(id_paciente), results1=results_combined)

# %%
##### import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.patches as mpatches
import matplotlib.colors as mcolors

# Define normal ranges for vitals
normal_ranges = {
    'FC': (70, 120),
    'Resp': (12, 16),
    'SpO2': (88, 1000),
    'ARTs': (95, 135),
    'ARTd': (58, 88)
}

# Designated colors for each vital sign
vital_sign_colors = {
    'FC': 'blue',
    'Resp': 'orange',
    'SpO2': 'green',
    'ARTs': 'red',
    'ARTd': 'purple'
}

# Function to count anomalies in a row based on the defined normal ranges
def count_anomalies(row):
    anomalies = 0
    for col in studied_vital_signs:
        if row[col] < normal_ranges[col][0] or row[col] > normal_ranges[col][1]:
            anomalies += 1
    return anomalies

# Function to process results_combined to compute the "official_pair" per row.
def compute_official_pair(results_combined):
    # Ensure the dataframe is sorted by Start Time.
    rows = results_combined.sort_values("Start Time").reset_index(drop=True)
    n = len(rows)
    official_pairs = []
    current_official = None  # Track the last official pair

    for i in range(n):
        current_val = rows.loc[i, "Pair"]
        # If current value is None (or string "None"), then use the last official pair if available.
        if pd.isnull(current_val) or current_val == "None":
            official_pairs.append(current_official if current_official is not None else "None")
        else:
            # If no official pair has been set, check if the new pair appears for at least 3 consecutive rows.
            if current_official is None:
                run_length = 1
                for j in range(i+1, min(i+3, n)):
                    if rows.loc[j, "Pair"] == current_val:
                        run_length += 1
                    else:
                        break
                if run_length >= 3:
                    current_official = current_val
                    official_pairs.append(current_val)
                else:
                    official_pairs.append(current_official if current_official is not None else "None")
            else:
                # If we already have an official pair, check if the new one is stable for at least 3 rows.
                if current_val == current_official:
                    official_pairs.append(current_val)
                else:
                    run_length = 1
                    for j in range(i+1, min(i+3, n)):
                        if rows.loc[j, "Pair"] == current_val:
                            run_length += 1
                        else:
                            break
                    if run_length >= 3:
                        current_official = current_val
                        official_pairs.append(current_val)
                    else:
                        # Not enough evidence to change, so continue with the current official pair.
                        official_pairs.append(current_official)
    rows["official_pair"] = official_pairs
    return rows

# Function to analyze and plot patient vital signs with background shading according to
# the official representative pair, and also add a separate legend for vital sign line colors.
def analyze_and_plot_patient_by_pair_with_official(patient_data, patient_id, results_combined):
    # Process the combined results to compute the official pair per interval.
    processed_results = compute_official_pair(results_combined)
    
    # Create a color mapping for official pairs.
    unique_officials = [p for p in processed_results["official_pair"].unique() if p != "None"]
    cmap_mpl = plt.get_cmap('tab10')
    pair_color_map = {pair: cmap_mpl(i) for i, pair in enumerate(unique_officials)}
    # Map "None" to white.
    pair_color_map["None"] = "white"
    
    # Create the base plot.
    plt.figure(figsize=(18, 6))
    
    # Plot each vital sign using its designated color.
    for col in studied_vital_signs:
        plt.plot(patient_data.index, patient_data[col], label=col, color=vital_sign_colors[col], linewidth=1)
    
    plt.title(f'Signos Vitales mas significativos para el Paciente {patient_id} en un rango de tiempo')
    plt.xlabel('Tiempo')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.grid(True)
    
    # Shade the background based on the official representative pair for each time interval.
    for idx, row in processed_results.iterrows():
        start_time = pd.to_datetime(row['Start Time'],  format="%Y/%m/%d %H:%M:%S")
        end_time = pd.to_datetime(row['End Time'],  format="%Y/%m/%d %H:%M:%S")
        off_pair = row["official_pair"]
        color = pair_color_map.get(off_pair, "white")
        plt.axvspan(start_time, end_time, color=color, alpha=0.3)
    
    # Build a custom legend for official pairs (excluding "None").
    official_handles = [mpatches.Patch(color=pair_color_map[pair], label=pair) 
                        for pair in pair_color_map if pair != "None"]
    official_legend = plt.legend(handles=official_handles, loc='center left', bbox_to_anchor=(1, 0.8),
                                 title="Official Pair")
    plt.gca().add_artist(official_legend)
    
    # Build a second legend for the vital sign line colors.
    vital_handles = [mpatches.Patch(color=vital_sign_colors[col], label=col) for col in studied_vital_signs]
    plt.legend(handles=vital_handles, loc='center left', bbox_to_anchor=(1, 0.4), title="Vital Signs")
    
    # Format the x-axis to show time in HH:MM:SS format.
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    
    plt.tight_layout(rect=[0, 0, 0.85, 1])
    plt.show()

# Example usage:
# patient_data should be a DataFrame indexed by time with columns: 'FC', 'Resp', 'SpO2', 'ARTs', 'ARTd'.
# results_combined is a DataFrame with columns:
# "Start Time", "End Time", "Pair", "Anomaly Level", "Confidence", "Anomaly".
#
# Example:
# results_combined = pd.DataFrame({
#     "Start Time": ["2025-02-19 11:41:00", "2025-02-19 11:43:00", "2025-02-19 11:45:00", "2025-02-19 11:47:00"],
#     "End Time": ["2025-02-19 11:43:00", "2025-02-19 11:45:00", "2025-02-19 11:47:00", "2025-02-19 11:49:00"],
#     "Pair": ["pair_('FC', 'SpO2')", "pair_('FC', 'SpO2')", None, "pair_('FC', 'SpO2')"],
#     "Anomaly Level": [1, 1, 1, 1],
#     "Confidence": [1.0, 1.0, 1.0, 1.0],
#     "Anomaly": [True, True, True, True]
# })
#
# patient_data.set_index('Time', inplace=True)
analyze_and_plot_patient_by_pair_with_official(paciente0, str(id_paciente), results_combined)

# %% [markdown]
# ### 5.2. Estrategia 2: Usar un indicador conjunto para cuantificar la anomalia en funcion de la confianza de cada modelo y el tiempo esperado para la anomalia.

# %%
# print available columns in the anomalies DataFrame inside results

for pair, anomalies in results.items():  

    # look for the first row that reports an anomaly where timepred is not NaT and is different from the start time
    filtered = anomalies[anomalies['time_pred'].notna() & (anomalies['time_pred'] > anomalies['Start Time'])]
    if not filtered.empty:
        first_anomaly_row = filtered.iloc[0]
        print(f"First anomaly row for pair {pair}:")
        print(first_anomaly_row)
        print("\n")
    else:
        print(f"No anomaly found for pair {pair}.\n")
# Out:
# First anomaly row for pair FC y SpO2:
# Start Time                 2025-03-17 02:57:00
# End Time                   2025-03-17 02:59:00
# Anomaly Level                                2
# Anomaly                                   True
# cnt_pred                                   1.0
# max_anomLikelihood_pred                    1.0
# time_pred                  2025-03-17 02:58:00
# anom_pred                                  1.0
# Name: 291, dtype: object
#
#
# First anomaly row for pair FC y ARTs:
# Start Time                 2025-03-17 00:27:00
# End Time                   2025-03-17 00:29:00
# Anomaly Level                                0
# Anomaly                                  False
# cnt_pred                                   1.0
# max_anomLikelihood_pred                    1.0
# time_pred                  2025-03-17 00:28:00
# anom_pred                                  0.0
# Name: 216, dtype: object
#
#
# First anomaly row for pair FC y ARTd:
# Start Time                 2025-03-16 21:29:00
# End Time                   2025-03-16 21:31:00
# Anomaly Level                                2
# Anomaly                                   True
# cnt_pred                                   1.0
# max_anomLikelihood_pred               0.160206
# time_pred                  2025-03-16 21:30:00
# anom_pred                                  1.0
# Name: 127, dtype: object
#
#
# First anomaly row for pair SpO2 y ARTs:
# Start Time                 2025-03-16 17:25:00
# End Time                   2025-03-16 17:27:00
# Anomaly Level                                0
# Anomaly                                  False
# cnt_pred                                   1.0
# max_anomLikelihood_pred               0.112494
# time_pred                  2025-03-16 17:26:00
# anom_pred                                  0.0
# Name: 5, dtype: object
#
#
# First anomaly row for pair SpO2 y ARTd:
# Start Time                 2025-03-16 17:41:00
# End Time                   2025-03-16 17:43:00
# Anomaly Level                                2
# Anomaly                                   True
# cnt_pred                                   1.0
# max_anomLikelihood_pred               0.112494
# time_pred                  2025-03-16 17:42:00
# anom_pred                                  1.0
# Name: 13, dtype: object
#
#
# First anomaly row for pair ARTs y ARTd:
# Start Time                 2025-03-16 17:21:00
# End Time                   2025-03-16 17:23:00
# Anomaly Level                                2
# Anomaly                                   True
# cnt_pred                                   1.0
# max_anomLikelihood_pred               0.112494
# time_pred                  2025-03-16 17:22:00
# anom_pred                                  1.0
# Name: 3, dtype: object

# %%
# Calculate the value of the indicator for each pair of signals in each time window.
# THE VALUE OF THE INDICATOR IS THE PRODUCT OF WHETHER AN ANOMALY WAS PREDICTED (anom_pred == 1), the likelihood of the anomaly (max_anomLikelihood_pred), and the time difference between the predicted time and the start time of the anomaly (if greater than 0, if equal the value is 1).

# use the results from for pair, anomalies in results.items()


def calculate_indicator_value(results_combined):
    
    # create a new dataframe to store the value of the indicator for each pair of signals in each time window.
    indicator_values = []
    
    for pair, anomalies in results.items():

        # for every row in the anomalies DataFrame, calculate the value of the indicator.
        for idx, row in anomalies.iterrows():
            # Calculate the time difference between 'time_pred' and 'Start Time'
            time_diff = (row['time_pred'] - row['Start Time']).total_seconds() / 60
            # If time_diff is negative, set it to 1 (as per your requirement)
            if time_diff < 0:
                time_diff = 1
                
            # Calculate the value of the indicator
            indicator_value = row['anom_pred'] * row['max_anomLikelihood_pred'] * time_diff
            # Append the result to the list
            indicator_values.append({
                'Start Time': row['Start Time'],
                'End Time': row['End Time'],
                'Pair': pair,
                'Indicator Value': indicator_value
            })
            
    # Create a DataFrame from the list of indicator values
    indicator_df = pd.DataFrame(indicator_values)
    # Group by 'Start Time', 'End Time', and 'Pair' to sum the indicator values
    indicator_df = indicator_df.groupby(['Start Time', 'End Time', 'Pair'], as_index=False).sum()
    # Sort the DataFrame by 'Start Time'
    indicator_df.sort_values('Start Time', inplace=True)
    return indicator_df

# %%
# calculate the indicator value for each pair of signals in each time window
results_combined = calculate_indicator_value(results_combined)

# Print the indicator values for each pair of signals in each time window.
print("Indicator values for each pair of signals in each time window:")
print(results_combined[['Start Time', 'End Time', 'Pair', 'Indicator Value']])

# CALCULATE THE PATIENT_INDICATOR AS THE SUM OF THE INDICATOR VALUES FOR EACH PAIR OF SIGNALS IN EACH TIME WINDOW, divided by the number of pairs of signals
def calculate_patient_indicator(indicator_df):
    # Group by 'Start Time' and 'End Time' to sum the indicator values for each time window.
    patient_indicator = indicator_df.groupby(['Start Time', 'End Time'], as_index=False).sum()
    
    # add one to the indicator value to avoid division by zero.
    patient_indicator['Indicator Value'] = patient_indicator['Indicator Value'] + 1
    
    # Calculate the number of pairs of signals in each time window.
    patient_indicator['Num Pairs'] = indicator_df.groupby(['Start Time', 'End Time'])['Pair'].nunique().values
    
    # Calculate the patient indicator as the sum of the indicator values divided by the number of pairs.
    patient_indicator['Indicator Value'] = patient_indicator['Indicator Value'] / patient_indicator['Num Pairs']
    return patient_indicator

# Calculate the patient indicator as the sum of the indicator values for each pair of signals in each time window.
patient_indicator = calculate_patient_indicator(results_combined)
# Print the patient indicator.
print("Patient indicator as the sum of the indicator values for each pair of signals in each time window:")
print(patient_indicator)

# plot the patient indicator over time
def plot_patient_indicator(patient_indicator):
    plt.figure(figsize=(16, 6))
    plt.plot(patient_indicator['Start Time'], patient_indicator['Indicator Value'], marker='o', linestyle='-', color='blue')
    plt.title('Resultados del Indicador del Paciente ' + str(id_paciente) + ' a lo largo del tiempo')
    plt.xlabel('Time')
    plt.ylabel('Indicator Value')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
# Plot the patient indicator over time.
plot_patient_indicator(patient_indicator)
# Out:
# Indicator values for each pair of signals in each time window:
#               Start Time            End Time         Pair  Indicator Value
# 0    2025-03-16 17:15:00 2025-03-16 17:17:00  ARTs y ARTd         0.000000
# 1    2025-03-16 17:15:00 2025-03-16 17:17:00    FC y ARTd         0.000000
# 2    2025-03-16 17:15:00 2025-03-16 17:17:00    FC y ARTs         0.000000
# 3    2025-03-16 17:15:00 2025-03-16 17:17:00    FC y SpO2         0.000000
# 4    2025-03-16 17:15:00 2025-03-16 17:17:00  SpO2 y ARTd         0.000000
# 5    2025-03-16 17:15:00 2025-03-16 17:17:00  SpO2 y ARTs         0.000000
# 11   2025-03-16 17:17:00 2025-03-16 17:19:00  SpO2 y ARTs         0.000000
# 10   2025-03-16 17:17:00 2025-03-16 17:19:00  SpO2 y ARTd         0.000000
# 9    2025-03-16 17:17:00 2025-03-16 17:19:00    FC y SpO2         0.000000
# 7    2025-03-16 17:17:00 2025-03-16 17:19:00    FC y ARTd         0.000000
# 6    2025-03-16 17:17:00 2025-03-16 17:19:00  ARTs y ARTd         0.000000
# 8    2025-03-16 17:17:00 2025-03-16 17:19:00    FC y ARTs         0.000000
# 12   2025-03-16 17:19:00 2025-03-16 17:21:00  ARTs y ARTd         0.000000
# 13   2025-03-16 17:19:00 2025-03-16 17:21:00    FC y ARTd         0.000000
# 14   2025-03-16 17:19:00 2025-03-16 17:21:00    FC y ARTs         0.000000
# 15   2025-03-16 17:19:00 2025-03-16 17:21:00    FC y SpO2         0.000000
# 16   2025-03-16 17:19:00 2025-03-16 17:21:00  SpO2 y ARTd         0.000000
# 17   2025-03-16 17:19:00 2025-03-16 17:21:00  SpO2 y ARTs         0.000000
# 23   2025-03-16 17:21:00 2025-03-16 17:23:00  SpO2 y ARTs         0.000000
# 22   2025-03-16 17:21:00 2025-03-16 17:23:00  SpO2 y ARTd         0.000000
# 21   2025-03-16 17:21:00 2025-03-16 17:23:00    FC y SpO2         0.000000
# 19   2025-03-16 17:21:00 2025-03-16 17:23:00    FC y ARTd         0.000000
# 18   2025-03-16 17:21:00 2025-03-16 17:23:00  ARTs y ARTd         0.112494
# 20   2025-03-16 17:21:00 2025-03-16 17:23:00    FC y ARTs         0.000000
# 24   2025-03-16 17:23:00 2025-03-16 17:25:00  ARTs y ARTd         0.000000
# 25   2025-03-16 17:23:00 2025-03-16 17:25:00    FC y ARTd         0.000000
# 26   2025-03-16 17:23:00 2025-03-16 17:25:00    FC y ARTs         0.000000
# 27   2025-03-16 17:23:00 2025-03-16 17:25:00    FC y SpO2         0.000000
# 28   2025-03-16 17:23:00 2025-03-16 17:25:00  SpO2 y ARTd         0.000000
# 29   2025-03-16 17:23:00 2025-03-16 17:25:00  SpO2 y ARTs         0.000000
# 32   2025-03-16 17:25:00 2025-03-16 17:27:00    FC y ARTs         0.000000
# 35   2025-03-16 17:25:00 2025-03-16 17:27:00  SpO2 y ARTs         0.000000
# 34   2025-03-16 17:25:00 2025-03-16 17:27:00  SpO2 y ARTd         0.000000
# 31   2025-03-16 17:25:00 2025-03-16 17:27:00    FC y ARTd         0.000000
# 30   2025-03-16 17:25:00 2025-03-16 17:27:00  ARTs y ARTd         0.000000
# 33   2025-03-16 17:25:00 2025-03-16 17:27:00    FC y SpO2         0.000000
# 40   2025-03-16 17:27:00 2025-03-16 17:29:00  SpO2 y ARTd         0.000000
# 36   2025-03-16 17:27:00 2025-03-16 17:29:00  ARTs y ARTd         0.000000
# 37   2025-03-16 17:27:00 2025-03-16 17:29:00    FC y ARTd         0.000000
# 38   2025-03-16 17:27:00 2025-03-16 17:29:00    FC y ARTs         0.000000
# 39   2025-03-16 17:27:00 2025-03-16 17:29:00    FC y SpO2         0.000000
# 41   2025-03-16 17:27:00 2025-03-16 17:29:00  SpO2 y ARTs         0.000000
# 47   2025-03-16 17:29:00 2025-03-16 17:31:00  SpO2 y ARTs         0.000000
# 46   2025-03-16 17:29:00 2025-03-16 17:31:00  SpO2 y ARTd         0.000000
# 45   2025-03-16 17:29:00 2025-03-16 17:31:00    FC y SpO2         0.000000
# 44   2025-03-16 17:29:00 2025-03-16 17:31:00    FC y ARTs         0.000000
# 43   2025-03-16 17:29:00 2025-03-16 17:31:00    FC y ARTd         0.000000
# 42   2025-03-16 17:29:00 2025-03-16 17:31:00  ARTs y ARTd         0.000000
# 48   2025-03-16 17:31:00 2025-03-16 17:33:00  ARTs y ARTd         0.000000
# 49   2025-03-16 17:31:00 2025-03-16 17:33:00    FC y ARTd         0.000000
# 50   2025-03-16 17:31:00 2025-03-16 17:33:00    FC y ARTs         0.000000
# 51   2025-03-16 17:31:00 2025-03-16 17:33:00    FC y SpO2         0.000000
# 52   2025-03-16 17:31:00 2025-03-16 17:33:00  SpO2 y ARTd         0.000000
# 53   2025-03-16 17:31:00 2025-03-16 17:33:00  SpO2 y ARTs         0.000000
# 59   2025-03-16 17:33:00 2025-03-16 17:35:00  SpO2 y ARTs         0.000000
# 58   2025-03-16 17:33:00 2025-03-16 17:35:00  SpO2 y ARTd         0.000000
# 57   2025-03-16 17:33:00 2025-03-16 17:35:00    FC y SpO2         0.000000
# 56   2025-03-16 17:33:00 2025-03-16 17:35:00    FC y ARTs         0.000000
# 55   2025-03-16 17:33:00 2025-03-16 17:35:00    FC y ARTd         0.000000
# 54   2025-03-16 17:33:00 2025-03-16 17:35:00  ARTs y ARTd         0.000000
# 60   2025-03-16 17:35:00 2025-03-16 17:37:00  ARTs y ARTd         1.000000
# 61   2025-03-16 17:35:00 2025-03-16 17:37:00    FC y ARTd         0.000000
# 62   2025-03-16 17:35:00 2025-03-16 17:37:00    FC y ARTs         0.000000
# 63   2025-03-16 17:35:00 2025-03-16 17:37:00    FC y SpO2         0.000000
# 64   2025-03-16 17:35:00 2025-03-16 17:37:00  SpO2 y ARTd         0.000000
# 65   2025-03-16 17:35:00 2025-03-16 17:37:00  SpO2 y ARTs         0.000000
# 71   2025-03-16 17:37:00 2025-03-16 17:39:00  SpO2 y ARTs         0.000000
# 70   2025-03-16 17:37:00 2025-03-16 17:39:00  SpO2 y ARTd         0.000000
# 68   2025-03-16 17:37:00 2025-03-16 17:39:00    FC y ARTs         0.000000
# 67   2025-03-16 17:37:00 2025-03-16 17:39:00    FC y ARTd         0.000000
# 66   2025-03-16 17:37:00 2025-03-16 17:39:00  ARTs y ARTd         0.000000
# 69   2025-03-16 17:37:00 2025-03-16 17:39:00    FC y SpO2         0.000000
# 72   2025-03-16 17:39:00 2025-03-16 17:41:00  ARTs y ARTd         0.000000
# 73   2025-03-16 17:39:00 2025-03-16 17:41:00    FC y ARTd         0.000000
# 74   2025-03-16 17:39:00 2025-03-16 17:41:00    FC y ARTs         0.000000
# 75   2025-03-16 17:39:00 2025-03-16 17:41:00    FC y SpO2         0.000000
# 76   2025-03-16 17:39:00 2025-03-16 17:41:00  SpO2 y ARTd         0.000000
# 77   2025-03-16 17:39:00 2025-03-16 17:41:00  SpO2 y ARTs         0.000000
# 79   2025-03-16 17:41:00 2025-03-16 17:43:00    FC y ARTd         0.000000
# 78   2025-03-16 17:41:00 2025-03-16 17:43:00  ARTs y ARTd         0.000000
# 80   2025-03-16 17:41:00 2025-03-16 17:43:00    FC y ARTs         0.000000
# 81   2025-03-16 17:41:00 2025-03-16 17:43:00    FC y SpO2         0.000000
# 82   2025-03-16 17:41:00 2025-03-16 17:43:00  SpO2 y ARTd         0.112494
# 83   2025-03-16 17:41:00 2025-03-16 17:43:00  SpO2 y ARTs         0.160206
# 87   2025-03-16 17:43:00 2025-03-16 17:45:00    FC y SpO2         0.000000
# 86   2025-03-16 17:43:00 2025-03-16 17:45:00    FC y ARTs         0.000000
# 88   2025-03-16 17:43:00 2025-03-16 17:45:00  SpO2 y ARTd         0.000000
# 84   2025-03-16 17:43:00 2025-03-16 17:45:00  ARTs y ARTd         0.000000
# 85   2025-03-16 17:43:00 2025-03-16 17:45:00    FC y ARTd         0.000000
# 89   2025-03-16 17:43:00 2025-03-16 17:45:00  SpO2 y ARTs         0.000000
# 95   2025-03-16 17:45:00 2025-03-16 17:47:00  SpO2 y ARTs         0.000000
# 93   2025-03-16 17:45:00 2025-03-16 17:47:00    FC y SpO2         0.000000
# 94   2025-03-16 17:45:00 2025-03-16 17:47:00  SpO2 y ARTd         0.000000
# 91   2025-03-16 17:45:00 2025-03-16 17:47:00    FC y ARTd         0.000000
# 90   2025-03-16 17:45:00 2025-03-16 17:47:00  ARTs y ARTd         0.000000
# 92   2025-03-16 17:45:00 2025-03-16 17:47:00    FC y ARTs         0.000000
# 96   2025-03-16 17:47:00 2025-03-16 17:49:00  ARTs y ARTd         0.000000
# 97   2025-03-16 17:47:00 2025-03-16 17:49:00    FC y ARTd         0.000000
# 98   2025-03-16 17:47:00 2025-03-16 17:49:00    FC y ARTs         0.000000
# 99   2025-03-16 17:47:00 2025-03-16 17:49:00    FC y SpO2         0.000000
# 100  2025-03-16 17:47:00 2025-03-16 17:49:00  SpO2 y ARTd         0.000000
# 101  2025-03-16 17:47:00 2025-03-16 17:49:00  SpO2 y ARTs         0.000000
# 107  2025-03-16 17:49:00 2025-03-16 17:51:00  SpO2 y ARTs         0.000000
# 106  2025-03-16 17:49:00 2025-03-16 17:51:00  SpO2 y ARTd         0.000000
# 105  2025-03-16 17:49:00 2025-03-16 17:51:00    FC y SpO2         0.000000
# 103  2025-03-16 17:49:00 2025-03-16 17:51:00    FC y ARTd         0.000000
# 102  2025-03-16 17:49:00 2025-03-16 17:51:00  ARTs y ARTd         0.000000
# 104  2025-03-16 17:49:00 2025-03-16 17:51:00    FC y ARTs         0.000000
# 108  2025-03-16 17:51:00 2025-03-16 17:53:00  ARTs y ARTd         0.000000
# 109  2025-03-16 17:51:00 2025-03-16 17:53:00    FC y ARTd         0.000000
# 110  2025-03-16 17:51:00 2025-03-16 17:53:00    FC y ARTs         0.000000
# 111  2025-03-16 17:51:00 2025-03-16 17:53:00    FC y SpO2         0.000000
# 112  2025-03-16 17:51:00 2025-03-16 17:53:00  SpO2 y ARTd         0.000000
# 113  2025-03-16 17:51:00 2025-03-16 17:53:00  SpO2 y ARTs         0.000000
# 119  2025-03-16 17:53:00 2025-03-16 17:55:00  SpO2 y ARTs         0.000000
# 117  2025-03-16 17:53:00 2025-03-16 17:55:00    FC y SpO2         0.000000
# 118  2025-03-16 17:53:00 2025-03-16 17:55:00  SpO2 y ARTd         0.000000
# 115  2025-03-16 17:53:00 2025-03-16 17:55:00    FC y ARTd         0.000000
# 114  2025-03-16 17:53:00 2025-03-16 17:55:00  ARTs y ARTd         0.000000
# 116  2025-03-16 17:53:00 2025-03-16 17:55:00    FC y ARTs         0.000000
# 120  2025-03-16 17:55:00 2025-03-16 17:57:00  ARTs y ARTd         0.000000
# 121  2025-03-16 17:55:00 2025-03-16 17:57:00    FC y ARTd         0.000000
# 122  2025-03-16 17:55:00 2025-03-16 17:57:00    FC y ARTs         0.000000
# 123  2025-03-16 17:55:00 2025-03-16 17:57:00    FC y SpO2         0.000000
# 124  2025-03-16 17:55:00 2025-03-16 17:57:00  SpO2 y ARTd         0.000000
# 125  2025-03-16 17:55:00 2025-03-16 17:57:00  SpO2 y ARTs         0.000000
# 131  2025-03-16 17:57:00 2025-03-16 17:59:00  SpO2 y ARTs         0.000000
# 129  2025-03-16 17:57:00 2025-03-16 17:59:00    FC y SpO2         0.000000
# 130  2025-03-16 17:57:00 2025-03-16 17:59:00  SpO2 y ARTd         0.000000
# 127  2025-03-16 17:57:00 2025-03-16 17:59:00    FC y ARTd         0.000000
# 126  2025-03-16 17:57:00 2025-03-16 17:59:00  ARTs y ARTd         0.000000
# 128  2025-03-16 17:57:00 2025-03-16 17:59:00    FC y ARTs         0.000000
# 132  2025-03-16 17:59:00 2025-03-16 18:01:00  ARTs y ARTd         0.000000
# 133  2025-03-16 17:59:00 2025-03-16 18:01:00    FC y ARTd         0.000000
# 134  2025-03-16 17:59:00 2025-03-16 18:01:00    FC y ARTs         0.000000
# 135  2025-03-16 17:59:00 2025-03-16 18:01:00    FC y SpO2         0.000000
# 136  2025-03-16 17:59:00 2025-03-16 18:01:00  SpO2 y ARTd         0.000000
# 137  2025-03-16 17:59:00 2025-03-16 18:01:00  SpO2 y ARTs         0.000000
# 143  2025-03-16 18:01:00 2025-03-16 18:03:00  SpO2 y ARTs         0.000000
# 142  2025-03-16 18:01:00 2025-03-16 18:03:00  SpO2 y ARTd         0.000000
# 141  2025-03-16 18:01:00 2025-03-16 18:03:00    FC y SpO2         0.000000
# 140  2025-03-16 18:01:00 2025-03-16 18:03:00    FC y ARTs         0.000000
# 138  2025-03-16 18:01:00 2025-03-16 18:03:00  ARTs y ARTd         0.000000
# 139  2025-03-16 18:01:00 2025-03-16 18:03:00    FC y ARTd         0.000000
# 144  2025-03-16 18:03:00 2025-03-16 18:05:00  ARTs y ARTd         0.000000
# 145  2025-03-16 18:03:00 2025-03-16 18:05:00    FC y ARTd         0.000000
# 146  2025-03-16 18:03:00 2025-03-16 18:05:00    FC y ARTs         0.000000
# 147  2025-03-16 18:03:00 2025-03-16 18:05:00    FC y SpO2         0.000000
# 148  2025-03-16 18:03:00 2025-03-16 18:05:00  SpO2 y ARTd         0.000000
# 149  2025-03-16 18:03:00 2025-03-16 18:05:00  SpO2 y ARTs         0.000000
# 155  2025-03-16 18:05:00 2025-03-16 18:07:00  SpO2 y ARTs         0.000000
# 154  2025-03-16 18:05:00 2025-03-16 18:07:00  SpO2 y ARTd         0.000000
# 153  2025-03-16 18:05:00 2025-03-16 18:07:00    FC y SpO2         0.000000
# 151  2025-03-16 18:05:00 2025-03-16 18:07:00    FC y ARTd         0.000000
# 150  2025-03-16 18:05:00 2025-03-16 18:07:00  ARTs y ARTd         0.000000
# 152  2025-03-16 18:05:00 2025-03-16 18:07:00    FC y ARTs         0.000000
# 156  2025-03-16 18:07:00 2025-03-16 18:09:00  ARTs y ARTd         0.000000
# 157  2025-03-16 18:07:00 2025-03-16 18:09:00    FC y ARTd         0.000000
# 158  2025-03-16 18:07:00 2025-03-16 18:09:00    FC y ARTs         0.000000
# 159  2025-03-16 18:07:00 2025-03-16 18:09:00    FC y SpO2         0.000000
# 160  2025-03-16 18:07:00 2025-03-16 18:09:00  SpO2 y ARTd         0.000000
# 161  2025-03-16 18:07:00 2025-03-16 18:09:00  SpO2 y ARTs         0.000000
# 167  2025-03-16 18:09:00 2025-03-16 18:11:00  SpO2 y ARTs         0.000000
# 166  2025-03-16 18:09:00 2025-03-16 18:11:00  SpO2 y ARTd         0.000000
# 165  2025-03-16 18:09:00 2025-03-16 18:11:00    FC y SpO2         0.000000
# 163  2025-03-16 18:09:00 2025-03-16 18:11:00    FC y ARTd         0.000000
# 162  2025-03-16 18:09:00 2025-03-16 18:11:00  ARTs y ARTd         0.000000
# 164  2025-03-16 18:09:00 2025-03-16 18:11:00    FC y ARTs         0.000000
# 168  2025-03-16 18:11:00 2025-03-16 18:13:00  ARTs y ARTd         0.000000
# 169  2025-03-16 18:11:00 2025-03-16 18:13:00    FC y ARTd         0.000000
# 170  2025-03-16 18:11:00 2025-03-16 18:13:00    FC y ARTs         0.000000
# 171  2025-03-16 18:11:00 2025-03-16 18:13:00    FC y SpO2         0.000000
# 172  2025-03-16 18:11:00 2025-03-16 18:13:00  SpO2 y ARTd         0.000000
# 173  2025-03-16 18:11:00 2025-03-16 18:13:00  SpO2 y ARTs         0.000000
# 179  2025-03-16 18:13:00 2025-03-16 18:15:00  SpO2 y ARTs         0.000000
# 178  2025-03-16 18:13:00 2025-03-16 18:15:00  SpO2 y ARTd         0.000000
# 177  2025-03-16 18:13:00 2025-03-16 18:15:00    FC y SpO2         0.000000
# 176  2025-03-16 18:13:00 2025-03-16 18:15:00    FC y ARTs         0.000000
# 174  2025-03-16 18:13:00 2025-03-16 18:15:00  ARTs y ARTd         0.000000
# 175  2025-03-16 18:13:00 2025-03-16 18:15:00    FC y ARTd         0.000000
# 180  2025-03-16 18:15:00 2025-03-16 18:17:00  ARTs y ARTd         0.000000
# 181  2025-03-16 18:15:00 2025-03-16 18:17:00    FC y ARTd         0.000000
# 182  2025-03-16 18:15:00 2025-03-16 18:17:00    FC y ARTs         0.000000
# 183  2025-03-16 18:15:00 2025-03-16 18:17:00    FC y SpO2         0.000000
# 184  2025-03-16 18:15:00 2025-03-16 18:17:00  SpO2 y ARTd         0.000000
# 185  2025-03-16 18:15:00 2025-03-16 18:17:00  SpO2 y ARTs         0.000000
# 190  2025-03-16 18:17:00 2025-03-16 18:19:00  SpO2 y ARTd         0.000000
# 191  2025-03-16 18:17:00 2025-03-16 18:19:00  SpO2 y ARTs         0.000000
# 189  2025-03-16 18:17:00 2025-03-16 18:19:00    FC y SpO2         0.000000
# 187  2025-03-16 18:17:00 2025-03-16 18:19:00    FC y ARTd         0.000000
# 188  2025-03-16 18:17:00 2025-03-16 18:19:00    FC y ARTs         0.000000
# 186  2025-03-16 18:17:00 2025-03-16 18:19:00  ARTs y ARTd         0.000000
# 192  2025-03-16 18:19:00 2025-03-16 18:21:00  ARTs y ARTd         0.000000
# 193  2025-03-16 18:19:00 2025-03-16 18:21:00    FC y ARTd         0.000000
# 194  2025-03-16 18:19:00 2025-03-16 18:21:00    FC y ARTs         0.000000
# 195  2025-03-16 18:19:00 2025-03-16 18:21:00    FC y SpO2         0.000000
# 196  2025-03-16 18:19:00 2025-03-16 18:21:00  SpO2 y ARTd         0.000000
# 197  2025-03-16 18:19:00 2025-03-16 18:21:00  SpO2 y ARTs         0.000000
# 203  2025-03-16 18:21:00 2025-03-16 18:23:00  SpO2 y ARTs         0.000000
# 202  2025-03-16 18:21:00 2025-03-16 18:23:00  SpO2 y ARTd         0.000000
# 201  2025-03-16 18:21:00 2025-03-16 18:23:00    FC y SpO2         0.000000
# 199  2025-03-16 18:21:00 2025-03-16 18:23:00    FC y ARTd         0.000000
# 198  2025-03-16 18:21:00 2025-03-16 18:23:00  ARTs y ARTd         0.000000
# 200  2025-03-16 18:21:00 2025-03-16 18:23:00    FC y ARTs         0.000000
# 204  2025-03-16 18:23:00 2025-03-16 18:25:00  ARTs y ARTd         0.000000
# 205  2025-03-16 18:23:00 2025-03-16 18:25:00    FC y ARTd         0.000000
# 206  2025-03-16 18:23:00 2025-03-16 18:25:00    FC y ARTs         0.000000
# 207  2025-03-16 18:23:00 2025-03-16 18:25:00    FC y SpO2         0.000000
# 208  2025-03-16 18:23:00 2025-03-16 18:25:00  SpO2 y ARTd         0.000000
# 209  2025-03-16 18:23:00 2025-03-16 18:25:00  SpO2 y ARTs         0.000000
# 214  2025-03-16 18:25:00 2025-03-16 18:27:00  SpO2 y ARTd         0.000000
# 215  2025-03-16 18:25:00 2025-03-16 18:27:00  SpO2 y ARTs         0.000000
# 213  2025-03-16 18:25:00 2025-03-16 18:27:00    FC y SpO2         0.000000
# 212  2025-03-16 18:25:00 2025-03-16 18:27:00    FC y ARTs         0.000000
# 211  2025-03-16 18:25:00 2025-03-16 18:27:00    FC y ARTd         0.000000
# 210  2025-03-16 18:25:00 2025-03-16 18:27:00  ARTs y ARTd         0.000000
# 216  2025-03-16 18:27:00 2025-03-16 18:29:00  ARTs y ARTd         0.000000
# 217  2025-03-16 18:27:00 2025-03-16 18:29:00    FC y ARTd         0.000000
# 218  2025-03-16 18:27:00 2025-03-16 18:29:00    FC y ARTs         0.000000
# 219  2025-03-16 18:27:00 2025-03-16 18:29:00    FC y SpO2         0.000000
# 220  2025-03-16 18:27:00 2025-03-16 18:29:00  SpO2 y ARTd         0.000000
# 221  2025-03-16 18:27:00 2025-03-16 18:29:00  SpO2 y ARTs         0.000000
# 227  2025-03-16 18:29:00 2025-03-16 18:31:00  SpO2 y ARTs         0.000000
# 226  2025-03-16 18:29:00 2025-03-16 18:31:00  SpO2 y ARTd         0.000000
# 225  2025-03-16 18:29:00 2025-03-16 18:31:00    FC y SpO2         0.000000
# 224  2025-03-16 18:29:00 2025-03-16 18:31:00    FC y ARTs         0.000000
# 223  2025-03-16 18:29:00 2025-03-16 18:31:00    FC y ARTd         0.000000
# 222  2025-03-16 18:29:00 2025-03-16 18:31:00  ARTs y ARTd         0.000000
# 228  2025-03-16 18:31:00 2025-03-16 18:33:00  ARTs y ARTd         0.000000
# 229  2025-03-16 18:31:00 2025-03-16 18:33:00    FC y ARTd         0.000000
# 230  2025-03-16 18:31:00 2025-03-16 18:33:00    FC y ARTs         0.000000
# 231  2025-03-16 18:31:00 2025-03-16 18:33:00    FC y SpO2         0.000000
# 232  2025-03-16 18:31:00 2025-03-16 18:33:00  SpO2 y ARTd         0.000000
# 233  2025-03-16 18:31:00 2025-03-16 18:33:00  SpO2 y ARTs         0.000000
# 239  2025-03-16 18:33:00 2025-03-16 18:35:00  SpO2 y ARTs         0.000000
# 238  2025-03-16 18:33:00 2025-03-16 18:35:00  SpO2 y ARTd         0.000000
# 237  2025-03-16 18:33:00 2025-03-16 18:35:00    FC y SpO2         0.000000
# 235  2025-03-16 18:33:00 2025-03-16 18:35:00    FC y ARTd         0.000000
# 234  2025-03-16 18:33:00 2025-03-16 18:35:00  ARTs y ARTd         0.000000
# 236  2025-03-16 18:33:00 2025-03-16 18:35:00    FC y ARTs         0.000000
# 244  2025-03-16 18:35:00 2025-03-16 18:37:00  SpO2 y ARTd         0.000000
# 243  2025-03-16 18:35:00 2025-03-16 18:37:00    FC y SpO2         0.000000
# 245  2025-03-16 18:35:00 2025-03-16 18:37:00  SpO2 y ARTs         0.000000
# 241  2025-03-16 18:35:00 2025-03-16 18:37:00    FC y ARTd         0.000000
# 240  2025-03-16 18:35:00 2025-03-16 18:37:00  ARTs y ARTd         0.000000
# 242  2025-03-16 18:35:00 2025-03-16 18:37:00    FC y ARTs         0.000000
# 246  2025-03-16 18:37:00 2025-03-16 18:39:00  ARTs y ARTd         0.000000
# 247  2025-03-16 18:37:00 2025-03-16 18:39:00    FC y ARTd         0.000000
# 248  2025-03-16 18:37:00 2025-03-16 18:39:00    FC y ARTs         0.000000
# 249  2025-03-16 18:37:00 2025-03-16 18:39:00    FC y SpO2         0.000000
# 250  2025-03-16 18:37:00 2025-03-16 18:39:00  SpO2 y ARTd         0.000000
# 251  2025-03-16 18:37:00 2025-03-16 18:39:00  SpO2 y ARTs         0.000000
# 256  2025-03-16 18:39:00 2025-03-16 18:41:00  SpO2 y ARTd         0.000000
# 255  2025-03-16 18:39:00 2025-03-16 18:41:00    FC y SpO2         0.000000
# 257  2025-03-16 18:39:00 2025-03-16 18:41:00  SpO2 y ARTs         0.000000
# 253  2025-03-16 18:39:00 2025-03-16 18:41:00    FC y ARTd         0.000000
# 252  2025-03-16 18:39:00 2025-03-16 18:41:00  ARTs y ARTd         0.130103
# 254  2025-03-16 18:39:00 2025-03-16 18:41:00    FC y ARTs         0.000000
# 258  2025-03-16 18:41:00 2025-03-16 18:43:00  ARTs y ARTd         0.000000
# 259  2025-03-16 18:41:00 2025-03-16 18:43:00    FC y ARTd         0.000000
# 260  2025-03-16 18:41:00 2025-03-16 18:43:00    FC y ARTs         0.000000
# 261  2025-03-16 18:41:00 2025-03-16 18:43:00    FC y SpO2         0.000000
# 262  2025-03-16 18:41:00 2025-03-16 18:43:00  SpO2 y ARTd         0.000000
# 263  2025-03-16 18:41:00 2025-03-16 18:43:00  SpO2 y ARTs         0.000000
# 269  2025-03-16 18:43:00 2025-03-16 18:45:00  SpO2 y ARTs         0.000000
# 268  2025-03-16 18:43:00 2025-03-16 18:45:00  SpO2 y ARTd         0.000000
# 267  2025-03-16 18:43:00 2025-03-16 18:45:00    FC y SpO2         0.000000
# 266  2025-03-16 18:43:00 2025-03-16 18:45:00    FC y ARTs         0.000000
# 264  2025-03-16 18:43:00 2025-03-16 18:45:00  ARTs y ARTd         0.000000
# 265  2025-03-16 18:43:00 2025-03-16 18:45:00    FC y ARTd         0.000000
# 270  2025-03-16 18:45:00 2025-03-16 18:47:00  ARTs y ARTd         0.000000
# 271  2025-03-16 18:45:00 2025-03-16 18:47:00    FC y ARTd         0.000000
# 272  2025-03-16 18:45:00 2025-03-16 18:47:00    FC y ARTs         0.000000
# 273  2025-03-16 18:45:00 2025-03-16 18:47:00    FC y SpO2         0.000000
# 274  2025-03-16 18:45:00 2025-03-16 18:47:00  SpO2 y ARTd         0.000000
# 275  2025-03-16 18:45:00 2025-03-16 18:47:00  SpO2 y ARTs         0.000000
# 281  2025-03-16 18:47:00 2025-03-16 18:49:00  SpO2 y ARTs         0.000000
# 279  2025-03-16 18:47:00 2025-03-16 18:49:00    FC y SpO2         0.000000
# 280  2025-03-16 18:47:00 2025-03-16 18:49:00  SpO2 y ARTd         0.000000
# 277  2025-03-16 18:47:00 2025-03-16 18:49:00    FC y ARTd         0.000000
# 276  2025-03-16 18:47:00 2025-03-16 18:49:00  ARTs y ARTd         0.000000
# 278  2025-03-16 18:47:00 2025-03-16 18:49:00    FC y ARTs         0.000000
# 287  2025-03-16 18:49:00 2025-03-16 18:51:00  SpO2 y ARTs         0.000000
# 286  2025-03-16 18:49:00 2025-03-16 18:51:00  SpO2 y ARTd         0.000000
# 285  2025-03-16 18:49:00 2025-03-16 18:51:00    FC y SpO2         0.000000
# 282  2025-03-16 18:49:00 2025-03-16 18:51:00  ARTs y ARTd         0.000000
# 283  2025-03-16 18:49:00 2025-03-16 18:51:00    FC y ARTd         0.000000
# 284  2025-03-16 18:49:00 2025-03-16 18:51:00    FC y ARTs         0.000000
# 288  2025-03-16 18:51:00 2025-03-16 18:53:00  ARTs y ARTd         0.000000
# 289  2025-03-16 18:51:00 2025-03-16 18:53:00    FC y ARTd         0.000000
# 290  2025-03-16 18:51:00 2025-03-16 18:53:00    FC y ARTs         0.000000
# 291  2025-03-16 18:51:00 2025-03-16 18:53:00    FC y SpO2         0.000000
# 292  2025-03-16 18:51:00 2025-03-16 18:53:00  SpO2 y ARTd         0.000000
# 293  2025-03-16 18:51:00 2025-03-16 18:53:00  SpO2 y ARTs         0.000000
# 294  2025-03-16 18:53:00 2025-03-16 18:55:00  ARTs y ARTd         0.000000
# 295  2025-03-16 18:53:00 2025-03-16 18:55:00    FC y ARTd         0.000000
# 296  2025-03-16 18:53:00 2025-03-16 18:55:00    FC y ARTs         0.000000
# 297  2025-03-16 18:53:00 2025-03-16 18:55:00    FC y SpO2         0.000000
# 298  2025-03-16 18:53:00 2025-03-16 18:55:00  SpO2 y ARTd         0.000000
# 299  2025-03-16 18:53:00 2025-03-16 18:55:00  SpO2 y ARTs         0.000000
# 304  2025-03-16 18:55:00 2025-03-16 18:57:00  SpO2 y ARTd         0.000000
# 303  2025-03-16 18:55:00 2025-03-16 18:57:00    FC y SpO2         0.000000
# 305  2025-03-16 18:55:00 2025-03-16 18:57:00  SpO2 y ARTs         0.000000
# 301  2025-03-16 18:55:00 2025-03-16 18:57:00    FC y ARTd         0.000000
# 300  2025-03-16 18:55:00 2025-03-16 18:57:00  ARTs y ARTd         0.000000
# 302  2025-03-16 18:55:00 2025-03-16 18:57:00    FC y ARTs         0.000000
# 306  2025-03-16 18:57:00 2025-03-16 18:59:00  ARTs y ARTd         0.000000
# 307  2025-03-16 18:57:00 2025-03-16 18:59:00    FC y ARTd         0.000000
# 308  2025-03-16 18:57:00 2025-03-16 18:59:00    FC y ARTs         0.000000
# 309  2025-03-16 18:57:00 2025-03-16 18:59:00    FC y SpO2         0.000000
# 310  2025-03-16 18:57:00 2025-03-16 18:59:00  SpO2 y ARTd         0.000000
# 311  2025-03-16 18:57:00 2025-03-16 18:59:00  SpO2 y ARTs         0.000000
# 317  2025-03-16 18:59:00 2025-03-16 19:01:00  SpO2 y ARTs         0.000000
# 316  2025-03-16 18:59:00 2025-03-16 19:01:00  SpO2 y ARTd         0.000000
# 315  2025-03-16 18:59:00 2025-03-16 19:01:00    FC y SpO2         0.000000
# 314  2025-03-16 18:59:00 2025-03-16 19:01:00    FC y ARTs         0.000000
# 312  2025-03-16 18:59:00 2025-03-16 19:01:00  ARTs y ARTd         0.000000
# 313  2025-03-16 18:59:00 2025-03-16 19:01:00    FC y ARTd         0.000000
# 318  2025-03-16 19:01:00 2025-03-16 19:03:00  ARTs y ARTd         0.000000
# 319  2025-03-16 19:01:00 2025-03-16 19:03:00    FC y ARTd         0.000000
# 320  2025-03-16 19:01:00 2025-03-16 19:03:00    FC y ARTs         0.000000
# 321  2025-03-16 19:01:00 2025-03-16 19:03:00    FC y SpO2         0.000000
# 322  2025-03-16 19:01:00 2025-03-16 19:03:00  SpO2 y ARTd         0.000000
# 323  2025-03-16 19:01:00 2025-03-16 19:03:00  SpO2 y ARTs         0.000000
# 329  2025-03-16 19:03:00 2025-03-16 19:05:00  SpO2 y ARTs         0.000000
# 327  2025-03-16 19:03:00 2025-03-16 19:05:00    FC y SpO2         0.000000
# 328  2025-03-16 19:03:00 2025-03-16 19:05:00  SpO2 y ARTd         0.000000
# 325  2025-03-16 19:03:00 2025-03-16 19:05:00    FC y ARTd         0.000000
# 324  2025-03-16 19:03:00 2025-03-16 19:05:00  ARTs y ARTd         0.000000
# 326  2025-03-16 19:03:00 2025-03-16 19:05:00    FC y ARTs         0.000000
# 330  2025-03-16 19:05:00 2025-03-16 19:07:00  ARTs y ARTd         0.000000
# 331  2025-03-16 19:05:00 2025-03-16 19:07:00    FC y ARTd         0.000000
# 332  2025-03-16 19:05:00 2025-03-16 19:07:00    FC y ARTs         0.000000
# 333  2025-03-16 19:05:00 2025-03-16 19:07:00    FC y SpO2         0.000000
# 334  2025-03-16 19:05:00 2025-03-16 19:07:00  SpO2 y ARTd         0.000000
# 335  2025-03-16 19:05:00 2025-03-16 19:07:00  SpO2 y ARTs         0.000000
# 341  2025-03-16 19:07:00 2025-03-16 19:09:00  SpO2 y ARTs         0.000000
# 340  2025-03-16 19:07:00 2025-03-16 19:09:00  SpO2 y ARTd         0.000000
# 339  2025-03-16 19:07:00 2025-03-16 19:09:00    FC y SpO2         0.000000
# 338  2025-03-16 19:07:00 2025-03-16 19:09:00    FC y ARTs         0.000000
# 336  2025-03-16 19:07:00 2025-03-16 19:09:00  ARTs y ARTd         0.000000
# 337  2025-03-16 19:07:00 2025-03-16 19:09:00    FC y ARTd         0.000000
# 342  2025-03-16 19:09:00 2025-03-16 19:11:00  ARTs y ARTd         0.000000
# 343  2025-03-16 19:09:00 2025-03-16 19:11:00    FC y ARTd         0.000000
# 344  2025-03-16 19:09:00 2025-03-16 19:11:00    FC y ARTs         0.000000
# 345  2025-03-16 19:09:00 2025-03-16 19:11:00    FC y SpO2         0.000000
# 346  2025-03-16 19:09:00 2025-03-16 19:11:00  SpO2 y ARTd         0.000000
# 347  2025-03-16 19:09:00 2025-03-16 19:11:00  SpO2 y ARTs         0.000000
# 353  2025-03-16 19:11:00 2025-03-16 19:13:00  SpO2 y ARTs         0.000000
# 352  2025-03-16 19:11:00 2025-03-16 19:13:00  SpO2 y ARTd         0.000000
# 351  2025-03-16 19:11:00 2025-03-16 19:13:00    FC y SpO2         0.000000
# 349  2025-03-16 19:11:00 2025-03-16 19:13:00    FC y ARTd         0.000000
# 348  2025-03-16 19:11:00 2025-03-16 19:13:00  ARTs y ARTd         0.000000
# 350  2025-03-16 19:11:00 2025-03-16 19:13:00    FC y ARTs         0.000000
# 354  2025-03-16 19:13:00 2025-03-16 19:15:00  ARTs y ARTd         0.000000
# 355  2025-03-16 19:13:00 2025-03-16 19:15:00    FC y ARTd         0.000000
# 356  2025-03-16 19:13:00 2025-03-16 19:15:00    FC y ARTs         0.000000
# 357  2025-03-16 19:13:00 2025-03-16 19:15:00    FC y SpO2         0.000000
# 358  2025-03-16 19:13:00 2025-03-16 19:15:00  SpO2 y ARTd         0.000000
# 359  2025-03-16 19:13:00 2025-03-16 19:15:00  SpO2 y ARTs         0.000000
# 365  2025-03-16 19:15:00 2025-03-16 19:17:00  SpO2 y ARTs         0.000000
# 364  2025-03-16 19:15:00 2025-03-16 19:17:00  SpO2 y ARTd         0.000000
# 363  2025-03-16 19:15:00 2025-03-16 19:17:00    FC y SpO2         0.000000
# 361  2025-03-16 19:15:00 2025-03-16 19:17:00    FC y ARTd         0.000000
# 360  2025-03-16 19:15:00 2025-03-16 19:17:00  ARTs y ARTd         0.000000
# 362  2025-03-16 19:15:00 2025-03-16 19:17:00    FC y ARTs         0.000000
# 370  2025-03-16 19:17:00 2025-03-16 19:19:00  SpO2 y ARTd         0.000000
# 366  2025-03-16 19:17:00 2025-03-16 19:19:00  ARTs y ARTd         0.000000
# 367  2025-03-16 19:17:00 2025-03-16 19:19:00    FC y ARTd         0.000000
# 368  2025-03-16 19:17:00 2025-03-16 19:19:00    FC y ARTs         0.000000
# 369  2025-03-16 19:17:00 2025-03-16 19:19:00    FC y SpO2         0.000000
# 371  2025-03-16 19:17:00 2025-03-16 19:19:00  SpO2 y ARTs         0.000000
# 376  2025-03-16 19:19:00 2025-03-16 19:21:00  SpO2 y ARTd         0.000000
# 377  2025-03-16 19:19:00 2025-03-16 19:21:00  SpO2 y ARTs         0.000000
# 375  2025-03-16 19:19:00 2025-03-16 19:21:00    FC y SpO2         0.000000
# 372  2025-03-16 19:19:00 2025-03-16 19:21:00  ARTs y ARTd         0.000000
# 373  2025-03-16 19:19:00 2025-03-16 19:21:00    FC y ARTd         0.000000
# 374  2025-03-16 19:19:00 2025-03-16 19:21:00    FC y ARTs         0.000000
# 378  2025-03-16 19:21:00 2025-03-16 19:23:00  ARTs y ARTd         0.000000
# 379  2025-03-16 19:21:00 2025-03-16 19:23:00    FC y ARTd         0.000000
# 380  2025-03-16 19:21:00 2025-03-16 19:23:00    FC y ARTs         0.000000
# 381  2025-03-16 19:21:00 2025-03-16 19:23:00    FC y SpO2         0.000000
# 382  2025-03-16 19:21:00 2025-03-16 19:23:00  SpO2 y ARTd         0.000000
# 383  2025-03-16 19:21:00 2025-03-16 19:23:00  SpO2 y ARTs         0.000000
# 389  2025-03-16 19:23:00 2025-03-16 19:25:00  SpO2 y ARTs         0.000000
# 388  2025-03-16 19:23:00 2025-03-16 19:25:00  SpO2 y ARTd         0.000000
# 387  2025-03-16 19:23:00 2025-03-16 19:25:00    FC y SpO2         0.000000
# 385  2025-03-16 19:23:00 2025-03-16 19:25:00    FC y ARTd         0.000000
# 384  2025-03-16 19:23:00 2025-03-16 19:25:00  ARTs y ARTd         0.000000
# 386  2025-03-16 19:23:00 2025-03-16 19:25:00    FC y ARTs         0.000000
# 390  2025-03-16 19:25:00 2025-03-16 19:27:00  ARTs y ARTd         0.000000
# 391  2025-03-16 19:25:00 2025-03-16 19:27:00    FC y ARTd         0.000000
# 392  2025-03-16 19:25:00 2025-03-16 19:27:00    FC y ARTs         0.000000
# 393  2025-03-16 19:25:00 2025-03-16 19:27:00    FC y SpO2         0.000000
# 394  2025-03-16 19:25:00 2025-03-16 19:27:00  SpO2 y ARTd         0.000000
# 395  2025-03-16 19:25:00 2025-03-16 19:27:00  SpO2 y ARTs         0.000000
# 401  2025-03-16 19:27:00 2025-03-16 19:29:00  SpO2 y ARTs         0.000000
# 400  2025-03-16 19:27:00 2025-03-16 19:29:00  SpO2 y ARTd         0.000000
# 399  2025-03-16 19:27:00 2025-03-16 19:29:00    FC y SpO2         0.000000
# 397  2025-03-16 19:27:00 2025-03-16 19:29:00    FC y ARTd         0.000000
# 396  2025-03-16 19:27:00 2025-03-16 19:29:00  ARTs y ARTd         0.000000
# 398  2025-03-16 19:27:00 2025-03-16 19:29:00    FC y ARTs         0.000000
# 402  2025-03-16 19:29:00 2025-03-16 19:31:00  ARTs y ARTd         0.000000
# 403  2025-03-16 19:29:00 2025-03-16 19:31:00    FC y ARTd         0.000000
# 404  2025-03-16 19:29:00 2025-03-16 19:31:00    FC y ARTs         0.000000
# 405  2025-03-16 19:29:00 2025-03-16 19:31:00    FC y SpO2         0.000000
# 406  2025-03-16 19:29:00 2025-03-16 19:31:00  SpO2 y ARTd         0.000000
# 407  2025-03-16 19:29:00 2025-03-16 19:31:00  SpO2 y ARTs         0.000000
# 410  2025-03-16 19:31:00 2025-03-16 19:33:00    FC y ARTs         0.000000
# 413  2025-03-16 19:31:00 2025-03-16 19:33:00  SpO2 y ARTs         0.000000
# 412  2025-03-16 19:31:00 2025-03-16 19:33:00  SpO2 y ARTd         0.000000
# 409  2025-03-16 19:31:00 2025-03-16 19:33:00    FC y ARTd         0.000000
# 408  2025-03-16 19:31:00 2025-03-16 19:33:00  ARTs y ARTd         0.000000
# 411  2025-03-16 19:31:00 2025-03-16 19:33:00    FC y SpO2         0.000000
# 418  2025-03-16 19:33:00 2025-03-16 19:35:00  SpO2 y ARTd         0.000000
# 414  2025-03-16 19:33:00 2025-03-16 19:35:00  ARTs y ARTd         0.000000
# 415  2025-03-16 19:33:00 2025-03-16 19:35:00    FC y ARTd         0.000000
# 416  2025-03-16 19:33:00 2025-03-16 19:35:00    FC y ARTs         0.000000
# 417  2025-03-16 19:33:00 2025-03-16 19:35:00    FC y SpO2         0.000000
# 419  2025-03-16 19:33:00 2025-03-16 19:35:00  SpO2 y ARTs         0.000000
# 425  2025-03-16 19:35:00 2025-03-16 19:37:00  SpO2 y ARTs         0.000000
# 423  2025-03-16 19:35:00 2025-03-16 19:37:00    FC y SpO2         0.000000
# 424  2025-03-16 19:35:00 2025-03-16 19:37:00  SpO2 y ARTd         0.000000
# 421  2025-03-16 19:35:00 2025-03-16 19:37:00    FC y ARTd         0.000000
# 420  2025-03-16 19:35:00 2025-03-16 19:37:00  ARTs y ARTd         0.000000
# 422  2025-03-16 19:35:00 2025-03-16 19:37:00    FC y ARTs         0.000000
# 426  2025-03-16 19:37:00 2025-03-16 19:39:00  ARTs y ARTd         0.000000
# 427  2025-03-16 19:37:00 2025-03-16 19:39:00    FC y ARTd         0.000000
# 428  2025-03-16 19:37:00 2025-03-16 19:39:00    FC y ARTs         0.000000
# 429  2025-03-16 19:37:00 2025-03-16 19:39:00    FC y SpO2         0.000000
# 430  2025-03-16 19:37:00 2025-03-16 19:39:00  SpO2 y ARTd         0.000000
# 431  2025-03-16 19:37:00 2025-03-16 19:39:00  SpO2 y ARTs         0.000000
# 437  2025-03-16 19:39:00 2025-03-16 19:41:00  SpO2 y ARTs         0.000000
# 435  2025-03-16 19:39:00 2025-03-16 19:41:00    FC y SpO2         0.000000
# 436  2025-03-16 19:39:00 2025-03-16 19:41:00  SpO2 y ARTd         0.000000
# 433  2025-03-16 19:39:00 2025-03-16 19:41:00    FC y ARTd         0.000000
# 432  2025-03-16 19:39:00 2025-03-16 19:41:00  ARTs y ARTd         0.000000
# 434  2025-03-16 19:39:00 2025-03-16 19:41:00    FC y ARTs         0.000000
# 438  2025-03-16 19:41:00 2025-03-16 19:43:00  ARTs y ARTd         0.000000
# 439  2025-03-16 19:41:00 2025-03-16 19:43:00    FC y ARTd         0.000000
# 440  2025-03-16 19:41:00 2025-03-16 19:43:00    FC y ARTs         0.000000
# 441  2025-03-16 19:41:00 2025-03-16 19:43:00    FC y SpO2         0.000000
# 442  2025-03-16 19:41:00 2025-03-16 19:43:00  SpO2 y ARTd         0.000000
# 443  2025-03-16 19:41:00 2025-03-16 19:43:00  SpO2 y ARTs         0.000000
# 449  2025-03-16 19:43:00 2025-03-16 19:45:00  SpO2 y ARTs         0.000000
# 448  2025-03-16 19:43:00 2025-03-16 19:45:00  SpO2 y ARTd         0.000000
# 447  2025-03-16 19:43:00 2025-03-16 19:45:00    FC y SpO2         0.000000
# 446  2025-03-16 19:43:00 2025-03-16 19:45:00    FC y ARTs         0.000000
# 444  2025-03-16 19:43:00 2025-03-16 19:45:00  ARTs y ARTd         0.000000
# 445  2025-03-16 19:43:00 2025-03-16 19:45:00    FC y ARTd         0.000000
# 450  2025-03-16 19:45:00 2025-03-16 19:47:00  ARTs y ARTd         0.000000
# 451  2025-03-16 19:45:00 2025-03-16 19:47:00    FC y ARTd         0.000000
# 452  2025-03-16 19:45:00 2025-03-16 19:47:00    FC y ARTs         0.000000
# 453  2025-03-16 19:45:00 2025-03-16 19:47:00    FC y SpO2         0.000000
# 454  2025-03-16 19:45:00 2025-03-16 19:47:00  SpO2 y ARTd         0.000000
# 455  2025-03-16 19:45:00 2025-03-16 19:47:00  SpO2 y ARTs         0.000000
# 461  2025-03-16 19:47:00 2025-03-16 19:49:00  SpO2 y ARTs         0.000000
# 460  2025-03-16 19:47:00 2025-03-16 19:49:00  SpO2 y ARTd         0.000000
# 459  2025-03-16 19:47:00 2025-03-16 19:49:00    FC y SpO2         0.000000
# 457  2025-03-16 19:47:00 2025-03-16 19:49:00    FC y ARTd         0.000000
# 456  2025-03-16 19:47:00 2025-03-16 19:49:00  ARTs y ARTd         0.000000
# 458  2025-03-16 19:47:00 2025-03-16 19:49:00    FC y ARTs         0.000000
# 462  2025-03-16 19:49:00 2025-03-16 19:51:00  ARTs y ARTd         0.000000
# 463  2025-03-16 19:49:00 2025-03-16 19:51:00    FC y ARTd         0.000000
# 464  2025-03-16 19:49:00 2025-03-16 19:51:00    FC y ARTs         0.000000
# 465  2025-03-16 19:49:00 2025-03-16 19:51:00    FC y SpO2         0.000000
# 466  2025-03-16 19:49:00 2025-03-16 19:51:00  SpO2 y ARTd         0.000000
# 467  2025-03-16 19:49:00 2025-03-16 19:51:00  SpO2 y ARTs         0.000000
# 472  2025-03-16 19:51:00 2025-03-16 19:53:00  SpO2 y ARTd         0.000000
# 473  2025-03-16 19:51:00 2025-03-16 19:53:00  SpO2 y ARTs         0.000000
# 471  2025-03-16 19:51:00 2025-03-16 19:53:00    FC y SpO2         0.000000
# 469  2025-03-16 19:51:00 2025-03-16 19:53:00    FC y ARTd         0.000000
# 468  2025-03-16 19:51:00 2025-03-16 19:53:00  ARTs y ARTd         1.000000
# 470  2025-03-16 19:51:00 2025-03-16 19:53:00    FC y ARTs         0.000000
# 474  2025-03-16 19:53:00 2025-03-16 19:55:00  ARTs y ARTd         0.000000
# 475  2025-03-16 19:53:00 2025-03-16 19:55:00    FC y ARTd         0.000000
# 476  2025-03-16 19:53:00 2025-03-16 19:55:00    FC y ARTs         0.000000
# 477  2025-03-16 19:53:00 2025-03-16 19:55:00    FC y SpO2         0.000000
# 478  2025-03-16 19:53:00 2025-03-16 19:55:00  SpO2 y ARTd         0.000000
# 479  2025-03-16 19:53:00 2025-03-16 19:55:00  SpO2 y ARTs         0.000000
# 485  2025-03-16 19:55:00 2025-03-16 19:57:00  SpO2 y ARTs         0.000000
# 484  2025-03-16 19:55:00 2025-03-16 19:57:00  SpO2 y ARTd         0.000000
# 483  2025-03-16 19:55:00 2025-03-16 19:57:00    FC y SpO2         0.000000
# 482  2025-03-16 19:55:00 2025-03-16 19:57:00    FC y ARTs         0.000000
# 481  2025-03-16 19:55:00 2025-03-16 19:57:00    FC y ARTd         0.000000
# 480  2025-03-16 19:55:00 2025-03-16 19:57:00  ARTs y ARTd         0.000000
# 486  2025-03-16 19:57:00 2025-03-16 19:59:00  ARTs y ARTd         0.000000
# 487  2025-03-16 19:57:00 2025-03-16 19:59:00    FC y ARTd         0.000000
# 488  2025-03-16 19:57:00 2025-03-16 19:59:00    FC y ARTs         0.000000
# 489  2025-03-16 19:57:00 2025-03-16 19:59:00    FC y SpO2         0.000000
# 490  2025-03-16 19:57:00 2025-03-16 19:59:00  SpO2 y ARTd         0.000000
# 491  2025-03-16 19:57:00 2025-03-16 19:59:00  SpO2 y ARTs         0.000000
# 497  2025-03-16 19:59:00 2025-03-16 20:01:00  SpO2 y ARTs         0.000000
# 496  2025-03-16 19:59:00 2025-03-16 20:01:00  SpO2 y ARTd         0.000000
# 495  2025-03-16 19:59:00 2025-03-16 20:01:00    FC y SpO2         0.000000
# 493  2025-03-16 19:59:00 2025-03-16 20:01:00    FC y ARTd         0.000000
# 492  2025-03-16 19:59:00 2025-03-16 20:01:00  ARTs y ARTd         0.000000
# 494  2025-03-16 19:59:00 2025-03-16 20:01:00    FC y ARTs         0.000000
# 498  2025-03-16 20:01:00 2025-03-16 20:03:00  ARTs y ARTd         0.000000
# 499  2025-03-16 20:01:00 2025-03-16 20:03:00    FC y ARTd         0.000000
# 500  2025-03-16 20:01:00 2025-03-16 20:03:00    FC y ARTs         0.000000
# 501  2025-03-16 20:01:00 2025-03-16 20:03:00    FC y SpO2         0.000000
# 502  2025-03-16 20:01:00 2025-03-16 20:03:00  SpO2 y ARTd         0.000000
# 503  2025-03-16 20:01:00 2025-03-16 20:03:00  SpO2 y ARTs         0.000000
# 506  2025-03-16 20:03:00 2025-03-16 20:05:00    FC y ARTs         0.000000
# 509  2025-03-16 20:03:00 2025-03-16 20:05:00  SpO2 y ARTs         0.000000
# 508  2025-03-16 20:03:00 2025-03-16 20:05:00  SpO2 y ARTd         0.000000
# 505  2025-03-16 20:03:00 2025-03-16 20:05:00    FC y ARTd         0.000000
# 504  2025-03-16 20:03:00 2025-03-16 20:05:00  ARTs y ARTd         0.000000
# 507  2025-03-16 20:03:00 2025-03-16 20:05:00    FC y SpO2         0.000000
# 514  2025-03-16 20:05:00 2025-03-16 20:07:00  SpO2 y ARTd         0.000000
# 510  2025-03-16 20:05:00 2025-03-16 20:07:00  ARTs y ARTd         0.000000
# 511  2025-03-16 20:05:00 2025-03-16 20:07:00    FC y ARTd         0.000000
# 512  2025-03-16 20:05:00 2025-03-16 20:07:00    FC y ARTs         0.000000
# 513  2025-03-16 20:05:00 2025-03-16 20:07:00    FC y SpO2         0.000000
# 515  2025-03-16 20:05:00 2025-03-16 20:07:00  SpO2 y ARTs         0.000000
# 520  2025-03-16 20:07:00 2025-03-16 20:09:00  SpO2 y ARTd         0.000000
# 521  2025-03-16 20:07:00 2025-03-16 20:09:00  SpO2 y ARTs         0.000000
# 519  2025-03-16 20:07:00 2025-03-16 20:09:00    FC y SpO2         0.000000
# 516  2025-03-16 20:07:00 2025-03-16 20:09:00  ARTs y ARTd         0.000000
# 517  2025-03-16 20:07:00 2025-03-16 20:09:00    FC y ARTd         0.000000
# 518  2025-03-16 20:07:00 2025-03-16 20:09:00    FC y ARTs         0.000000
# 522  2025-03-16 20:09:00 2025-03-16 20:11:00  ARTs y ARTd         0.000000
# 523  2025-03-16 20:09:00 2025-03-16 20:11:00    FC y ARTd         0.000000
# 524  2025-03-16 20:09:00 2025-03-16 20:11:00    FC y ARTs         0.000000
# 525  2025-03-16 20:09:00 2025-03-16 20:11:00    FC y SpO2         0.000000
# 526  2025-03-16 20:09:00 2025-03-16 20:11:00  SpO2 y ARTd         0.000000
# 527  2025-03-16 20:09:00 2025-03-16 20:11:00  SpO2 y ARTs         0.000000
# 533  2025-03-16 20:11:00 2025-03-16 20:13:00  SpO2 y ARTs         0.000000
# 532  2025-03-16 20:11:00 2025-03-16 20:13:00  SpO2 y ARTd         0.000000
# 531  2025-03-16 20:11:00 2025-03-16 20:13:00    FC y SpO2         0.000000
# 529  2025-03-16 20:11:00 2025-03-16 20:13:00    FC y ARTd         0.000000
# 528  2025-03-16 20:11:00 2025-03-16 20:13:00  ARTs y ARTd         0.000000
# 530  2025-03-16 20:11:00 2025-03-16 20:13:00    FC y ARTs         0.000000
# 534  2025-03-16 20:13:00 2025-03-16 20:15:00  ARTs y ARTd         0.000000
# 535  2025-03-16 20:13:00 2025-03-16 20:15:00    FC y ARTd         0.000000
# 536  2025-03-16 20:13:00 2025-03-16 20:15:00    FC y ARTs         0.000000
# 537  2025-03-16 20:13:00 2025-03-16 20:15:00    FC y SpO2         0.000000
# 538  2025-03-16 20:13:00 2025-03-16 20:15:00  SpO2 y ARTd         0.000000
# 539  2025-03-16 20:13:00 2025-03-16 20:15:00  SpO2 y ARTs         0.000000
# 544  2025-03-16 20:15:00 2025-03-16 20:17:00  SpO2 y ARTd         0.000000
# 545  2025-03-16 20:15:00 2025-03-16 20:17:00  SpO2 y ARTs         0.000000
# 543  2025-03-16 20:15:00 2025-03-16 20:17:00    FC y SpO2         0.000000
# 540  2025-03-16 20:15:00 2025-03-16 20:17:00  ARTs y ARTd         0.000000
# 541  2025-03-16 20:15:00 2025-03-16 20:17:00    FC y ARTd         0.000000
# 542  2025-03-16 20:15:00 2025-03-16 20:17:00    FC y ARTs         0.000000
# 546  2025-03-16 20:17:00 2025-03-16 20:19:00  ARTs y ARTd         0.000000
# 547  2025-03-16 20:17:00 2025-03-16 20:19:00    FC y ARTd         0.000000
# 548  2025-03-16 20:17:00 2025-03-16 20:19:00    FC y ARTs         0.000000
# 549  2025-03-16 20:17:00 2025-03-16 20:19:00    FC y SpO2         0.000000
# 550  2025-03-16 20:17:00 2025-03-16 20:19:00  SpO2 y ARTd         0.000000
# 551  2025-03-16 20:17:00 2025-03-16 20:19:00  SpO2 y ARTs         0.000000
# 557  2025-03-16 20:19:00 2025-03-16 20:21:00  SpO2 y ARTs         0.000000
# 556  2025-03-16 20:19:00 2025-03-16 20:21:00  SpO2 y ARTd         0.000000
# 555  2025-03-16 20:19:00 2025-03-16 20:21:00    FC y SpO2         0.000000
# 552  2025-03-16 20:19:00 2025-03-16 20:21:00  ARTs y ARTd         0.000000
# 553  2025-03-16 20:19:00 2025-03-16 20:21:00    FC y ARTd         0.000000
# 554  2025-03-16 20:19:00 2025-03-16 20:21:00    FC y ARTs         0.000000
# 561  2025-03-16 20:21:00 2025-03-16 20:23:00    FC y SpO2         0.000000
# 562  2025-03-16 20:21:00 2025-03-16 20:23:00  SpO2 y ARTd         0.000000
# 563  2025-03-16 20:21:00 2025-03-16 20:23:00  SpO2 y ARTs         0.000000
# 560  2025-03-16 20:21:00 2025-03-16 20:23:00    FC y ARTs         0.000000
# 558  2025-03-16 20:21:00 2025-03-16 20:23:00  ARTs y ARTd         0.000000
# 559  2025-03-16 20:21:00 2025-03-16 20:23:00    FC y ARTd         0.000000
# 564  2025-03-16 20:23:00 2025-03-16 20:25:00  ARTs y ARTd         0.000000
# 565  2025-03-16 20:23:00 2025-03-16 20:25:00    FC y ARTd         0.000000
# 566  2025-03-16 20:23:00 2025-03-16 20:25:00    FC y ARTs         0.000000
# 567  2025-03-16 20:23:00 2025-03-16 20:25:00    FC y SpO2         0.000000
# 568  2025-03-16 20:23:00 2025-03-16 20:25:00  SpO2 y ARTd         0.000000
# 569  2025-03-16 20:23:00 2025-03-16 20:25:00  SpO2 y ARTs         0.112494
# 570  2025-03-16 20:25:00 2025-03-16 20:27:00  ARTs y ARTd         0.000000
# 571  2025-03-16 20:25:00 2025-03-16 20:27:00    FC y ARTd         0.000000
# 572  2025-03-16 20:25:00 2025-03-16 20:27:00    FC y ARTs         0.000000
# 573  2025-03-16 20:25:00 2025-03-16 20:27:00    FC y SpO2         0.000000
# 574  2025-03-16 20:25:00 2025-03-16 20:27:00  SpO2 y ARTd         0.000000
# 575  2025-03-16 20:25:00 2025-03-16 20:27:00  SpO2 y ARTs         1.000000
# 580  2025-03-16 20:27:00 2025-03-16 20:29:00  SpO2 y ARTd         0.000000
# 579  2025-03-16 20:27:00 2025-03-16 20:29:00    FC y SpO2         0.000000
# 581  2025-03-16 20:27:00 2025-03-16 20:29:00  SpO2 y ARTs         0.000000
# 577  2025-03-16 20:27:00 2025-03-16 20:29:00    FC y ARTd         0.000000
# 576  2025-03-16 20:27:00 2025-03-16 20:29:00  ARTs y ARTd         0.000000
# 578  2025-03-16 20:27:00 2025-03-16 20:29:00    FC y ARTs         0.000000
# 582  2025-03-16 20:29:00 2025-03-16 20:31:00  ARTs y ARTd         0.000000
# 583  2025-03-16 20:29:00 2025-03-16 20:31:00    FC y ARTd         0.000000
# 584  2025-03-16 20:29:00 2025-03-16 20:31:00    FC y ARTs         0.000000
# 585  2025-03-16 20:29:00 2025-03-16 20:31:00    FC y SpO2         0.000000
# 586  2025-03-16 20:29:00 2025-03-16 20:31:00  SpO2 y ARTd         0.000000
# 587  2025-03-16 20:29:00 2025-03-16 20:31:00  SpO2 y ARTs         0.112494
# 593  2025-03-16 20:31:00 2025-03-16 20:33:00  SpO2 y ARTs         0.000000
# 592  2025-03-16 20:31:00 2025-03-16 20:33:00  SpO2 y ARTd         0.000000
# 591  2025-03-16 20:31:00 2025-03-16 20:33:00    FC y SpO2         0.000000
# 590  2025-03-16 20:31:00 2025-03-16 20:33:00    FC y ARTs         0.000000
# 588  2025-03-16 20:31:00 2025-03-16 20:33:00  ARTs y ARTd         0.000000
# 589  2025-03-16 20:31:00 2025-03-16 20:33:00    FC y ARTd         0.000000
# 594  2025-03-16 20:33:00 2025-03-16 20:35:00  ARTs y ARTd         0.000000
# 595  2025-03-16 20:33:00 2025-03-16 20:35:00    FC y ARTd         0.000000
# 596  2025-03-16 20:33:00 2025-03-16 20:35:00    FC y ARTs         0.000000
# 597  2025-03-16 20:33:00 2025-03-16 20:35:00    FC y SpO2         0.000000
# 598  2025-03-16 20:33:00 2025-03-16 20:35:00  SpO2 y ARTd         0.000000
# 599  2025-03-16 20:33:00 2025-03-16 20:35:00  SpO2 y ARTs         0.000000
# 604  2025-03-16 20:35:00 2025-03-16 20:37:00  SpO2 y ARTd         0.000000
# 603  2025-03-16 20:35:00 2025-03-16 20:37:00    FC y SpO2         0.000000
# 605  2025-03-16 20:35:00 2025-03-16 20:37:00  SpO2 y ARTs         0.000000
# 601  2025-03-16 20:35:00 2025-03-16 20:37:00    FC y ARTd         0.000000
# 602  2025-03-16 20:35:00 2025-03-16 20:37:00    FC y ARTs         0.000000
# 600  2025-03-16 20:35:00 2025-03-16 20:37:00  ARTs y ARTd         0.000000
# 606  2025-03-16 20:37:00 2025-03-16 20:39:00  ARTs y ARTd         0.130103
# 607  2025-03-16 20:37:00 2025-03-16 20:39:00    FC y ARTd         0.000000
# 608  2025-03-16 20:37:00 2025-03-16 20:39:00    FC y ARTs         0.000000
# 609  2025-03-16 20:37:00 2025-03-16 20:39:00    FC y SpO2         0.000000
# 610  2025-03-16 20:37:00 2025-03-16 20:39:00  SpO2 y ARTd         0.000000
# 611  2025-03-16 20:37:00 2025-03-16 20:39:00  SpO2 y ARTs         0.000000
# 615  2025-03-16 20:39:00 2025-03-16 20:41:00    FC y SpO2         0.000000
# 617  2025-03-16 20:39:00 2025-03-16 20:41:00  SpO2 y ARTs         0.000000
# 616  2025-03-16 20:39:00 2025-03-16 20:41:00  SpO2 y ARTd         0.000000
# 614  2025-03-16 20:39:00 2025-03-16 20:41:00    FC y ARTs         0.000000
# 613  2025-03-16 20:39:00 2025-03-16 20:41:00    FC y ARTd         0.000000
# 612  2025-03-16 20:39:00 2025-03-16 20:41:00  ARTs y ARTd         0.000000
# 618  2025-03-16 20:41:00 2025-03-16 20:43:00  ARTs y ARTd         0.000000
# 619  2025-03-16 20:41:00 2025-03-16 20:43:00    FC y ARTd         0.000000
# 620  2025-03-16 20:41:00 2025-03-16 20:43:00    FC y ARTs         0.000000
# 621  2025-03-16 20:41:00 2025-03-16 20:43:00    FC y SpO2         0.000000
# 622  2025-03-16 20:41:00 2025-03-16 20:43:00  SpO2 y ARTd         0.000000
# 623  2025-03-16 20:41:00 2025-03-16 20:43:00  SpO2 y ARTs         0.000000
# 628  2025-03-16 20:43:00 2025-03-16 20:45:00  SpO2 y ARTd         0.000000
# 627  2025-03-16 20:43:00 2025-03-16 20:45:00    FC y SpO2         0.000000
# 629  2025-03-16 20:43:00 2025-03-16 20:45:00  SpO2 y ARTs         0.000000
# 626  2025-03-16 20:43:00 2025-03-16 20:45:00    FC y ARTs         0.000000
# 624  2025-03-16 20:43:00 2025-03-16 20:45:00  ARTs y ARTd         0.000000
# 625  2025-03-16 20:43:00 2025-03-16 20:45:00    FC y ARTd         0.000000
# 630  2025-03-16 20:45:00 2025-03-16 20:47:00  ARTs y ARTd         0.000000
# 631  2025-03-16 20:45:00 2025-03-16 20:47:00    FC y ARTd         0.000000
# 632  2025-03-16 20:45:00 2025-03-16 20:47:00    FC y ARTs         0.000000
# 633  2025-03-16 20:45:00 2025-03-16 20:47:00    FC y SpO2         0.000000
# 634  2025-03-16 20:45:00 2025-03-16 20:47:00  SpO2 y ARTd         0.000000
# 635  2025-03-16 20:45:00 2025-03-16 20:47:00  SpO2 y ARTs         0.000000
# 641  2025-03-16 20:47:00 2025-03-16 20:49:00  SpO2 y ARTs         0.000000
# 640  2025-03-16 20:47:00 2025-03-16 20:49:00  SpO2 y ARTd         0.000000
# ...
# 401  FC y SpO2SpO2 y ARTsSpO2 y ARTdFC y ARTsARTs y...         0.166667
# 402  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.333333
# 403  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTsARTs y...         0.166667
# 404  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 405  SpO2 y ARTdFC y SpO2SpO2 y ARTsFC y ARTdFC y A...         0.166667
# 406  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 407  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 408  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 409  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 410  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.333333
# 411  FC y ARTsSpO2 y ARTsSpO2 y ARTdFC y ARTdARTs y...         0.166667
# 412  SpO2 y ARTdARTs y ARTdFC y ARTdFC y ARTsFC y S...         0.166667
# 413  SpO2 y ARTdSpO2 y ARTsFC y SpO2FC y ARTsFC y A...         0.166667
# 414  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 415  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTsFC y A...         0.166667
# 416  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 417  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 418  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 419  FC y ARTsSpO2 y ARTsSpO2 y ARTdFC y ARTdARTs y...         0.166667
# 420  SpO2 y ARTdARTs y ARTdFC y ARTdFC y ARTsFC y S...         0.166667
# 421  FC y SpO2SpO2 y ARTdSpO2 y ARTsFC y ARTsARTs y...         0.166667
# 422  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 423  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 424  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 425  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTsFC y A...         0.166667
# 426  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 427  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTsFC y A...         0.166667
# 428  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 429  SpO2 y ARTdSpO2 y ARTsFC y SpO2FC y ARTdFC y A...         0.166667
# 430  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 431  FC y SpO2SpO2 y ARTsSpO2 y ARTdFC y ARTsFC y A...         0.166667
# 432  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 433  SpO2 y ARTdFC y SpO2SpO2 y ARTsFC y ARTsARTs y...         0.166667
# 434  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 435  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 436  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.360034
# 437  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 438  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 439  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 440  SpO2 y ARTdFC y SpO2SpO2 y ARTsFC y ARTdARTs y...         0.166667
# 441  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 442  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTsARTs y...         0.166667
# 443  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 444  SpO2 y ARTdFC y SpO2SpO2 y ARTsFC y ARTdFC y A...         0.166667
# 445  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 446  FC y SpO2SpO2 y ARTsSpO2 y ARTdFC y ARTsFC y A...         0.166667
# 447  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 448  SpO2 y ARTdFC y SpO2SpO2 y ARTsFC y ARTsARTs y...         0.166667
# 449  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 450  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTsARTs y...         0.166667
# 451  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 452  SpO2 y ARTdFC y SpO2SpO2 y ARTsFC y ARTdFC y A...         0.166667
# 453  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.352082
# 454  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 455  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 456  SpO2 y ARTdSpO2 y ARTsFC y SpO2FC y ARTsFC y A...         0.166667
# 457  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 458  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 459  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 460  FC y SpO2SpO2 y ARTdSpO2 y ARTsFC y ARTsARTs y...         0.166667
# 461  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 462  SpO2 y ARTsFC y ARTsSpO2 y ARTdARTs y ARTdFC y...         0.166667
# 463  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.565051
# 464  FC y SpO2SpO2 y ARTsSpO2 y ARTdFC y ARTsARTs y...         0.166667
# 465  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.360034
# 466  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTsARTs y...         0.166667
# 467  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 468  SpO2 y ARTsFC y SpO2SpO2 y ARTdFC y ARTdFC y A...         0.215052
# 469  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 470  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.193368
# 471  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 472  SpO2 y ARTdSpO2 y ARTsFC y SpO2FC y ARTsFC y A...         0.166667
# 473  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 474  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 475  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 476  FC y SpO2SpO2 y ARTdSpO2 y ARTsFC y ARTsARTs y...         0.166667
# 477  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 478  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 479  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 480  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 481  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 482  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTsARTs y...         0.166667
# 483  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.500000
# 484  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 485  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 486  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 487  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 488  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 489  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 490  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTsARTs y...         0.188350
# 491  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 492  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 493  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.185416
# 494  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 495  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 496  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 497  ARTs y ARTdFC y ARTdFC y ARTsFC y SpO2SpO2 y A...         0.166667
# 498  SpO2 y ARTsSpO2 y ARTdFC y SpO2FC y ARTdARTs y...         0.166667
# 499  SpO2 y ARTdARTs y ARTdFC y ARTdFC y ARTsFC y S...         0.166667
#
#      Num Pairs
# 0            6
# 1            6
# 2            6
# 3            6
# 4            6
# 5            6
# 6            6
# 7            6
# 8            6
# 9            6
# 10           6
# 11           6
# 12           6
# 13           6
# 14           6
# 15           6
# 16           6
# 17           6
# 18           6
# 19           6
# 20           6
# 21           6
# 22           6
# 23           6
# 24           6
# 25           6
# 26           6
# 27           6
# 28           6
# 29           6
# 30           6
# 31           6
# 32           6
# 33           6
# 34           6
# 35           6
# 36           6
# 37           6
# 38           6
# 39           6
# 40           6
# 41           6
# 42           6
# 43           6
# 44           6
# 45           6
# 46           6
# 47           6
# 48           6
# 49           6
# 50           6
# 51           6
# 52           6
# 53           6
# 54           6
# 55           6
# 56           6
# 57           6
# 58           6
# 59           6
# 60           6
# 61           6
# 62           6
# 63           6
# 64           6
# 65           6
# 66           6
# 67           6
# 68           6
# 69           6
# 70           6
# 71           6
# 72           6
# 73           6
# 74           6
# 75           6
# 76           6
# 77           6
# 78           6
# 79           6
# 80           6
# 81           6
# 82           6
# 83           6
# 84           6
# 85           6
# 86           6
# 87           6
# 88           6
# 89           6
# 90           6
# 91           6
# 92           6
# 93           6
# 94           6
# 95           6
# 96           6
# 97           6
# 98           6
# 99           6
# 100          6
# 101          6
# 102          6
# 103          6
# 104          6
# 105          6
# 106          6
# 107          6
# 108          6
# 109          6
# 110          6
# 111          6
# 112          6
# 113          6
# 114          6
# 115          6
# 116          6
# 117          6
# 118          6
# 119          6
# 120          6
# 121          6
# 122          6
# 123          6
# 124          6
# 125          6
# 126          6
# 127          6
# 128          6
# 129          6
# 130          6
# 131          6
# 132          6
# 133          6
# 134          6
# 135          6
# 136          6
# 137          6
# 138          6
# 139          6
# 140          6
# 141          6
# 142          6
# 143          6
# 144          6
# 145          6
# 146          6
# 147          6
# 148          6
# 149          6
# 150          6
# 151          6
# 152          6
# 153          6
# 154          6
# 155          6
# 156          6
# 157          6
# 158          6
# 159          6
# 160          6
# 161          6
# 162          6
# 163          6
# 164          6
# 165          6
# 166          6
# 167          6
# 168          6
# 169          6
# 170          6
# 171          6
# 172          6
# 173          6
# 174          6
# 175          6
# 176          6
# 177          6
# 178          6
# 179          6
# 180          6
# 181          6
# 182          6
# 183          6
# 184          6
# 185          6
# 186          6
# 187          6
# 188          6
# 189          6
# 190          6
# 191          6
# 192          6
# 193          6
# 194          6
# 195          6
# 196          6
# 197          6
# 198          6
# 199          6
# 200          6
# 201          6
# 202          6
# 203          6
# 204          6
# 205          6
# 206          6
# 207          6
# 208          6
# 209          6
# 210          6
# 211          6
# 212          6
# 213          6
# 214          6
# 215          6
# 216          6
# 217          6
# 218          6
# 219          6
# 220          6
# 221          6
# 222          6
# 223          6
# 224          6
# 225          6
# 226          6
# 227          6
# 228          6
# 229          6
# 230          6
# 231          6
# 232          6
# 233          6
# 234          6
# 235          6
# 236          6
# 237          6
# 238          6
# 239          6
# 240          6
# 241          6
# 242          6
# 243          6
# 244          6
# 245          6
# 246          6
# 247          6
# 248          6
# 249          6
# 250          6
# 251          6
# 252          6
# 253          6
# 254          6
# 255          6
# 256          6
# 257          6
# 258          6
# 259          6
# 260          6
# 261          6
# 262          6
# 263          6
# 264          6
# 265          6
# 266          6
# 267          6
# 268          6
# 269          6
# 270          6
# 271          6
# 272          6
# 273          6
# 274          6
# 275          6
# 276          6
# 277          6
# 278          6
# 279          6
# 280          6
# 281          6
# 282          6
# 283          6
# 284          6
# 285          6
# 286          6
# 287          6
# 288          6
# 289          6
# 290          6
# 291          6
# 292          6
# 293          6
# 294          6
# 295          6
# 296          6
# 297          6
# 298          6
# 299          6
# 300          6
# 301          6
# 302          6
# 303          6
# 304          6
# 305          6
# 306          6
# 307          6
# 308          6
# 309          6
# 310          6
# 311          6
# 312          6
# 313          6
# 314          6
# 315          6
# 316          6
# 317          6
# 318          6
# 319          6
# 320          6
# 321          6
# 322          6
# 323          6
# 324          6
# 325          6
# 326          6
# 327          6
# 328          6
# 329          6
# 330          6
# 331          6
# 332          6
# 333          6
# 334          6
# 335          6
# 336          6
# 337          6
# 338          6
# 339          6
# 340          6
# 341          6
# 342          6
# 343          6
# 344          6
# 345          6
# 346          6
# 347          6
# 348          6
# 349          6
# 350          6
# 351          6
# 352          6
# 353          6
# 354          6
# 355          6
# 356          6
# 357          6
# 358          6
# 359          6
# 360          6
# 361          6
# 362          6
# 363          6
# 364          6
# 365          6
# 366          6
# 367          6
# 368          6
# 369          6
# 370          6
# 371          6
# 372          6
# 373          6
# 374          6
# 375          6
# 376          6
# 377          6
# 378          6
# 379          6
# 380          6
# 381          6
# 382          6
# 383          6
# 384          6
# 385          6
# 386          6
# 387          6
# 388          6
# 389          6
# 390          6
# 391          6
# 392          6
# 393          6
# 394          6
# 395          6
# 396          6
# 397          6
# 398          6
# 399          6
# 400          6
# 401          6
# 402          6
# 403          6
# 404          6
# 405          6
# 406          6
# 407          6
# 408          6
# 409          6
# 410          6
# 411          6
# 412          6
# 413          6
# 414          6
# 415          6
# 416          6
# 417          6
# 418          6
# 419          6
# 420          6
# 421          6
# 422          6
# 423          6
# 424          6
# 425          6
# 426          6
# 427          6
# 428          6
# 429          6
# 430          6
# 431          6
# 432          6
# 433          6
# 434          6
# 435          6
# 436          6
# 437          6
# 438          6
# 439          6
# 440          6
# 441          6
# 442          6
# 443          6
# 444          6
# 445          6
# 446          6
# 447          6
# 448          6
# 449          6
# 450          6
# 451          6
# 452          6
# 453          6
# 454          6
# 455          6
# 456          6
# 457          6
# 458          6
# 459          6
# 460          6
# 461          6
# 462          6
# 463          6
# 464          6
# 465          6
# 466          6
# 467          6
# 468          6
# 469          6
# 470          6
# 471          6
# 472          6
# 473          6
# 474          6
# 475          6
# 476          6
# 477          6
# 478          6
# 479          6
# 480          6
# 481          6
# 482          6
# 483          6
# 484          6
# 485          6
# 486          6
# 487          6
# 488          6
# 489          6
# 490          6
# 491          6
# 492          6
# 493          6
# 494          6
# 495          6
# 496          6
# 497          6
# 498          6
# 499          6

# %%
# graph the indicator over the patient's vital signs with a background color according to the indicator value.

def plot_indicator_with_vitals(patient_data, patient_id, patient_indicator):
    # Count anomalies for each row of patient data
    patient_data['Anomalies'] = patient_data.apply(count_anomalies, axis=1)
    
    # Define a dynamic color mapping based on the indicator value
    max_indicator_value = patient_indicator['Indicator Value'].max()
    colors = ['lightgreen', '#ffffB3', 'yellow', 'orange', 'red']
    cmap = mcolors.LinearSegmentedColormap.from_list("custom_gradient", colors, N=5)
    norm = mcolors.Normalize(vmin=0, vmax=max_indicator_value)
    
    # Create a color mapping for the indicator values
    color_values = patient_indicator['Indicator Value'].apply(lambda x: cmap(norm(x)))
    
    # Create a color mapping for the number of anomalies
    patient_data['color'] = patient_data['Anomalies'].apply(lambda x: cmap(norm(x)))
    # Create the base plot
    plt.figure(figsize=(18, 6))
    # Plot all vital signs dynamically
    for col in studied_vital_signs:
        plt.plot(patient_data.index, patient_data[col], label=col, linewidth=1, color=vital_sign_colors[col])
    plt.title(f'Signos Vitales Paciente {patient_id} analizados con Indicador', y=1.5)
    plt.xlabel('Tiempo')
    plt.ylabel('Valores')
    plt.xticks(rotation=45)
    plt.grid(True)
    # Add a color bar for the number of anomalies
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    plt.colorbar(sm, ax=plt.gca(), orientation='horizontal', pad=0.2, ticks=range(5), label='Valor del Indicador')
    # Apply background coloring based on the indicator value
    for i in range(len(patient_indicator.index) - 1):
        plt.axvspan(patient_indicator['Start Time'].iloc[i], patient_indicator['End Time'].iloc[i + 1], 
                    color=color_values.iloc[i], alpha=0.25)
        
    # finish the plot
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.8))  # Position legend outside the plot area
    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust layout to leave space for the legend and raised title
    plt.show()
    
    
# use the function to plot the indicator with the patient's vital signs
plot_indicator_with_vitals(paciente0, str(id_paciente), patient_indicator)

# %% [markdown]
# ### 5.3. Calcular metricas como categorias

# %%
   
# calculate how the indicator compares to the number of vital signs outside the normal range.
# in order to obtain the accuracy and recall of the indicator.

# the number of signs outside the normal range is already calculated in the paciente0 DataFrame as 'Anomalies'.
# but we need to normalize this value over the number of vital signs.

def normalize_anomalies(patient_data):
    # Normalize the number of anomalies by the number of vital signs
    num_vital_signs = len(normal_ranges)

    
    patient_data['Normalized Anomalies'] = patient_data['Anomalies'] / num_vital_signs
    return patient_data

# Normalize the anomalies in the patient data
paciente0 = normalize_anomalies(paciente0)

def plot_normalized_anomalies(patient_data):
    plt.figure(figsize=(16, 6))
    # Use the index for the x-axis if 'Start Time' is the index
    plt.plot(patient_data.index, patient_data['Normalized Anomalies'], marker='o', linestyle='-', color='green')
    plt.title('Normalized Number of Anomalies Over Time')
    plt.xlabel('Time')
    plt.ylabel('Normalized Anomalies')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
# Plot the normalized anomalies over time.
plot_normalized_anomalies(paciente0)

# %%
# In order to calculate the accuracy and recall of the indicator, we'll create 3 discrete categories, indicating if the patient indicator is low, medium, or high.

# well calculate the same for the number of anomalies outside the normal range, so we can compare them. in a 3x3 matrix. and obtain the accuracy and recall of the indicator.


def categorize_indicator_and_anomalies(patient_data, patient_indicator):
    # Define thresholds for categorization
    low_threshold = 0.3
    high_threshold = 0.6
    
    
    # Categorize the normalized anomalies
    anomalies_category = []
    for index, row in patient_data.iterrows():
        if row['Normalized Anomalies'] < low_threshold:
            anomalies_category.append('Low')
        elif row['Normalized Anomalies'] < high_threshold:
            anomalies_category.append('Medium')
        else:
            anomalies_category.append('High')
    # Assign the categories to the DataFrame
    patient_data['True Category'] = anomalies_category
    
    # print the first 10 items of the anomalies category
    print("Anomalies Category (first 10 items):")
    print(patient_data['True Category'].head(10))
    
    # Categorize the patient indicator
    indicator_category = []
    for index, row in patient_indicator.iterrows():
        if row['Indicator Value'] < low_threshold:
            indicator_category.append('Low')
        elif row['Indicator Value'] < high_threshold:
            indicator_category.append('Medium')
        else:
            indicator_category.append('High')
    # Assign the categories to the patient indicator DataFrame
    patient_indicator['Indicator Category'] = indicator_category
    # print the first 10 items of the indicator category
    print("Indicator Category (first 10 items):")
    print(patient_indicator['Indicator Category'].head(10))
    
    # Get the results for normalized anomalies and put then in a new dataframe with numerical index
    min_len = min(len(patient_data), len(patient_indicator))

    # Truncate both DataFrames to the same length
    patient_data_trunc = patient_data.iloc[:min_len].reset_index(drop=True)
    patient_indicator_trunc = patient_indicator.iloc[:min_len].reset_index(drop=True)

    # Now create the results DataFrame using the truncated DataFrames
    results = pd.DataFrame({
        'Start Time': patient_indicator_trunc['Start Time'].values,
        'End Time': patient_indicator_trunc['End Time'].values,
        'True Category': patient_data_trunc['True Category'].values,
        'Indicator Category': patient_indicator_trunc['Indicator Category'].values,
        'Indicator Value': patient_indicator_trunc['Indicator Value'].values
    })
    # print the first 10 items of the results DataFrame
    print("Results DataFrame (first 10 items):")
    print(results.head(10))
    
    return results

# Categorize the indicator and anomalies
results = categorize_indicator_and_anomalies(paciente0, patient_indicator)
# Out:
# Anomalies Category (first 10 items):
# Time
# 2025-03-16 17:15:00    Low
# 2025-03-16 17:16:00    Low
# 2025-03-16 17:17:00    Low
# 2025-03-16 17:18:00    Low
# 2025-03-16 17:19:00    Low
# 2025-03-16 17:20:00    Low
# 2025-03-16 17:21:00    Low
# 2025-03-16 17:22:00    Low
# 2025-03-16 17:23:00    Low
# 2025-03-16 17:24:00    Low
# Name: True Category, dtype: object
# Indicator Category (first 10 items):
# 0    Low
# 1    Low
# 2    Low
# 3    Low
# 4    Low
# 5    Low
# 6    Low
# 7    Low
# 8    Low
# 9    Low
# Name: Indicator Category, dtype: object
# Results DataFrame (first 10 items):
#            Start Time            End Time True Category Indicator Category  \
# 0 2025-03-16 17:15:00 2025-03-16 17:17:00           Low                Low
# 1 2025-03-16 17:17:00 2025-03-16 17:19:00           Low                Low
# 2 2025-03-16 17:19:00 2025-03-16 17:21:00           Low                Low
# 3 2025-03-16 17:21:00 2025-03-16 17:23:00           Low                Low
# 4 2025-03-16 17:23:00 2025-03-16 17:25:00           Low                Low
# 5 2025-03-16 17:25:00 2025-03-16 17:27:00           Low                Low
# 6 2025-03-16 17:27:00 2025-03-16 17:29:00           Low                Low
# 7 2025-03-16 17:29:00 2025-03-16 17:31:00           Low                Low
# 8 2025-03-16 17:31:00 2025-03-16 17:33:00           Low                Low
# 9 2025-03-16 17:33:00 2025-03-16 17:35:00           Low                Low
#
#    Indicator Value
# 0         0.166667
# 1         0.166667
# 2         0.166667
# 3         0.185416
# 4         0.166667
# 5         0.166667
# 6         0.166667
# 7         0.166667
# 8         0.166667
# 9         0.166667

# %%
# CALCULATE THE CONFUSION MATRIX FOR THE INDICATOR AND ANOMALIES
def calculate_confusion_matrix(results):
    # Create a confusion matrix
    confusion_matrix = pd.crosstab(results['True Category'], results['Indicator Category'], 
                                   rownames=['True'], colnames=['Predicted'], margins=True)
    return confusion_matrix
# Calculate the confusion matrix for the indicator and anomalies
confusion_matrix = calculate_confusion_matrix(results)

# Print the confusion matrix
print("Confusion Matrix:")
print(confusion_matrix)

# Calculate the accuracy and recall for each category using sklearn's classification report
from sklearn.metrics import classification_report
def calculate_accuracy_recall(results):
    # Create a classification report
    report = classification_report(results['True Category'], results['Indicator Category'], output_dict=True)
    return report

# Calculate the accuracy and recall for the indicator
accuracy_recall = calculate_accuracy_recall(results)
# Print the accuracy and recall for the indicator
# print("Accuracy and Recall Report:")
# print(pd.DataFrame(accuracy_recall).transpose())

# extract the precision and recall from the weighted average
precision = accuracy_recall['weighted avg']['precision']
recall = accuracy_recall['weighted avg']['recall']
print()
# Print the precision and recall for the indicator
print(f"Precision: {precision:.2f}, Recall: {recall:.2f}")

# calculate the F1 and F2 scores for the indicator
from sklearn.metrics import f1_score, fbeta_score
def calculate_f_scores(results, beta=2):
    # Calculate F1 and F2 scores
    f1 = f1_score(results['True Category'], results['Indicator Category'], average='weighted')
    f2 = fbeta_score(results['True Category'], results['Indicator Category'], beta=beta, average='weighted')
    return f1, f2
# Calculate the F1 and F2 scores for the indicator
f1, f2 = calculate_f_scores(results, beta=2)
# Print the F1 and F2 scores for the indicator
print(f"F1 Score: {f1:.2f}, F2 Score: {f2:.2f}")
# Out:
# Confusion Matrix:
# Predicted  High  Low  Medium  All
# True
# High          0    6       1    7
# Low           4  431      31  466
# Medium        0   25       2   27
# All           4  462      34  500
#
# Precision: 0.87, Recall: 0.87
# F1 Score: 0.87, F2 Score: 0.87

# %%
# do the exact same calculation for the anomaly level in results1
# it stores the anomaly level for each pair of signals in each time window. in results1['Anomaly Level'].

def normalize_original_anomalies(results1):

    # normalize by the number of signals
    num_vital_signs = len(normal_ranges)
    
    # Normalize the anomaly level by the number of pairs
    results1['Normalized Anomaly Level'] = results1['Anomaly Level'] / num_vital_signs
    return results1

results1 = normalize_original_anomalies(results1)

# Categorize the anomaly level in results1
def categorize_original_anomalies(patient_data, results1):
    # Define thresholds for categorization
    low_threshold = 0.3
    high_threshold = 0.6
    
    # Categorize the normalized anomaly level
    anomaly_category = []
    for index, row in results1.iterrows():
        if row['Normalized Anomaly Level'] < low_threshold:
            anomaly_category.append('Low')
        elif row['Normalized Anomaly Level'] < high_threshold:
            anomaly_category.append('Medium')
        else:
            anomaly_category.append('High')
    
    # Assign the categories to the DataFrame
    results1['Anomaly Category'] = anomaly_category
    # print the first 10 items of the anomaly category
    print("Anomaly Category (first 10 items):")
    print(results1['Anomaly Category'].head(10))
    # Get the results for normalized anomalies and put then in a new dataframe with numerical index
    # Truncate both DataFrames to the same length if needed
    min_len = min(len(patient_data), len(results1))

    patient_data_trunc = patient_data.iloc[:min_len].reset_index(drop=True)
    results1_trunc = results1.iloc[:min_len].reset_index(drop=True)

    results = pd.DataFrame({
        'Start Time': results1_trunc['Start Time'].values,
        'End Time': results1_trunc['End Time'].values,
        'True Category': patient_data_trunc['True Category'].values,
        'Anomaly Category': results1_trunc['Anomaly Category'].values
    })
    # print the first 10 items of the results DataFrame
    print("Results DataFrame (first 10 items):")
    print(results.head(10))
    return results

# Categorize the anomaly level in results1
new_results = categorize_original_anomalies(paciente0, results1)
# Calculate the confusion matrix for the anomaly level in results1


def calculate_confusion_matrix1(results1):
    # Create a confusion matrix for the anomaly level
    confusion_matrix1 = pd.crosstab(results1['True Category'], results1['Anomaly Category'], 
                                     rownames=['True'], colnames=['Predicted'], margins=True)
    return confusion_matrix1


confusion_matrix1 = calculate_confusion_matrix1(new_results)
# Print the confusion matrix for the anomaly level in results1
print("Confusion Matrix for Anomaly Level:")
print(confusion_matrix1)

def calculate_accuracy_recall1(results1):
    # Create a classification report for the anomaly level
    report1 = classification_report(results1['True Category'], results1['Anomaly Category'], output_dict=True)
    return report1
# Calculate the accuracy and recall for the anomaly level in results1
accuracy_recall1 = calculate_accuracy_recall1(new_results)
# Print the accuracy and recall for the anomaly level in results1
# print("Accuracy and Recall Report for Anomaly Level:")
# print(pd.DataFrame(accuracy_recall1).transpose())
# extract the precision and recall from the weighted average for the anomaly level
precision1 = accuracy_recall1['weighted avg']['precision']
recall1 = accuracy_recall1['weighted avg']['recall']
print()

# Print the precision and recall for the anomaly level in results1
print(f"Precision for Anomaly Level: {precision1:.2f}, Recall for Anomaly Level: {recall1:.2f}")
def calculate_f_scores1(results1, beta=2):
    # Calculate F1 and F2 scores for the anomaly level
    f1 = f1_score(results1['True Category'], results1['Anomaly Category'], average='weighted')
    f2 = fbeta_score(results1['True Category'], results1['Anomaly Category'], beta=beta, average='weighted')
    return f1, f2
# Calculate the F1 and F2 scores for the anomaly level in results1
f1_1, f2_1 = calculate_f_scores1(new_results, beta=2)
# Print the F1 and F2 scores for the anomaly level in results1
print(f"F1 Score for Anomaly Level: {f1_1:.2f}, F2 Score for Anomaly Level: {f2_1:.2f}")
# Out:
# Anomaly Category (first 10 items):
# 0       Low
# 1       Low
# 2       Low
# 3    Medium
# 4    Medium
# 5       Low
# 6       Low
# 7       Low
# 8       Low
# 9       Low
# Name: Anomaly Category, dtype: object
# Results DataFrame (first 10 items):
#            Start Time            End Time True Category Anomaly Category
# 0 2025-03-16 17:15:00 2025-03-16 17:17:00           Low              Low
# 1 2025-03-16 17:17:00 2025-03-16 17:19:00           Low              Low
# 2 2025-03-16 17:19:00 2025-03-16 17:21:00           Low              Low
# 3 2025-03-16 17:21:00 2025-03-16 17:23:00           Low           Medium
# 4 2025-03-16 17:23:00 2025-03-16 17:25:00           Low           Medium
# 5 2025-03-16 17:25:00 2025-03-16 17:27:00           Low              Low
# 6 2025-03-16 17:27:00 2025-03-16 17:29:00           Low              Low
# 7 2025-03-16 17:29:00 2025-03-16 17:31:00           Low              Low
# 8 2025-03-16 17:31:00 2025-03-16 17:33:00           Low              Low
# 9 2025-03-16 17:33:00 2025-03-16 17:35:00           Low              Low
# Confusion Matrix for Anomaly Level:
# Predicted  High  Low  Medium  All
# True
# High          0    6       1    7
# Low          22  309     135  466
# Medium        0   23       4   27
# All          22  338     140  500
#
# Precision for Anomaly Level: 0.85, Recall for Anomaly Level: 0.63
# F1 Score for Anomaly Level: 0.72, F2 Score for Anomaly Level: 0.66

# %% [markdown]
# ### 5.4. Calcular reducción en el numero de falsos positivos

# %%
# El numero de falsos positicos es el numero de anomalias reportadas por el modelo que no son anomalias reales, es decir, cuando el paciente esta en un rango normal pero el modelo reporta una anomalia.


# Calcular falsos positivos para el modelo original:
# the resuls for the original model are stored in results1
def calculate_false_positives(results1, patient_data):
    # Count the number of false positives
    # these are where the normalized anomaly level is greater than 0 (indicating an anomaly was predicted) but the patient data in anomaly_df['Anomaly'] is False (indicating no actual anomaly).
    # DO NOT USE THE  CATEGORY, USE THE NORMALIZED VALUE
    false_positives = results1[
        (results1['Normalized Anomaly Level'] > 0.1) &
        (anomaly_df['Anomaly'] == False)  # This means the patient is in a normal range.
    ]

    # This means the model predicted an anomaly (not 'Low') but all thecc vital signs are within normal ranges.
    return len(false_positives)

false_positives = calculate_false_positives(results1, paciente0)
print(f"False Positives for the original model: {false_positives}")

# Calcular falsos positivos para el modelo de busqueda en subespacios:
def calculate_false_positives_search(results, patient_data, patient_indicator):
    # Count the number of false positives
    false_positives = results[
        (results['Indicator Value'] > 0.1) &  # This means the indicator value is greater than 0, indicating an anomaly was predicted.
        (anomaly_df['Anomaly'] == False)  # This means the patient is in a normal range.
    ]
    return len(false_positives)

false_positives_search = calculate_false_positives_search(results, paciente0, patient_indicator)
print(f"False Positives for the new model: {false_positives_search}")
# Out:
# False Positives for the original model: 31
# False Positives for the new model: 228

# %%
# Calcular la reducción de falsos positivos:
def calculate_false_positive_reduction(original_fp, search_fp):
    if original_fp == 0:
        return 0
    reduction = ((original_fp - search_fp) / original_fp) * 100
    return reduction

false_positive_reduction = calculate_false_positive_reduction(false_positives, false_positives_search)

print(f"El nuevo modelo de busqueda en subespacios ha reducido los falsos positivos en un {false_positive_reduction}% respecto al modelo original.")
# Out:
# El nuevo modelo de busqueda en subespacios ha reducido los falsos positivos en un -635.483870967742% respecto al modelo original.
